# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pdfkit as pdf

# %%
prob_ = "signed_graphs"
n_ = 60

# %%
form_ = "edge1"
method_ = "lp"

k_ = 2

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

lp1_n60_k2 = pd.DataFrame()
lp1_n60_k2 = pd.concat([lp1_n60_k2, df], ignore_index=True)
lp1_n60_k2.columns = ['instance','form','method','bs','time']
#lp1_n60_k2

k_ = 3

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

lp1_n60_k3 = pd.DataFrame()
lp1_n60_k3 = pd.concat([lp1_n60_k3, df], ignore_index=True)
lp1_n60_k3.columns = ['instance','form','method','bs','time']
#lp1_n60_k3

k_ = 4

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

lp1_n60_k4 = pd.DataFrame()
lp1_n60_k4 = pd.concat([lp1_n60_k4, df], ignore_index=True)
lp1_n60_k4.columns = ['instance','form','method','bs','time']
#lp1_n60_k4

k_ = 5

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

lp1_n60_k5 = pd.DataFrame()
lp1_n60_k5 = pd.concat([lp1_n60_k5, df], ignore_index=True)
lp1_n60_k5.columns = ['instance','form','method','bs','time']
#lp1_n60_k5

# %%
form_ = "edge1"
method_ = "mip"

k_ = 2

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

mip1_n60_k2 = pd.DataFrame()
mip1_n60_k2 = pd.concat([mip1_n60_k2, df], ignore_index=True)
mip1_n60_k2.columns = ['instance','form','method','bb','bs','gap','time','nodes','opt']
#mip1_n60_k2

k_ = 3

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

mip1_n60_k3 = pd.DataFrame()
mip1_n60_k3 = pd.concat([mip1_n60_k3, df], ignore_index=True)
mip1_n60_k3.columns = ['instance','form','method','bb','bs','gap','time','nodes','opt']
#mip1_n60_k3


k_ = 4

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

mip1_n60_k4 = pd.DataFrame()
mip1_n60_k4 = pd.concat([mip1_n60_k4, df], ignore_index=True)
mip1_n60_k4.columns = ['instance','form','method','bb','bs','gap','time','nodes','opt']
#mip1_n60_k4

k_ = 5

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

mip1_n60_k5 = pd.DataFrame()
mip1_n60_k5 = pd.concat([mip1_n60_k5, df], ignore_index=True)
mip1_n60_k5.columns = ['instance','form','method','bb','bs','gap','time','nodes','opt']
#mip1_n60_k5

# %%
mip1_n60_k2['lp'] = lp1_n60_k2['bs']
mip1_n60_k2['glp'] = (mip1_n60_k2['bs'] - lp1_n60_k2['bs'])/mip1_n60_k2['bs']
mip1_n60_k2
# Out:
#                                              instance   form method    bb  \
# 0   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge1    mip  23.0
# 1   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge1    mip  11.0
# 2   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge1    mip   9.0
# 3   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge1    mip  13.0
# 4   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge1    mip  13.0
# 5   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge1    mip  38.0
# 6   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge1    mip  24.0
# 7   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge1    mip  33.0
# 8   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge1    mip  35.0
# 9   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge1    mip  25.0
# 10  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge1    mip  61.0
# 11  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge1    mip  50.0
# 12  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge1    mip  62.0
# 13  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge1    mip  65.0
# 14  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge1    mip  54.0
#
#       bs  gap       time  nodes  opt   lp  glp
# 0   23.0  0.0   1.267003     11    1  0.0  1.0
# 1   11.0  0.0   0.275746      0    1  0.0  1.0
# 2    9.0  0.0   0.401247      0    1  0.0  1.0
# 3   13.0  0.0   0.260890      0    1  0.0  1.0
# 4   13.0  0.0   0.224955      0    1  0.0  1.0
# 5   38.0  0.0   3.127075     91    1  0.0  1.0
# 6   24.0  0.0   1.477598      9    1  0.0  1.0
# 7   33.0  0.0   2.232977     51    1  0.0  1.0
# 8   35.0  0.0   2.070462     36    1  0.0  1.0
# 9   25.0  0.0   0.902953      9    1  0.0  1.0
# 10  61.0  0.0  34.543862   3414    1  0.0  1.0
# 11  50.0  0.0   7.954383    312    1  0.0  1.0
# 12  62.0  0.0  27.921737   1852    1  0.0  1.0
# 13  65.0  0.0  26.724592   1708    1  0.0  1.0
# 14  54.0  0.0  16.049069    741    1  0.0  1.0

# %%
tab = pd.DataFrame({
    'instance':"n60_k2",
    'form':'edge1',
    'method':'mip',
    'bb':mip1_n60_k2['bb'].mean(),
    'bs':mip1_n60_k2['bs'].mean(),
    'gap':mip1_n60_k2['gap'].mean(),
    'time':mip1_n60_k2['time'].mean(),
    'nodes':mip1_n60_k2['nodes'].mean(),
    'opt':mip1_n60_k2['opt'].sum(),
    'lp':mip1_n60_k2['lp'].mean(),
    'glp':mip1_n60_k2['glp'].mean()
    },index=[""]
)

mip1_n60_k2 = pd.concat([mip1_n60_k2,tab])
mip1_n60_k2
# Out:
#                                              instance   form method    bb  \
# 0   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge1    mip  23.0
# 1   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge1    mip  11.0
# 2   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge1    mip   9.0
# 3   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge1    mip  13.0
# 4   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge1    mip  13.0
# 5   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge1    mip  38.0
# 6   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge1    mip  24.0
# 7   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge1    mip  33.0
# 8   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge1    mip  35.0
# 9   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge1    mip  25.0
# 10  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge1    mip  61.0
# 11  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge1    mip  50.0
# 12  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge1    mip  62.0
# 13  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge1    mip  65.0
# 14  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge1    mip  54.0
#                                                n60_k2  edge1    mip  34.4
#
#       bs  gap       time        nodes  opt   lp  glp
# 0   23.0  0.0   1.267003    11.000000    1  0.0  1.0
# 1   11.0  0.0   0.275746     0.000000    1  0.0  1.0
# 2    9.0  0.0   0.401247     0.000000    1  0.0  1.0
# 3   13.0  0.0   0.260890     0.000000    1  0.0  1.0
# 4   13.0  0.0   0.224955     0.000000    1  0.0  1.0
# 5   38.0  0.0   3.127075    91.000000    1  0.0  1.0
# 6   24.0  0.0   1.477598     9.000000    1  0.0  1.0
# 7   33.0  0.0   2.232977    51.000000    1  0.0  1.0
# 8   35.0  0.0   2.070462    36.000000    1  0.0  1.0
# 9   25.0  0.0   0.902953     9.000000    1  0.0  1.0
# 10  61.0  0.0  34.543862  3414.000000    1  0.0  1.0
# 11  50.0  0.0   7.954383   312.000000    1  0.0  1.0
# 12  62.0  0.0  27.921737  1852.000000    1  0.0  1.0
# 13  65.0  0.0  26.724592  1708.000000    1  0.0  1.0
# 14  54.0  0.0  16.049069   741.000000    1  0.0  1.0
#     34.4  0.0   8.362303   548.933333   15  0.0  1.0

# %%
mip1_n60_k2['instance'] = mip1_n60_k2['instance'].str.replace('data/kmbs/RANDOM/random_','')
mip1_n60_k2['instance'] = mip1_n60_k2['instance'].str.replace('_','\_') 
#mip1_n60_k2

print(mip1_n60_k2[['instance','form','bs','gap','time','nodes','opt','lp','glp']].to_latex(index=False,float_format="%.2f"))
# Out:
# \begin{tabular}{llrrrrrrr}
# \toprule
# instance & form & bs & gap & time & nodes & opt & lp & glp \\
# \midrule
# n60\_k2\_pos30\_neg5\_err5\_1.g & edge1 & 23.00 & 0.00 & 1.27 & 11.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err5\_2.g & edge1 & 11.00 & 0.00 & 0.28 & 0.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err5\_3.g & edge1 & 9.00 & 0.00 & 0.40 & 0.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err5\_4.g & edge1 & 13.00 & 0.00 & 0.26 & 0.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err5\_5.g & edge1 & 13.00 & 0.00 & 0.22 & 0.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err10\_1.g & edge1 & 38.00 & 0.00 & 3.13 & 91.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err10\_2.g & edge1 & 24.00 & 0.00 & 1.48 & 9.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err10\_3.g & edge1 & 33.00 & 0.00 & 2.23 & 51.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err10\_4.g & edge1 & 35.00 & 0.00 & 2.07 & 36.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err10\_5.g & edge1 & 25.00 & 0.00 & 0.90 & 9.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err20\_1.g & edge1 & 61.00 & 0.00 & 34.54 & 3414.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err20\_2.g & edge1 & 50.00 & 0.00 & 7.95 & 312.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err20\_3.g & edge1 & 62.00 & 0.00 & 27.92 & 1852.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err20\_4.g & edge1 & 65.00 & 0.00 & 26.72 & 1708.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err20\_5.g & edge1 & 54.00 & 0.00 & 16.05 & 741.00 & 1 & 0.00 & 1.00 \\
# n60\_k2 & edge1 & 34.40 & 0.00 & 8.36 & 548.93 & 15 & 0.00 & 1.00 \\
# \bottomrule
# \end{tabular}

# %%
mip1_n60_k3['lp'] = lp1_n60_k3['bs']
mip1_n60_k3['glp'] = (mip1_n60_k3['bs'] - lp1_n60_k3['bs'])/mip1_n60_k3['bs']
mip1_n60_k3
# Out:
#                                              instance   form method    bb  \
# 0   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge1    mip  13.0
# 1   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge1    mip   8.0
# 2   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge1    mip  14.0
# 3   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge1    mip  14.0
# 4   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge1    mip   8.0
# 5   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge1    mip  20.0
# 6   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge1    mip  18.0
# 7   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge1    mip  21.0
# 8   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge1    mip  27.0
# 9   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge1    mip  19.0
# 10  data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err2...  edge1    mip  40.0
# 11  data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err2...  edge1    mip  33.0
# 12  data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err2...  edge1    mip  39.0
# 13  data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err2...  edge1    mip  47.0
# 14  data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err2...  edge1    mip  38.0
#
#       bs  gap        time  nodes  opt   lp  glp
# 0   13.0  0.0    1.007310      9    1  0.0  1.0
# 1    8.0  0.0    0.512733      0    1  0.0  1.0
# 2   14.0  0.0    0.858965      7    1  0.0  1.0
# 3   14.0  0.0    0.924525     11    1  0.0  1.0
# 4    8.0  0.0    0.094897      0    1  0.0  1.0
# 5   20.0  0.0    1.860288     29    1  0.0  1.0
# 6   18.0  0.0    1.608990     24    1  0.0  1.0
# 7   21.0  0.0    1.544780     28    1  0.0  1.0
# 8   27.0  0.0    2.812268     80    1  0.0  1.0
# 9   19.0  0.0    1.666477     15    1  0.0  1.0
# 10  40.0  0.0   11.908260   1047    1  0.0  1.0
# 11  33.0  0.0    6.500454    614    1  0.0  1.0
# 12  39.0  0.0    9.880773   1344    1  0.0  1.0
# 13  47.0  0.0  100.218562  13453    1  0.0  1.0
# 14  38.0  0.0   50.701519  10138    1  0.0  1.0

# %%
tab = pd.DataFrame({
    'instance':"n60_k3",
    'form':'edge1',
    'method':'mip',
    'bb':mip1_n60_k3['bb'].mean(),
    'bs':mip1_n60_k3['bs'].mean(),
    'gap':mip1_n60_k3['gap'].mean(),
    'time':mip1_n60_k3['time'].mean(),
    'nodes':mip1_n60_k3['nodes'].mean(),
    'opt':mip1_n60_k3['opt'].sum(),
    'lp':mip1_n60_k3['lp'].mean(),
    'glp':mip1_n60_k3['glp'].mean()
    },index=[""]
)

mip1_n60_k3 = pd.concat([mip1_n60_k3,tab])
#mip1_n60_k3
mip1_n60_k3['instance'] = mip1_n60_k3['instance'].str.replace('data/kmbs/RANDOM/random_','')
mip1_n60_k3['instance'] = mip1_n60_k3['instance'].str.replace('_','\_') 
mip1_n60_k3
# Out:
#                             instance   form method         bb         bs  gap  \
# 0    n60\_k3\_pos30\_neg5\_err5\_1.g  edge1    mip  13.000000  13.000000  0.0
# 1    n60\_k3\_pos30\_neg5\_err5\_2.g  edge1    mip   8.000000   8.000000  0.0
# 2    n60\_k3\_pos30\_neg5\_err5\_3.g  edge1    mip  14.000000  14.000000  0.0
# 3    n60\_k3\_pos30\_neg5\_err5\_4.g  edge1    mip  14.000000  14.000000  0.0
# 4    n60\_k3\_pos30\_neg5\_err5\_5.g  edge1    mip   8.000000   8.000000  0.0
# 5   n60\_k3\_pos30\_neg5\_err10\_1.g  edge1    mip  20.000000  20.000000  0.0
# 6   n60\_k3\_pos30\_neg5\_err10\_2.g  edge1    mip  18.000000  18.000000  0.0
# 7   n60\_k3\_pos30\_neg5\_err10\_3.g  edge1    mip  21.000000  21.000000  0.0
# 8   n60\_k3\_pos30\_neg5\_err10\_4.g  edge1    mip  27.000000  27.000000  0.0
# 9   n60\_k3\_pos30\_neg5\_err10\_5.g  edge1    mip  19.000000  19.000000  0.0
# 10  n60\_k3\_pos30\_neg5\_err20\_1.g  edge1    mip  40.000000  40.000000  0.0
# 11  n60\_k3\_pos30\_neg5\_err20\_2.g  edge1    mip  33.000000  33.000000  0.0
# 12  n60\_k3\_pos30\_neg5\_err20\_3.g  edge1    mip  39.000000  39.000000  0.0
# 13  n60\_k3\_pos30\_neg5\_err20\_4.g  edge1    mip  47.000000  47.000000  0.0
# 14  n60\_k3\_pos30\_neg5\_err20\_5.g  edge1    mip  38.000000  38.000000  0.0
#                              n60\_k3  edge1    mip  23.933333  23.933333  0.0
#
#           time    nodes  opt   lp  glp
# 0     1.007310      9.0    1  0.0  1.0
# 1     0.512733      0.0    1  0.0  1.0
# 2     0.858965      7.0    1  0.0  1.0
# 3     0.924525     11.0    1  0.0  1.0
# 4     0.094897      0.0    1  0.0  1.0
# 5     1.860288     29.0    1  0.0  1.0
# 6     1.608990     24.0    1  0.0  1.0
# 7     1.544780     28.0    1  0.0  1.0
# 8     2.812268     80.0    1  0.0  1.0
# 9     1.666477     15.0    1  0.0  1.0
# 10   11.908260   1047.0    1  0.0  1.0
# 11    6.500454    614.0    1  0.0  1.0
# 12    9.880773   1344.0    1  0.0  1.0
# 13  100.218562  13453.0    1  0.0  1.0
# 14   50.701519  10138.0    1  0.0  1.0
#      12.806720   1786.6   15  0.0  1.0

# %%
print(mip1_n60_k3[['instance','form','bs','gap','time','nodes','opt','lp','glp']].to_latex(index=False,float_format="%.2f"))
# Out:
# \begin{tabular}{llrrrrrrr}
# \toprule
# instance & form & bs & gap & time & nodes & opt & lp & glp \\
# \midrule
# n60\_k3\_pos30\_neg5\_err5\_1.g & edge1 & 13.00 & 0.00 & 1.01 & 9.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err5\_2.g & edge1 & 8.00 & 0.00 & 0.51 & 0.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err5\_3.g & edge1 & 14.00 & 0.00 & 0.86 & 7.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err5\_4.g & edge1 & 14.00 & 0.00 & 0.92 & 11.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err5\_5.g & edge1 & 8.00 & 0.00 & 0.09 & 0.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err10\_1.g & edge1 & 20.00 & 0.00 & 1.86 & 29.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err10\_2.g & edge1 & 18.00 & 0.00 & 1.61 & 24.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err10\_3.g & edge1 & 21.00 & 0.00 & 1.54 & 28.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err10\_4.g & edge1 & 27.00 & 0.00 & 2.81 & 80.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err10\_5.g & edge1 & 19.00 & 0.00 & 1.67 & 15.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err20\_1.g & edge1 & 40.00 & 0.00 & 11.91 & 1047.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err20\_2.g & edge1 & 33.00 & 0.00 & 6.50 & 614.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err20\_3.g & edge1 & 39.00 & 0.00 & 9.88 & 1344.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err20\_4.g & edge1 & 47.00 & 0.00 & 100.22 & 13453.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err20\_5.g & edge1 & 38.00 & 0.00 & 50.70 & 10138.00 & 1 & 0.00 & 1.00 \\
# n60\_k3 & edge1 & 23.93 & 0.00 & 12.81 & 1786.60 & 15 & 0.00 & 1.00 \\
# \bottomrule
# \end{tabular}

# %%
mip1_n60_k4['lp'] = lp1_n60_k4['bs']
mip1_n60_k4['glp'] = (mip1_n60_k4['bs'] - lp1_n60_k4['bs'])/mip1_n60_k4['bs']
mip1_n60_k4
# Out:
#                                              instance   form method    bb  \
# 0   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge1    mip  12.0
# 1   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge1    mip  14.0
# 2   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge1    mip  13.0
# 3   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge1    mip  21.0
# 4   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge1    mip  16.0
# 5   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge1    mip  19.0
# 6   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge1    mip  19.0
# 7   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge1    mip  20.0
# 8   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge1    mip  21.0
# 9   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge1    mip  22.0
# 10  data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err2...  edge1    mip  28.0
# 11  data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err2...  edge1    mip  31.0
# 12  data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err2...  edge1    mip  34.0
# 13  data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err2...  edge1    mip  29.0
# 14  data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err2...  edge1    mip  34.0
#
#       bs  gap       time  nodes  opt   lp  glp
# 0   12.0  0.0   0.703312     33    1  0.0  1.0
# 1   14.0  0.0   1.023727     38    1  0.0  1.0
# 2   13.0  0.0   0.839539     12    1  0.0  1.0
# 3   21.0  0.0   1.919605    158    1  0.0  1.0
# 4   16.0  0.0   1.222867     30    1  0.0  1.0
# 5   19.0  0.0   1.725496    154    1  0.0  1.0
# 6   19.0  0.0   1.136606     65    1  0.0  1.0
# 7   20.0  0.0   1.864296    109    1  0.0  1.0
# 8   21.0  0.0   2.565522    190    1  0.0  1.0
# 9   22.0  0.0   2.671270    223    1  0.0  1.0
# 10  28.0  0.0   5.261966   1083    1  0.0  1.0
# 11  31.0  0.0   9.383905   2221    1  0.0  1.0
# 12  34.0  0.0  10.276077   2817    1  0.0  1.0
# 13  29.0  0.0   5.868698   1197    1  0.0  1.0
# 14  34.0  0.0  26.336490   4279    1  0.0  1.0

# %%
tab = pd.DataFrame({
    'instance':"n60_k4",
    'form':'edge1',
    'method':'mip',
    'bb':mip1_n60_k4['bb'].mean(),
    'bs':mip1_n60_k4['bs'].mean(),
    'gap':mip1_n60_k4['gap'].mean(),
    'time':mip1_n60_k4['time'].mean(),
    'nodes':mip1_n60_k4['nodes'].mean(),
    'opt':mip1_n60_k4['opt'].sum(),
    'lp':mip1_n60_k4['lp'].mean(),
    'glp':mip1_n60_k4['glp'].mean()
    },index=[""]
)

mip1_n60_k4 = pd.concat([mip1_n60_k4,tab])
#mip1_n60_k4
mip1_n60_k4['instance'] = mip1_n60_k4['instance'].str.replace('data/kmbs/RANDOM/random_','')
mip1_n60_k4['instance'] = mip1_n60_k4['instance'].str.replace('_','\_') 
mip1_n60_k4
# Out:
#                             instance   form method    bb    bs  gap  \
# 0    n60\_k4\_pos30\_neg5\_err5\_1.g  edge1    mip  12.0  12.0  0.0
# 1    n60\_k4\_pos30\_neg5\_err5\_2.g  edge1    mip  14.0  14.0  0.0
# 2    n60\_k4\_pos30\_neg5\_err5\_3.g  edge1    mip  13.0  13.0  0.0
# 3    n60\_k4\_pos30\_neg5\_err5\_4.g  edge1    mip  21.0  21.0  0.0
# 4    n60\_k4\_pos30\_neg5\_err5\_5.g  edge1    mip  16.0  16.0  0.0
# 5   n60\_k4\_pos30\_neg5\_err10\_1.g  edge1    mip  19.0  19.0  0.0
# 6   n60\_k4\_pos30\_neg5\_err10\_2.g  edge1    mip  19.0  19.0  0.0
# 7   n60\_k4\_pos30\_neg5\_err10\_3.g  edge1    mip  20.0  20.0  0.0
# 8   n60\_k4\_pos30\_neg5\_err10\_4.g  edge1    mip  21.0  21.0  0.0
# 9   n60\_k4\_pos30\_neg5\_err10\_5.g  edge1    mip  22.0  22.0  0.0
# 10  n60\_k4\_pos30\_neg5\_err20\_1.g  edge1    mip  28.0  28.0  0.0
# 11  n60\_k4\_pos30\_neg5\_err20\_2.g  edge1    mip  31.0  31.0  0.0
# 12  n60\_k4\_pos30\_neg5\_err20\_3.g  edge1    mip  34.0  34.0  0.0
# 13  n60\_k4\_pos30\_neg5\_err20\_4.g  edge1    mip  29.0  29.0  0.0
# 14  n60\_k4\_pos30\_neg5\_err20\_5.g  edge1    mip  34.0  34.0  0.0
#                              n60\_k4  edge1    mip  22.2  22.2  0.0
#
#          time   nodes  opt   lp  glp
# 0    0.703312    33.0    1  0.0  1.0
# 1    1.023727    38.0    1  0.0  1.0
# 2    0.839539    12.0    1  0.0  1.0
# 3    1.919605   158.0    1  0.0  1.0
# 4    1.222867    30.0    1  0.0  1.0
# 5    1.725496   154.0    1  0.0  1.0
# 6    1.136606    65.0    1  0.0  1.0
# 7    1.864296   109.0    1  0.0  1.0
# 8    2.565522   190.0    1  0.0  1.0
# 9    2.671270   223.0    1  0.0  1.0
# 10   5.261966  1083.0    1  0.0  1.0
# 11   9.383905  2221.0    1  0.0  1.0
# 12  10.276077  2817.0    1  0.0  1.0
# 13   5.868698  1197.0    1  0.0  1.0
# 14  26.336490  4279.0    1  0.0  1.0
#      4.853292   840.6   15  0.0  1.0

# %%
print(mip1_n60_k4[['instance','form','bs','gap','time','nodes','opt','lp','glp']].to_latex(index=False,float_format="%.2f"))
# Out:
# \begin{tabular}{llrrrrrrr}
# \toprule
# instance & form & bs & gap & time & nodes & opt & lp & glp \\
# \midrule
# n60\_k4\_pos30\_neg5\_err5\_1.g & edge1 & 12.00 & 0.00 & 0.70 & 33.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err5\_2.g & edge1 & 14.00 & 0.00 & 1.02 & 38.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err5\_3.g & edge1 & 13.00 & 0.00 & 0.84 & 12.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err5\_4.g & edge1 & 21.00 & 0.00 & 1.92 & 158.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err5\_5.g & edge1 & 16.00 & 0.00 & 1.22 & 30.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err10\_1.g & edge1 & 19.00 & 0.00 & 1.73 & 154.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err10\_2.g & edge1 & 19.00 & 0.00 & 1.14 & 65.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err10\_3.g & edge1 & 20.00 & 0.00 & 1.86 & 109.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err10\_4.g & edge1 & 21.00 & 0.00 & 2.57 & 190.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err10\_5.g & edge1 & 22.00 & 0.00 & 2.67 & 223.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err20\_1.g & edge1 & 28.00 & 0.00 & 5.26 & 1083.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err20\_2.g & edge1 & 31.00 & 0.00 & 9.38 & 2221.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err20\_3.g & edge1 & 34.00 & 0.00 & 10.28 & 2817.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err20\_4.g & edge1 & 29.00 & 0.00 & 5.87 & 1197.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err20\_5.g & edge1 & 34.00 & 0.00 & 26.34 & 4279.00 & 1 & 0.00 & 1.00 \\
# n60\_k4 & edge1 & 22.20 & 0.00 & 4.85 & 840.60 & 15 & 0.00 & 1.00 \\
# \bottomrule
# \end{tabular}

# %%
mip1_n60_k5['lp'] = lp1_n60_k5['bs']
mip1_n60_k5['glp'] = (mip1_n60_k5['bs'] - lp1_n60_k5['bs'])/mip1_n60_k5['bs']
mip1_n60_k5
# Out:
#                                              instance   form method    bb  \
# 0   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge1    mip  18.0
# 1   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge1    mip  13.0
# 2   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge1    mip  14.0
# 3   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge1    mip  16.0
# 4   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge1    mip  10.0
# 5   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge1    mip  22.0
# 6   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge1    mip  18.0
# 7   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge1    mip  22.0
# 8   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge1    mip  18.0
# 9   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge1    mip  17.0
# 10  data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err2...  edge1    mip  25.0
# 11  data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err2...  edge1    mip  23.0
# 12  data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err2...  edge1    mip  23.0
# 13  data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err2...  edge1    mip  27.0
# 14  data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err2...  edge1    mip  26.0
#
#       bs  gap       time  nodes  opt   lp  glp
# 0   18.0  0.0   1.481376    201    1  0.0  1.0
# 1   13.0  0.0   0.921854     70    1  0.0  1.0
# 2   14.0  0.0   1.023586     55    1  0.0  1.0
# 3   16.0  0.0   1.560668    210    1  0.0  1.0
# 4   10.0  0.0   0.673031     41    1  0.0  1.0
# 5   22.0  0.0   2.781315    410    1  0.0  1.0
# 6   18.0  0.0   1.309814    158    1  0.0  1.0
# 7   22.0  0.0   2.696275    621    1  0.0  1.0
# 8   18.0  0.0   1.960290    242    1  0.0  1.0
# 9   17.0  0.0   1.065829     91    1  0.0  1.0
# 10  25.0  0.0   3.460459    670    1  0.0  1.0
# 11  23.0  0.0   3.050783    655    1  0.0  1.0
# 12  23.0  0.0   2.485907    300    1  0.0  1.0
# 13  27.0  0.0  13.353358   3140    1  0.0  1.0
# 14  26.0  0.0   2.799706    426    1  0.0  1.0

# %%
tab = pd.DataFrame({
    'instance':"n60_k5",
    'form':'edge1',
    'method':'mip',
    'bb':mip1_n60_k5['bb'].mean(),
    'bs':mip1_n60_k5['bs'].mean(),
    'gap':mip1_n60_k5['gap'].mean(),
    'time':mip1_n60_k5['time'].mean(),
    'nodes':mip1_n60_k5['nodes'].mean(),
    'opt':mip1_n60_k5['opt'].sum(),
    'lp':mip1_n60_k5['lp'].mean(),
    'glp':mip1_n60_k5['glp'].mean()
    },index=[""]
)

mip1_n60_k5 = pd.concat([mip1_n60_k5,tab])
#mip1_n60_k5

mip1_n60_k5['instance'] = mip1_n60_k5['instance'].str.replace('data/kmbs/RANDOM/random_','')
mip1_n60_k5['instance'] = mip1_n60_k5['instance'].str.replace('_','\_') 
mip1_n60_k5
# Out:
#                             instance   form method         bb         bs  gap  \
# 0    n60\_k5\_pos30\_neg5\_err5\_1.g  edge1    mip  18.000000  18.000000  0.0
# 1    n60\_k5\_pos30\_neg5\_err5\_2.g  edge1    mip  13.000000  13.000000  0.0
# 2    n60\_k5\_pos30\_neg5\_err5\_3.g  edge1    mip  14.000000  14.000000  0.0
# 3    n60\_k5\_pos30\_neg5\_err5\_4.g  edge1    mip  16.000000  16.000000  0.0
# 4    n60\_k5\_pos30\_neg5\_err5\_5.g  edge1    mip  10.000000  10.000000  0.0
# 5   n60\_k5\_pos30\_neg5\_err10\_1.g  edge1    mip  22.000000  22.000000  0.0
# 6   n60\_k5\_pos30\_neg5\_err10\_2.g  edge1    mip  18.000000  18.000000  0.0
# 7   n60\_k5\_pos30\_neg5\_err10\_3.g  edge1    mip  22.000000  22.000000  0.0
# 8   n60\_k5\_pos30\_neg5\_err10\_4.g  edge1    mip  18.000000  18.000000  0.0
# 9   n60\_k5\_pos30\_neg5\_err10\_5.g  edge1    mip  17.000000  17.000000  0.0
# 10  n60\_k5\_pos30\_neg5\_err20\_1.g  edge1    mip  25.000000  25.000000  0.0
# 11  n60\_k5\_pos30\_neg5\_err20\_2.g  edge1    mip  23.000000  23.000000  0.0
# 12  n60\_k5\_pos30\_neg5\_err20\_3.g  edge1    mip  23.000000  23.000000  0.0
# 13  n60\_k5\_pos30\_neg5\_err20\_4.g  edge1    mip  27.000000  27.000000  0.0
# 14  n60\_k5\_pos30\_neg5\_err20\_5.g  edge1    mip  26.000000  26.000000  0.0
#                              n60\_k5  edge1    mip  19.466667  19.466667  0.0
#
#          time   nodes  opt   lp  glp
# 0    1.481376   201.0    1  0.0  1.0
# 1    0.921854    70.0    1  0.0  1.0
# 2    1.023586    55.0    1  0.0  1.0
# 3    1.560668   210.0    1  0.0  1.0
# 4    0.673031    41.0    1  0.0  1.0
# 5    2.781315   410.0    1  0.0  1.0
# 6    1.309814   158.0    1  0.0  1.0
# 7    2.696275   621.0    1  0.0  1.0
# 8    1.960290   242.0    1  0.0  1.0
# 9    1.065829    91.0    1  0.0  1.0
# 10   3.460459   670.0    1  0.0  1.0
# 11   3.050783   655.0    1  0.0  1.0
# 12   2.485907   300.0    1  0.0  1.0
# 13  13.353358  3140.0    1  0.0  1.0
# 14   2.799706   426.0    1  0.0  1.0
#      2.708283   486.0   15  0.0  1.0

# %%
print(mip1_n60_k5[['instance','form','bs','gap','time','nodes','opt','lp','glp']].to_latex(index=False,float_format="%.2f"))
# Out:
# \begin{tabular}{llrrrrrrr}
# \toprule
# instance & form & bs & gap & time & nodes & opt & lp & glp \\
# \midrule
# n60\_k5\_pos30\_neg5\_err5\_1.g & edge1 & 18.00 & 0.00 & 1.48 & 201.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err5\_2.g & edge1 & 13.00 & 0.00 & 0.92 & 70.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err5\_3.g & edge1 & 14.00 & 0.00 & 1.02 & 55.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err5\_4.g & edge1 & 16.00 & 0.00 & 1.56 & 210.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err5\_5.g & edge1 & 10.00 & 0.00 & 0.67 & 41.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err10\_1.g & edge1 & 22.00 & 0.00 & 2.78 & 410.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err10\_2.g & edge1 & 18.00 & 0.00 & 1.31 & 158.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err10\_3.g & edge1 & 22.00 & 0.00 & 2.70 & 621.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err10\_4.g & edge1 & 18.00 & 0.00 & 1.96 & 242.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err10\_5.g & edge1 & 17.00 & 0.00 & 1.07 & 91.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err20\_1.g & edge1 & 25.00 & 0.00 & 3.46 & 670.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err20\_2.g & edge1 & 23.00 & 0.00 & 3.05 & 655.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err20\_3.g & edge1 & 23.00 & 0.00 & 2.49 & 300.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err20\_4.g & edge1 & 27.00 & 0.00 & 13.35 & 3140.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err20\_5.g & edge1 & 26.00 & 0.00 & 2.80 & 426.00 & 1 & 0.00 & 1.00 \\
# n60\_k5 & edge1 & 19.47 & 0.00 & 2.71 & 486.00 & 15 & 0.00 & 1.00 \\
# \bottomrule
# \end{tabular}

# %%
form_="edge2"
method_="lp"

k_ = 2

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

lp2_n60_k2 = pd.DataFrame()
lp2_n60_k2 = pd.concat([lp2_n60_k2, df], ignore_index=True)
lp2_n60_k2.columns = ['instance','form','method','bs','time']
#lp2_n60_k2

k_ = 3

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

lp2_n60_k3 = pd.DataFrame()
lp2_n60_k3 = pd.concat([lp2_n60_k3, df], ignore_index=True)
lp2_n60_k3.columns = ['instance','form','method','bs','time']
#lp2_n60_k3

k_ = 4

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

lp2_n60_k4 = pd.DataFrame()
lp2_n60_k4 = pd.concat([lp2_n60_k4, df], ignore_index=True)
lp2_n60_k4.columns = ['instance','form','method','bs','time']
#lp2_n60_k4

k_ = 5

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

lp2_n60_k5 = pd.DataFrame()
lp2_n60_k5 = pd.concat([lp2_n60_k5, df], ignore_index=True)
lp2_n60_k5.columns = ['instance','form','method','bs','time']
#lp2_n60_k5

# %%
form_="edge2"
method_="mip"

k_ = 2

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

mip2_n60_k2 = pd.DataFrame()
mip2_n60_k2 = pd.concat([mip2_n60_k2, df], ignore_index=True)
mip2_n60_k2.columns = ['instance','form','method','bb','bs','gap','time','nodes','opt']


k_ = 3

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

mip2_n60_k3 = pd.DataFrame()
mip2_n60_k3 = pd.concat([mip2_n60_k3, df], ignore_index=True)
mip2_n60_k3.columns = ['instance','form','method','bb','bs','gap','time','nodes','opt']


k_ = 4

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

mip2_n60_k4 = pd.DataFrame()
mip2_n60_k4 = pd.concat([mip2_n60_k4, df], ignore_index=True)
mip2_n60_k4.columns = ['instance','form','method','bb','bs','gap','time','nodes','opt']


k_ = 4

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

mip2_n60_k4 = pd.DataFrame()
mip2_n60_k4 = pd.concat([mip2_n60_k4, df], ignore_index=True)
mip2_n60_k4.columns = ['instance','form','method','bb','bs','gap','time','nodes','opt']


k_ = 5

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

mip2_n60_k5 = pd.DataFrame()
mip2_n60_k5 = pd.concat([mip2_n60_k5, df], ignore_index=True)
mip2_n60_k5.columns = ['instance','form','method','bb','bs','gap','time','nodes','opt']

# %%
mip2_n60_k2['lp'] = lp2_n60_k2['bs']
mip2_n60_k2['glp'] = (mip2_n60_k2['bs'] - lp2_n60_k2['bs'])/mip2_n60_k2['bs']
mip2_n60_k2
# Out:
#                                              instance   form method  \
# 0   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge2    mip
# 1   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge2    mip
# 2   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge2    mip
# 3   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge2    mip
# 4   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge2    mip
# 5   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge2    mip
# 6   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge2    mip
# 7   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge2    mip
# 8   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge2    mip
# 9   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge2    mip
# 10  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge2    mip
# 11  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge2    mip
# 12  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge2    mip
# 13  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge2    mip
# 14  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge2    mip
#
#            bb    bs       gap         time   nodes  opt   lp  glp
# 0   23.000000  23.0  0.000000     4.572483    2168    1  0.0  1.0
# 1   11.000000  11.0  0.000000     0.166248      38    1  0.0  1.0
# 2    9.000000   9.0  0.000000     0.171424      33    1  0.0  1.0
# 3   13.000000  13.0  0.000000     0.354066     113    1  0.0  1.0
# 4   13.000000  13.0  0.000000     0.379188     260    1  0.0  1.0
# 5   38.000000  38.0  0.000000    50.686118    7075    1  0.0  1.0
# 6   24.000000  24.0  0.000000     1.264719     917    1  0.0  1.0
# 7   33.000000  33.0  0.000000    16.050782    2196    1  0.0  1.0
# 8   35.000000  35.0  0.000000    14.665711    1623    1  0.0  1.0
# 9   25.000000  25.0  0.000000    10.471022     764    1  0.0  1.0
# 10  61.000000  61.0  0.000000  1618.881586  420316    1  0.0  1.0
# 11  50.000000  50.0  0.000000   428.720169  137576    1  0.0  1.0
# 12  62.000000  62.0  0.000000  1806.624958  527470    1  0.0  1.0
# 13  57.602152  65.0  0.113813  3600.003865  763563    0  0.0  1.0
# 14  54.000000  54.0  0.000000   888.302220  266161    1  0.0  1.0

# %%
tab = pd.DataFrame({
    'instance':"n60_k2",
    'form':'edge2',
    'method':'mip',
    'bb':mip2_n60_k2['bb'].mean(),
    'bs':mip2_n60_k2['bs'].mean(),
    'gap':mip2_n60_k2['gap'].mean(),
    'time':mip2_n60_k2['time'].mean(),
    'nodes':mip2_n60_k2['nodes'].mean(),
    'opt':mip2_n60_k2['opt'].sum(),
    'lp':mip2_n60_k2['lp'].mean(),
    'glp':mip2_n60_k2['glp'].mean()
    },index=[""]
)

mip2_n60_k2 = pd.concat([mip2_n60_k2,tab])
mip2_n60_k2
# Out:
#                                              instance   form method  \
# 0   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge2    mip
# 1   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge2    mip
# 2   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge2    mip
# 3   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge2    mip
# 4   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge2    mip
# 5   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge2    mip
# 6   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge2    mip
# 7   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge2    mip
# 8   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge2    mip
# 9   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge2    mip
# 10  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge2    mip
# 11  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge2    mip
# 12  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge2    mip
# 13  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge2    mip
# 14  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge2    mip
#                                                n60_k2  edge2    mip
#
#            bb    bs       gap         time     nodes  opt   lp  glp
# 0   23.000000  23.0  0.000000     4.572483    2168.0    1  0.0  1.0
# 1   11.000000  11.0  0.000000     0.166248      38.0    1  0.0  1.0
# 2    9.000000   9.0  0.000000     0.171424      33.0    1  0.0  1.0
# 3   13.000000  13.0  0.000000     0.354066     113.0    1  0.0  1.0
# 4   13.000000  13.0  0.000000     0.379188     260.0    1  0.0  1.0
# 5   38.000000  38.0  0.000000    50.686118    7075.0    1  0.0  1.0
# 6   24.000000  24.0  0.000000     1.264719     917.0    1  0.0  1.0
# 7   33.000000  33.0  0.000000    16.050782    2196.0    1  0.0  1.0
# 8   35.000000  35.0  0.000000    14.665711    1623.0    1  0.0  1.0
# 9   25.000000  25.0  0.000000    10.471022     764.0    1  0.0  1.0
# 10  61.000000  61.0  0.000000  1618.881586  420316.0    1  0.0  1.0
# 11  50.000000  50.0  0.000000   428.720169  137576.0    1  0.0  1.0
# 12  62.000000  62.0  0.000000  1806.624958  527470.0    1  0.0  1.0
# 13  57.602152  65.0  0.113813  3600.003865  763563.0    0  0.0  1.0
# 14  54.000000  54.0  0.000000   888.302220  266161.0    1  0.0  1.0
#     33.906810  34.4  0.007588   562.754304  142018.2   14  0.0  1.0

# %%
mip2_n60_k2['instance'] = mip2_n60_k2['instance'].str.replace('data/kmbs/RANDOM/random_','')
mip2_n60_k2['instance'] = mip2_n60_k2['instance'].str.replace('_','\_') 
#mip2_n60_k2

print(mip2_n60_k2[['instance','form','bs','gap','time','nodes','opt','lp','glp']].to_latex(index=False,float_format="%.2f"))
# Out:
# \begin{tabular}{llrrrrrrr}
# \toprule
# instance & form & bs & gap & time & nodes & opt & lp & glp \\
# \midrule
# n60\_k2\_pos30\_neg5\_err5\_1.g & edge2 & 23.00 & 0.00 & 4.57 & 2168.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err5\_2.g & edge2 & 11.00 & 0.00 & 0.17 & 38.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err5\_3.g & edge2 & 9.00 & 0.00 & 0.17 & 33.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err5\_4.g & edge2 & 13.00 & 0.00 & 0.35 & 113.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err5\_5.g & edge2 & 13.00 & 0.00 & 0.38 & 260.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err10\_1.g & edge2 & 38.00 & 0.00 & 50.69 & 7075.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err10\_2.g & edge2 & 24.00 & 0.00 & 1.26 & 917.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err10\_3.g & edge2 & 33.00 & 0.00 & 16.05 & 2196.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err10\_4.g & edge2 & 35.00 & 0.00 & 14.67 & 1623.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err10\_5.g & edge2 & 25.00 & 0.00 & 10.47 & 764.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err20\_1.g & edge2 & 61.00 & 0.00 & 1618.88 & 420316.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err20\_2.g & edge2 & 50.00 & 0.00 & 428.72 & 137576.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err20\_3.g & edge2 & 62.00 & 0.00 & 1806.62 & 527470.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err20\_4.g & edge2 & 65.00 & 0.11 & 3600.00 & 763563.00 & 0 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err20\_5.g & edge2 & 54.00 & 0.00 & 888.30 & 266161.00 & 1 & 0.00 & 1.00 \\
# n60\_k2 & edge2 & 34.40 & 0.01 & 562.75 & 142018.20 & 14 & 0.00 & 1.00 \\
# \bottomrule
# \end{tabular}

# %%
mip2_n60_k3['lp'] = lp2_n60_k3['bs']
mip2_n60_k3['glp'] = (mip2_n60_k3['bs'] - lp2_n60_k3['bs'])/mip2_n60_k3['bs']

mip2_n60_k3
# Out:
#                                              instance   form method    bb  \
# 0   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge2    mip  13.0
# 1   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge2    mip   8.0
# 2   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge2    mip  14.0
# 3   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge2    mip  14.0
# 4   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge2    mip   8.0
# 5   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge2    mip  20.0
# 6   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge2    mip  18.0
# 7   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge2    mip  21.0
# 8   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge2    mip  27.0
# 9   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge2    mip  19.0
# 10  data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err2...  edge2    mip  40.0
# 11  data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err2...  edge2    mip  33.0
# 12  data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err2...  edge2    mip  39.0
# 13  data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err2...  edge2    mip  47.0
# 14  data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err2...  edge2    mip  38.0
#
#       bs  gap         time   nodes  opt   lp  glp
# 0   13.0  0.0     0.615653     460    1  0.0  1.0
# 1    8.0  0.0     0.432340     277    1  0.0  1.0
# 2   14.0  0.0     0.654056     572    1  0.0  1.0
# 3   14.0  0.0     1.193325    1089    1  0.0  1.0
# 4    8.0  0.0     0.204746      89    1  0.0  1.0
# 5   20.0  0.0     3.220907    1730    1  0.0  1.0
# 6   18.0  0.0     1.864694    1646    1  0.0  1.0
# 7   21.0  0.0     6.952096    1217    1  0.0  1.0
# 8   27.0  0.0    57.592212   34176    1  0.0  1.0
# 9   19.0  0.0     5.560979    1011    1  0.0  1.0
# 10  40.0  0.0   220.434362   57053    1  0.0  1.0
# 11  33.0  0.0    76.829703   17864    1  0.0  1.0
# 12  39.0  0.0   220.499761   57642    1  0.0  1.0
# 13  47.0  0.0  2880.253290  952526    1  0.0  1.0
# 14  38.0  0.0  1170.614884  374951    1  0.0  1.0

# %%
tab = pd.DataFrame({
    'instance':"n60_k3",
    'form':'edge2',
    'method':'mip',
    'bb':mip2_n60_k3['bb'].mean(),
    'bs':mip2_n60_k3['bs'].mean(),
    'gap':mip2_n60_k3['gap'].mean(),
    'time':mip2_n60_k3['time'].mean(),
    'nodes':mip2_n60_k3['nodes'].mean(),
    'opt':mip2_n60_k3['opt'].sum(),
    'lp':mip2_n60_k3['lp'].mean(),
    'glp':mip2_n60_k3['glp'].mean()
    },index=[""]
)

mip2_n60_k3 = pd.concat([mip2_n60_k3,tab])
mip2_n60_k3
# Out:
#                                              instance   form method  \
# 0   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge2    mip
# 1   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge2    mip
# 2   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge2    mip
# 3   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge2    mip
# 4   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge2    mip
# 5   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge2    mip
# 6   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge2    mip
# 7   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge2    mip
# 8   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge2    mip
# 9   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge2    mip
# 10  data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err2...  edge2    mip
# 11  data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err2...  edge2    mip
# 12  data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err2...  edge2    mip
# 13  data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err2...  edge2    mip
# 14  data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err2...  edge2    mip
#                                                n60_k3  edge2    mip
#
#            bb         bs  gap         time          nodes  opt   lp  glp
# 0   13.000000  13.000000  0.0     0.615653     460.000000    1  0.0  1.0
# 1    8.000000   8.000000  0.0     0.432340     277.000000    1  0.0  1.0
# 2   14.000000  14.000000  0.0     0.654056     572.000000    1  0.0  1.0
# 3   14.000000  14.000000  0.0     1.193325    1089.000000    1  0.0  1.0
# 4    8.000000   8.000000  0.0     0.204746      89.000000    1  0.0  1.0
# 5   20.000000  20.000000  0.0     3.220907    1730.000000    1  0.0  1.0
# 6   18.000000  18.000000  0.0     1.864694    1646.000000    1  0.0  1.0
# 7   21.000000  21.000000  0.0     6.952096    1217.000000    1  0.0  1.0
# 8   27.000000  27.000000  0.0    57.592212   34176.000000    1  0.0  1.0
# 9   19.000000  19.000000  0.0     5.560979    1011.000000    1  0.0  1.0
# 10  40.000000  40.000000  0.0   220.434362   57053.000000    1  0.0  1.0
# 11  33.000000  33.000000  0.0    76.829703   17864.000000    1  0.0  1.0
# 12  39.000000  39.000000  0.0   220.499761   57642.000000    1  0.0  1.0
# 13  47.000000  47.000000  0.0  2880.253290  952526.000000    1  0.0  1.0
# 14  38.000000  38.000000  0.0  1170.614884  374951.000000    1  0.0  1.0
#     23.933333  23.933333  0.0   309.794867  100153.533333   15  0.0  1.0

# %%
mip2_n60_k3['instance'] = mip2_n60_k3['instance'].str.replace('data/kmbs/RANDOM/random_','')
mip2_n60_k3['instance'] = mip2_n60_k3['instance'].str.replace('_','\_') 
#mip2_n60_k3

print(mip2_n60_k3[['instance','form','bs','gap','time','nodes','opt','lp','glp']].to_latex(index=False,float_format="%.2f"))
# Out:
# \begin{tabular}{llrrrrrrr}
# \toprule
# instance & form & bs & gap & time & nodes & opt & lp & glp \\
# \midrule
# n60\_k3\_pos30\_neg5\_err5\_1.g & edge2 & 13.00 & 0.00 & 0.62 & 460.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err5\_2.g & edge2 & 8.00 & 0.00 & 0.43 & 277.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err5\_3.g & edge2 & 14.00 & 0.00 & 0.65 & 572.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err5\_4.g & edge2 & 14.00 & 0.00 & 1.19 & 1089.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err5\_5.g & edge2 & 8.00 & 0.00 & 0.20 & 89.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err10\_1.g & edge2 & 20.00 & 0.00 & 3.22 & 1730.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err10\_2.g & edge2 & 18.00 & 0.00 & 1.86 & 1646.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err10\_3.g & edge2 & 21.00 & 0.00 & 6.95 & 1217.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err10\_4.g & edge2 & 27.00 & 0.00 & 57.59 & 34176.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err10\_5.g & edge2 & 19.00 & 0.00 & 5.56 & 1011.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err20\_1.g & edge2 & 40.00 & 0.00 & 220.43 & 57053.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err20\_2.g & edge2 & 33.00 & 0.00 & 76.83 & 17864.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err20\_3.g & edge2 & 39.00 & 0.00 & 220.50 & 57642.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err20\_4.g & edge2 & 47.00 & 0.00 & 2880.25 & 952526.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err20\_5.g & edge2 & 38.00 & 0.00 & 1170.61 & 374951.00 & 1 & 0.00 & 1.00 \\
# n60\_k3 & edge2 & 23.93 & 0.00 & 309.79 & 100153.53 & 15 & 0.00 & 1.00 \\
# \bottomrule
# \end{tabular}

# %%
mip2_n60_k4['lp'] = lp2_n60_k4['bs']
mip2_n60_k4['glp'] = (mip2_n60_k4['bs'] - lp2_n60_k4['bs'])/mip2_n60_k4['bs']

mip2_n60_k4
# Out:
#                                              instance   form method    bb  \
# 0   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge2    mip  12.0
# 1   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge2    mip  14.0
# 2   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge2    mip  13.0
# 3   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge2    mip  21.0
# 4   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge2    mip  16.0
# 5   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge2    mip  19.0
# 6   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge2    mip  19.0
# 7   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge2    mip  20.0
# 8   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge2    mip  21.0
# 9   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge2    mip  22.0
# 10  data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err2...  edge2    mip  28.0
# 11  data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err2...  edge2    mip  31.0
# 12  data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err2...  edge2    mip  34.0
# 13  data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err2...  edge2    mip  29.0
# 14  data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err2...  edge2    mip  34.0
#
#       bs  gap        time   nodes  opt   lp  glp
# 0   12.0  0.0    0.422697     450    1  0.0  1.0
# 1   14.0  0.0    1.245298    1610    1  0.0  1.0
# 2   13.0  0.0    0.585346     569    1  0.0  1.0
# 3   21.0  0.0   17.462224   11736    1  0.0  1.0
# 4   16.0  0.0    3.435966    1975    1  0.0  1.0
# 5   19.0  0.0    7.582924    1656    1  0.0  1.0
# 6   19.0  0.0    6.691188    1576    1  0.0  1.0
# 7   20.0  0.0    3.024081    3348    1  0.0  1.0
# 8   21.0  0.0   12.096498    2413    1  0.0  1.0
# 9   22.0  0.0   19.755078   12670    1  0.0  1.0
# 10  28.0  0.0  119.777405   65067    1  0.0  1.0
# 11  31.0  0.0   27.247601    9072    1  0.0  1.0
# 12  34.0  0.0  303.022499  193481    1  0.0  1.0
# 13  29.0  0.0   59.820849   31752    1  0.0  1.0
# 14  34.0  0.0  427.151669  232162    1  0.0  1.0

# %%
tab = pd.DataFrame({
    'instance':"n60_k4",
    'form':'edge2',
    'method':'mip',
    'bb':mip2_n60_k4['bb'].mean(),
    'bs':mip2_n60_k4['bs'].mean(),
    'gap':mip2_n60_k4['gap'].mean(),
    'time':mip2_n60_k4['time'].mean(),
    'nodes':mip2_n60_k4['nodes'].mean(),
    'opt':mip2_n60_k4['opt'].sum(),
    'lp':mip2_n60_k4['lp'].mean(),
    'glp':mip2_n60_k4['glp'].mean()
    },index=[""]
)

mip2_n60_k4 = pd.concat([mip2_n60_k4,tab])
mip2_n60_k4
# Out:
#                                              instance   form method    bb  \
# 0   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge2    mip  12.0
# 1   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge2    mip  14.0
# 2   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge2    mip  13.0
# 3   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge2    mip  21.0
# 4   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge2    mip  16.0
# 5   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge2    mip  19.0
# 6   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge2    mip  19.0
# 7   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge2    mip  20.0
# 8   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge2    mip  21.0
# 9   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge2    mip  22.0
# 10  data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err2...  edge2    mip  28.0
# 11  data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err2...  edge2    mip  31.0
# 12  data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err2...  edge2    mip  34.0
# 13  data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err2...  edge2    mip  29.0
# 14  data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err2...  edge2    mip  34.0
#                                                n60_k4  edge2    mip  22.2
#
#       bs  gap        time          nodes  opt   lp  glp
# 0   12.0  0.0    0.422697     450.000000    1  0.0  1.0
# 1   14.0  0.0    1.245298    1610.000000    1  0.0  1.0
# 2   13.0  0.0    0.585346     569.000000    1  0.0  1.0
# 3   21.0  0.0   17.462224   11736.000000    1  0.0  1.0
# 4   16.0  0.0    3.435966    1975.000000    1  0.0  1.0
# 5   19.0  0.0    7.582924    1656.000000    1  0.0  1.0
# 6   19.0  0.0    6.691188    1576.000000    1  0.0  1.0
# 7   20.0  0.0    3.024081    3348.000000    1  0.0  1.0
# 8   21.0  0.0   12.096498    2413.000000    1  0.0  1.0
# 9   22.0  0.0   19.755078   12670.000000    1  0.0  1.0
# 10  28.0  0.0  119.777405   65067.000000    1  0.0  1.0
# 11  31.0  0.0   27.247601    9072.000000    1  0.0  1.0
# 12  34.0  0.0  303.022499  193481.000000    1  0.0  1.0
# 13  29.0  0.0   59.820849   31752.000000    1  0.0  1.0
# 14  34.0  0.0  427.151669  232162.000000    1  0.0  1.0
#     22.2  0.0   67.288088   37969.133333   15  0.0  1.0

# %%
mip2_n60_k4['instance'] = mip2_n60_k4['instance'].str.replace('data/kmbs/RANDOM/random_','')
mip2_n60_k4['instance'] = mip2_n60_k4['instance'].str.replace('_','\_') 
#mip2_n60_k4

print(mip2_n60_k4[['instance','form','bs','gap','time','nodes','opt','lp','glp']].to_latex(index=False,float_format="%.2f"))
# Out:
# \begin{tabular}{llrrrrrrr}
# \toprule
# instance & form & bs & gap & time & nodes & opt & lp & glp \\
# \midrule
# n60\_k4\_pos30\_neg5\_err5\_1.g & edge2 & 12.00 & 0.00 & 0.42 & 450.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err5\_2.g & edge2 & 14.00 & 0.00 & 1.25 & 1610.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err5\_3.g & edge2 & 13.00 & 0.00 & 0.59 & 569.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err5\_4.g & edge2 & 21.00 & 0.00 & 17.46 & 11736.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err5\_5.g & edge2 & 16.00 & 0.00 & 3.44 & 1975.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err10\_1.g & edge2 & 19.00 & 0.00 & 7.58 & 1656.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err10\_2.g & edge2 & 19.00 & 0.00 & 6.69 & 1576.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err10\_3.g & edge2 & 20.00 & 0.00 & 3.02 & 3348.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err10\_4.g & edge2 & 21.00 & 0.00 & 12.10 & 2413.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err10\_5.g & edge2 & 22.00 & 0.00 & 19.76 & 12670.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err20\_1.g & edge2 & 28.00 & 0.00 & 119.78 & 65067.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err20\_2.g & edge2 & 31.00 & 0.00 & 27.25 & 9072.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err20\_3.g & edge2 & 34.00 & 0.00 & 303.02 & 193481.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err20\_4.g & edge2 & 29.00 & 0.00 & 59.82 & 31752.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err20\_5.g & edge2 & 34.00 & 0.00 & 427.15 & 232162.00 & 1 & 0.00 & 1.00 \\
# n60\_k4 & edge2 & 22.20 & 0.00 & 67.29 & 37969.13 & 15 & 0.00 & 1.00 \\
# \bottomrule
# \end{tabular}

# %%
mip2_n60_k5['lp'] = lp2_n60_k5['bs']
mip2_n60_k5['glp'] = (mip2_n60_k5['bs'] - lp2_n60_k2['bs'])/mip2_n60_k5['bs']

mip2_n60_k5
# Out:
#                                              instance   form method    bb  \
# 0   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge2    mip  18.0
# 1   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge2    mip  13.0
# 2   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge2    mip  14.0
# 3   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge2    mip  16.0
# 4   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge2    mip  10.0
# 5   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge2    mip  22.0
# 6   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge2    mip  18.0
# 7   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge2    mip  22.0
# 8   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge2    mip  18.0
# 9   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge2    mip  17.0
# 10  data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err2...  edge2    mip  25.0
# 11  data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err2...  edge2    mip  23.0
# 12  data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err2...  edge2    mip  23.0
# 13  data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err2...  edge2    mip  27.0
# 14  data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err2...  edge2    mip  26.0
#
#       bs  gap       time  nodes  opt   lp  glp
# 0   18.0  0.0  11.647674   6545    1  0.0  1.0
# 1   13.0  0.0   4.899674   3205    1  0.0  1.0
# 2   14.0  0.0   1.062019   1802    1  0.0  1.0
# 3   16.0  0.0   8.365117   5967    1  0.0  1.0
# 4   10.0  0.0   0.590753    667    1  0.0  1.0
# 5   22.0  0.0  17.013782   8339    1  0.0  1.0
# 6   18.0  0.0   6.059283   2548    1  0.0  1.0
# 7   22.0  0.0  31.535516  10409    1  0.0  1.0
# 8   18.0  0.0  21.401408  18531    1  0.0  1.0
# 9   17.0  0.0   6.977393   1227    1  0.0  1.0
# 10  25.0  0.0  48.306035  21513    1  0.0  1.0
# 11  23.0  0.0  35.820541  24616    1  0.0  1.0
# 12  23.0  0.0  20.685185   7318    1  0.0  1.0
# 13  27.0  0.0  82.396200  28837    1  0.0  1.0
# 14  26.0  0.0  38.732148  27096    1  0.0  1.0

# %%
tab = pd.DataFrame({
    'instance':"n60_k5",
    'form':'edge2',
    'method':'mip',
    'bb':mip2_n60_k5['bb'].mean(),
    'bs':mip2_n60_k5['bs'].mean(),
    'gap':mip2_n60_k5['gap'].mean(),
    'time':mip2_n60_k5['time'].mean(),
    'nodes':mip2_n60_k5['nodes'].mean(),
    'opt':mip2_n60_k5['opt'].sum(),
    'lp':mip2_n60_k5['lp'].mean(),
    'glp':mip2_n60_k5['glp'].mean()
    },index=[""]
)

mip2_n60_k5 = pd.concat([mip2_n60_k5,tab])
mip2_n60_k5
# Out:
#                                              instance   form method  \
# 0   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge2    mip
# 1   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge2    mip
# 2   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge2    mip
# 3   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge2    mip
# 4   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge2    mip
# 5   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge2    mip
# 6   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge2    mip
# 7   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge2    mip
# 8   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge2    mip
# 9   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge2    mip
# 10  data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err2...  edge2    mip
# 11  data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err2...  edge2    mip
# 12  data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err2...  edge2    mip
# 13  data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err2...  edge2    mip
# 14  data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err2...  edge2    mip
#                                                n60_k5  edge2    mip
#
#            bb         bs  gap       time         nodes  opt   lp  glp
# 0   18.000000  18.000000  0.0  11.647674   6545.000000    1  0.0  1.0
# 1   13.000000  13.000000  0.0   4.899674   3205.000000    1  0.0  1.0
# 2   14.000000  14.000000  0.0   1.062019   1802.000000    1  0.0  1.0
# 3   16.000000  16.000000  0.0   8.365117   5967.000000    1  0.0  1.0
# 4   10.000000  10.000000  0.0   0.590753    667.000000    1  0.0  1.0
# 5   22.000000  22.000000  0.0  17.013782   8339.000000    1  0.0  1.0
# 6   18.000000  18.000000  0.0   6.059283   2548.000000    1  0.0  1.0
# 7   22.000000  22.000000  0.0  31.535516  10409.000000    1  0.0  1.0
# 8   18.000000  18.000000  0.0  21.401408  18531.000000    1  0.0  1.0
# 9   17.000000  17.000000  0.0   6.977393   1227.000000    1  0.0  1.0
# 10  25.000000  25.000000  0.0  48.306035  21513.000000    1  0.0  1.0
# 11  23.000000  23.000000  0.0  35.820541  24616.000000    1  0.0  1.0
# 12  23.000000  23.000000  0.0  20.685185   7318.000000    1  0.0  1.0
# 13  27.000000  27.000000  0.0  82.396200  28837.000000    1  0.0  1.0
# 14  26.000000  26.000000  0.0  38.732148  27096.000000    1  0.0  1.0
#     19.466667  19.466667  0.0  22.366182  11241.333333   15  0.0  1.0

# %%
mip2_n60_k5['instance'] = mip2_n60_k5['instance'].str.replace('data/kmbs/RANDOM/random_','')
mip2_n60_k5['instance'] = mip2_n60_k5['instance'].str.replace('_','\_') 
#mip2_n60_k5

print(mip2_n60_k5[['instance','form','bs','gap','time','nodes','opt','lp','glp']].to_latex(index=False,float_format="%.2f"))
# Out:
# \begin{tabular}{llrrrrrrr}
# \toprule
# instance & form & bs & gap & time & nodes & opt & lp & glp \\
# \midrule
# n60\_k5\_pos30\_neg5\_err5\_1.g & edge2 & 18.00 & 0.00 & 11.65 & 6545.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err5\_2.g & edge2 & 13.00 & 0.00 & 4.90 & 3205.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err5\_3.g & edge2 & 14.00 & 0.00 & 1.06 & 1802.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err5\_4.g & edge2 & 16.00 & 0.00 & 8.37 & 5967.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err5\_5.g & edge2 & 10.00 & 0.00 & 0.59 & 667.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err10\_1.g & edge2 & 22.00 & 0.00 & 17.01 & 8339.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err10\_2.g & edge2 & 18.00 & 0.00 & 6.06 & 2548.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err10\_3.g & edge2 & 22.00 & 0.00 & 31.54 & 10409.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err10\_4.g & edge2 & 18.00 & 0.00 & 21.40 & 18531.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err10\_5.g & edge2 & 17.00 & 0.00 & 6.98 & 1227.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err20\_1.g & edge2 & 25.00 & 0.00 & 48.31 & 21513.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err20\_2.g & edge2 & 23.00 & 0.00 & 35.82 & 24616.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err20\_3.g & edge2 & 23.00 & 0.00 & 20.69 & 7318.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err20\_4.g & edge2 & 27.00 & 0.00 & 82.40 & 28837.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err20\_5.g & edge2 & 26.00 & 0.00 & 38.73 & 27096.00 & 1 & 0.00 & 1.00 \\
# n60\_k5 & edge2 & 19.47 & 0.00 & 22.37 & 11241.33 & 15 & 0.00 & 1.00 \\
# \bottomrule
# \end{tabular}

# %%
form_="edge3"
method_="lp"

k_ = 2

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

lp3_n60_k2 = pd.DataFrame()
lp3_n60_k2 = pd.concat([lp3_n60_k2, df], ignore_index=True)
lp3_n60_k2.columns = ['instance','form','method','bs','time']
#lp3_n60_k2

k_ = 3

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

lp3_n60_k3 = pd.DataFrame()
lp3_n60_k3 = pd.concat([lp3_n60_k3, df], ignore_index=True)
lp3_n60_k3.columns = ['instance','form','method','bs','time']
#lp3_n60_k3

k_ = 4

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

lp3_n60_k4 = pd.DataFrame()
lp3_n60_k4 = pd.concat([lp3_n60_k4, df], ignore_index=True)
lp3_n60_k4.columns = ['instance','form','method','bs','time']
#lp3_n60_k4

k_ = 5

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

lp3_n60_k5 = pd.DataFrame()
lp3_n60_k5 = pd.concat([lp3_n60_k5, df], ignore_index=True)
lp3_n60_k5.columns = ['instance','form','method','bs','time']
#lp3_n60_k5

# %%
form_="edge3"
method_="mip"

k_ = 2

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

mip3_n60_k2 = pd.DataFrame()
mip3_n60_k2 = pd.concat([mip3_n60_k2, df], ignore_index=True)
mip3_n60_k2.columns = ['instance','form','method','bb','bs','gap','time','nodes','opt']


k_ = 3

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

mip3_n60_k3 = pd.DataFrame()
mip3_n60_k3 = pd.concat([mip3_n60_k3, df], ignore_index=True)
mip3_n60_k3.columns = ['instance','form','method','bb','bs','gap','time','nodes','opt']


k_ = 4

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

mip3_n60_k4 = pd.DataFrame()
mip3_n60_k4 = pd.concat([mip3_n60_k4, df], ignore_index=True)
mip3_n60_k4.columns = ['instance','form','method','bb','bs','gap','time','nodes','opt']


k_ = 4

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

mip3_n60_k4 = pd.DataFrame()
mip3_n60_k4 = pd.concat([mip3_n60_k4, df], ignore_index=True)
mip3_n60_k4.columns = ['instance','form','method','bb','bs','gap','time','nodes','opt']


k_ = 5

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

mip3_n60_k5 = pd.DataFrame()
mip3_n60_k5 = pd.concat([mip3_n60_k5, df], ignore_index=True)
mip3_n60_k5.columns = ['instance','form','method','bb','bs','gap','time','nodes','opt']

# %%
mip3_n60_k2['lp'] = lp3_n60_k2['bs']
mip3_n60_k2['glp'] = (mip3_n60_k2['bs'] - lp3_n60_k2['bs'])/mip3_n60_k2['bs']

mip3_n60_k2
# Out:
#                                              instance   form method    bb  \
# 0   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge3    mip  23.0
# 1   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge3    mip  11.0
# 2   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge3    mip   9.0
# 3   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge3    mip  13.0
# 4   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge3    mip  13.0
# 5   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge3    mip  38.0
# 6   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge3    mip  24.0
# 7   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge3    mip  33.0
# 8   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge3    mip  35.0
# 9   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge3    mip  25.0
# 10  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge3    mip  61.0
# 11  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge3    mip  50.0
# 12  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge3    mip  62.0
# 13  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge3    mip  65.0
# 14  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge3    mip  54.0
#
#       bs  gap        time  nodes  opt   lp  glp
# 0   23.0  0.0    3.125646     47    1  0.0  1.0
# 1   11.0  0.0    1.636894     13    1  0.0  1.0
# 2    9.0  0.0    1.494714      6    1  0.0  1.0
# 3   13.0  0.0    1.523555     10    1  0.0  1.0
# 4   13.0  0.0    1.749806     15    1  0.0  1.0
# 5   38.0  0.0    8.438817    403    1  0.0  1.0
# 6   24.0  0.0    2.741065     49    1  0.0  1.0
# 7   33.0  0.0    4.643853    108    1  0.0  1.0
# 8   35.0  0.0    5.166744    164    1  0.0  1.0
# 9   25.0  0.0    3.571783     43    1  0.0  1.0
# 10  61.0  0.0  196.547501  13222    1  0.0  1.0
# 11  50.0  0.0   21.516048    922    1  0.0  1.0
# 12  62.0  0.0   74.140403   3808    1  0.0  1.0
# 13  65.0  0.0  177.590134   9026    1  0.0  1.0
# 14  54.0  0.0  105.707274   3332    1  0.0  1.0

# %%
tab = pd.DataFrame({
    'instance':"n60_k2",
    'form':'edge3',
    'method':'mip',
    'bb':mip3_n60_k2['bb'].mean(),
    'bs':mip3_n60_k2['bs'].mean(),
    'gap':mip3_n60_k2['gap'].mean(),
    'time':mip3_n60_k2['time'].mean(),
    'nodes':mip3_n60_k2['nodes'].mean(),
    'opt':mip3_n60_k2['opt'].sum(),
    'lp':mip3_n60_k2['lp'].mean(),
    'glp':mip3_n60_k2['glp'].mean()
    },index=[""]
)

mip3_n60_k2 = pd.concat([mip3_n60_k2,tab])
mip3_n60_k2
# Out:
#                                              instance   form method    bb  \
# 0   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge3    mip  23.0
# 1   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge3    mip  11.0
# 2   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge3    mip   9.0
# 3   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge3    mip  13.0
# 4   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge3    mip  13.0
# 5   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge3    mip  38.0
# 6   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge3    mip  24.0
# 7   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge3    mip  33.0
# 8   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge3    mip  35.0
# 9   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge3    mip  25.0
# 10  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge3    mip  61.0
# 11  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge3    mip  50.0
# 12  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge3    mip  62.0
# 13  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge3    mip  65.0
# 14  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge3    mip  54.0
#                                                n60_k2  edge3    mip  34.4
#
#       bs  gap        time         nodes  opt   lp  glp
# 0   23.0  0.0    3.125646     47.000000    1  0.0  1.0
# 1   11.0  0.0    1.636894     13.000000    1  0.0  1.0
# 2    9.0  0.0    1.494714      6.000000    1  0.0  1.0
# 3   13.0  0.0    1.523555     10.000000    1  0.0  1.0
# 4   13.0  0.0    1.749806     15.000000    1  0.0  1.0
# 5   38.0  0.0    8.438817    403.000000    1  0.0  1.0
# 6   24.0  0.0    2.741065     49.000000    1  0.0  1.0
# 7   33.0  0.0    4.643853    108.000000    1  0.0  1.0
# 8   35.0  0.0    5.166744    164.000000    1  0.0  1.0
# 9   25.0  0.0    3.571783     43.000000    1  0.0  1.0
# 10  61.0  0.0  196.547501  13222.000000    1  0.0  1.0
# 11  50.0  0.0   21.516048    922.000000    1  0.0  1.0
# 12  62.0  0.0   74.140403   3808.000000    1  0.0  1.0
# 13  65.0  0.0  177.590134   9026.000000    1  0.0  1.0
# 14  54.0  0.0  105.707274   3332.000000    1  0.0  1.0
#     34.4  0.0   40.639616   2077.866667   15  0.0  1.0

# %%
mip3_n60_k2['instance'] = mip3_n60_k2['instance'].str.replace('data/kmbs/RANDOM/random_','')
mip3_n60_k2['instance'] = mip3_n60_k2['instance'].str.replace('_','\_') 
#mip3_n60_k2

print(mip3_n60_k2[['instance','form','bs','gap','time','nodes','opt','lp','glp']].to_latex(index=False,float_format="%.2f"))
# Out:
# \begin{tabular}{llrrrrrrr}
# \toprule
# instance & form & bs & gap & time & nodes & opt & lp & glp \\
# \midrule
# n60\_k2\_pos30\_neg5\_err5\_1.g & edge3 & 23.00 & 0.00 & 3.13 & 47.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err5\_2.g & edge3 & 11.00 & 0.00 & 1.64 & 13.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err5\_3.g & edge3 & 9.00 & 0.00 & 1.49 & 6.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err5\_4.g & edge3 & 13.00 & 0.00 & 1.52 & 10.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err5\_5.g & edge3 & 13.00 & 0.00 & 1.75 & 15.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err10\_1.g & edge3 & 38.00 & 0.00 & 8.44 & 403.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err10\_2.g & edge3 & 24.00 & 0.00 & 2.74 & 49.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err10\_3.g & edge3 & 33.00 & 0.00 & 4.64 & 108.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err10\_4.g & edge3 & 35.00 & 0.00 & 5.17 & 164.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err10\_5.g & edge3 & 25.00 & 0.00 & 3.57 & 43.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err20\_1.g & edge3 & 61.00 & 0.00 & 196.55 & 13222.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err20\_2.g & edge3 & 50.00 & 0.00 & 21.52 & 922.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err20\_3.g & edge3 & 62.00 & 0.00 & 74.14 & 3808.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err20\_4.g & edge3 & 65.00 & 0.00 & 177.59 & 9026.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err20\_5.g & edge3 & 54.00 & 0.00 & 105.71 & 3332.00 & 1 & 0.00 & 1.00 \\
# n60\_k2 & edge3 & 34.40 & 0.00 & 40.64 & 2077.87 & 15 & 0.00 & 1.00 \\
# \bottomrule
# \end{tabular}

# %%
mip3_n60_k3['lp'] = lp3_n60_k3['bs']
mip3_n60_k3['glp'] = (mip3_n60_k3['bs'] - lp3_n60_k3['bs'])/mip3_n60_k3['bs']

mip3_n60_k3
# Out:
#                                              instance   form method    bb  \
# 0   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge3    mip  13.0
# 1   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge3    mip   8.0
# 2   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge3    mip  14.0
# 3   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge3    mip  14.0
# 4   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge3    mip   8.0
# 5   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge3    mip  20.0
# 6   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge3    mip  18.0
# 7   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge3    mip  21.0
# 8   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge3    mip  27.0
# 9   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge3    mip  19.0
# 10  data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err2...  edge3    mip  40.0
# 11  data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err2...  edge3    mip  33.0
# 12  data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err2...  edge3    mip  39.0
# 13  data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err2...  edge3    mip  47.0
# 14  data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err2...  edge3    mip  38.0
#
#       bs  gap        time  nodes  opt   lp  glp
# 0   13.0  0.0    1.786679     27    1  0.0  1.0
# 1    8.0  0.0    0.992873     10    1  0.0  1.0
# 2   14.0  0.0    2.532493     39    1  0.0  1.0
# 3   14.0  0.0    1.794174     18    1  0.0  1.0
# 4    8.0  0.0    1.411439      9    1  0.0  1.0
# 5   20.0  0.0    2.709902     55    1  0.0  1.0
# 6   18.0  0.0    2.642482     51    1  0.0  1.0
# 7   21.0  0.0    2.837652    136    1  0.0  1.0
# 8   27.0  0.0    7.357282    305    1  0.0  1.0
# 9   19.0  0.0    2.568224     59    1  0.0  1.0
# 10  40.0  0.0   40.603478   4097    1  0.0  1.0
# 11  33.0  0.0   14.975926   1449    1  0.0  1.0
# 12  39.0  0.0   60.373094   7820    1  0.0  1.0
# 13  47.0  0.0  160.469554  18889    1  0.0  1.0
# 14  38.0  0.0   77.157400  10434    1  0.0  1.0

# %%
tab = pd.DataFrame({
    'instance':"n60_k3",
    'form':'edge3',
    'method':'mip',
    'bb':mip3_n60_k3['bb'].mean(),
    'bs':mip3_n60_k3['bs'].mean(),
    'gap':mip3_n60_k3['gap'].mean(),
    'time':mip3_n60_k3['time'].mean(),
    'nodes':mip3_n60_k3['nodes'].mean(),
    'opt':mip3_n60_k3['opt'].sum(),
    'lp':mip3_n60_k3['lp'].mean(),
    'glp':mip3_n60_k3['glp'].mean()
    },index=[""]
)

mip3_n60_k3 = pd.concat([mip3_n60_k3,tab])
mip3_n60_k3
# Out:
#                                              instance   form method  \
# 0   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge3    mip
# 1   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge3    mip
# 2   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge3    mip
# 3   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge3    mip
# 4   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge3    mip
# 5   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge3    mip
# 6   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge3    mip
# 7   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge3    mip
# 8   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge3    mip
# 9   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge3    mip
# 10  data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err2...  edge3    mip
# 11  data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err2...  edge3    mip
# 12  data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err2...  edge3    mip
# 13  data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err2...  edge3    mip
# 14  data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err2...  edge3    mip
#                                                n60_k3  edge3    mip
#
#            bb         bs  gap        time    nodes  opt   lp  glp
# 0   13.000000  13.000000  0.0    1.786679     27.0    1  0.0  1.0
# 1    8.000000   8.000000  0.0    0.992873     10.0    1  0.0  1.0
# 2   14.000000  14.000000  0.0    2.532493     39.0    1  0.0  1.0
# 3   14.000000  14.000000  0.0    1.794174     18.0    1  0.0  1.0
# 4    8.000000   8.000000  0.0    1.411439      9.0    1  0.0  1.0
# 5   20.000000  20.000000  0.0    2.709902     55.0    1  0.0  1.0
# 6   18.000000  18.000000  0.0    2.642482     51.0    1  0.0  1.0
# 7   21.000000  21.000000  0.0    2.837652    136.0    1  0.0  1.0
# 8   27.000000  27.000000  0.0    7.357282    305.0    1  0.0  1.0
# 9   19.000000  19.000000  0.0    2.568224     59.0    1  0.0  1.0
# 10  40.000000  40.000000  0.0   40.603478   4097.0    1  0.0  1.0
# 11  33.000000  33.000000  0.0   14.975926   1449.0    1  0.0  1.0
# 12  39.000000  39.000000  0.0   60.373094   7820.0    1  0.0  1.0
# 13  47.000000  47.000000  0.0  160.469554  18889.0    1  0.0  1.0
# 14  38.000000  38.000000  0.0   77.157400  10434.0    1  0.0  1.0
#     23.933333  23.933333  0.0   25.347510   2893.2   15  0.0  1.0

# %%
mip3_n60_k3['instance'] = mip3_n60_k3['instance'].str.replace('data/kmbs/RANDOM/random_','')
mip3_n60_k3['instance'] = mip3_n60_k3['instance'].str.replace('_','\_') 
#mip3_n60_k3

print(mip3_n60_k3[['instance','form','bs','gap','time','nodes','opt','lp','glp']].to_latex(index=False,float_format="%.2f"))
# Out:
# \begin{tabular}{llrrrrrrr}
# \toprule
# instance & form & bs & gap & time & nodes & opt & lp & glp \\
# \midrule
# n60\_k3\_pos30\_neg5\_err5\_1.g & edge3 & 13.00 & 0.00 & 1.79 & 27.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err5\_2.g & edge3 & 8.00 & 0.00 & 0.99 & 10.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err5\_3.g & edge3 & 14.00 & 0.00 & 2.53 & 39.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err5\_4.g & edge3 & 14.00 & 0.00 & 1.79 & 18.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err5\_5.g & edge3 & 8.00 & 0.00 & 1.41 & 9.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err10\_1.g & edge3 & 20.00 & 0.00 & 2.71 & 55.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err10\_2.g & edge3 & 18.00 & 0.00 & 2.64 & 51.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err10\_3.g & edge3 & 21.00 & 0.00 & 2.84 & 136.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err10\_4.g & edge3 & 27.00 & 0.00 & 7.36 & 305.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err10\_5.g & edge3 & 19.00 & 0.00 & 2.57 & 59.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err20\_1.g & edge3 & 40.00 & 0.00 & 40.60 & 4097.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err20\_2.g & edge3 & 33.00 & 0.00 & 14.98 & 1449.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err20\_3.g & edge3 & 39.00 & 0.00 & 60.37 & 7820.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err20\_4.g & edge3 & 47.00 & 0.00 & 160.47 & 18889.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err20\_5.g & edge3 & 38.00 & 0.00 & 77.16 & 10434.00 & 1 & 0.00 & 1.00 \\
# n60\_k3 & edge3 & 23.93 & 0.00 & 25.35 & 2893.20 & 15 & 0.00 & 1.00 \\
# \bottomrule
# \end{tabular}

# %%
mip3_n60_k4['lp'] = lp3_n60_k4['bs']
mip3_n60_k4['glp'] = (mip3_n60_k4['bs'] - lp3_n60_k4['bs'])/mip3_n60_k4['bs']

mip3_n60_k4
# Out:
#                                              instance   form method    bb  \
# 0   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge3    mip  12.0
# 1   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge3    mip  14.0
# 2   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge3    mip  13.0
# 3   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge3    mip  21.0
# 4   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge3    mip  16.0
# 5   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge3    mip  19.0
# 6   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge3    mip  19.0
# 7   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge3    mip  20.0
# 8   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge3    mip  21.0
# 9   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge3    mip  22.0
# 10  data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err2...  edge3    mip  28.0
# 11  data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err2...  edge3    mip  31.0
# 12  data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err2...  edge3    mip  34.0
# 13  data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err2...  edge3    mip  29.0
# 14  data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err2...  edge3    mip  34.0
#
#       bs  gap       time  nodes  opt   lp  glp
# 0   12.0  0.0   1.073002     62    1  0.0  1.0
# 1   14.0  0.0   2.027173    169    1  0.0  1.0
# 2   13.0  0.0   2.022661     76    1  0.0  1.0
# 3   21.0  0.0   5.845131    464    1  0.0  1.0
# 4   16.0  0.0   2.496975    165    1  0.0  1.0
# 5   19.0  0.0   3.404706    212    1  0.0  1.0
# 6   19.0  0.0   3.626842    359    1  0.0  1.0
# 7   20.0  0.0   3.697625    258    1  0.0  1.0
# 8   21.0  0.0   4.339956    333    1  0.0  1.0
# 9   22.0  0.0   5.091888    449    1  0.0  1.0
# 10  28.0  0.0  11.161286   1716    1  0.0  1.0
# 11  31.0  0.0  27.800434   6373    1  0.0  1.0
# 12  34.0  0.0  50.155228   8780    1  0.0  1.0
# 13  29.0  0.0  15.376475   2956    1  0.0  1.0
# 14  34.0  0.0  46.372647   7050    1  0.0  1.0

# %%
tab = pd.DataFrame({
    'instance':"n60_k4",
    'form':'edge3',
    'method':'mip',
    'bb':mip3_n60_k4['bb'].mean(),
    'bs':mip3_n60_k4['bs'].mean(),
    'gap':mip3_n60_k4['gap'].mean(),
    'time':mip3_n60_k4['time'].mean(),
    'nodes':mip3_n60_k4['nodes'].mean(),
    'opt':mip3_n60_k4['opt'].sum(),
    'lp':mip3_n60_k4['lp'].mean(),
    'glp':mip3_n60_k4['glp'].mean()
    },index=[""]
)

mip3_n60_k4 = pd.concat([mip3_n60_k4,tab])
mip3_n60_k4
# Out:
#                                              instance   form method    bb  \
# 0   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge3    mip  12.0
# 1   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge3    mip  14.0
# 2   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge3    mip  13.0
# 3   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge3    mip  21.0
# 4   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge3    mip  16.0
# 5   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge3    mip  19.0
# 6   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge3    mip  19.0
# 7   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge3    mip  20.0
# 8   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge3    mip  21.0
# 9   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge3    mip  22.0
# 10  data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err2...  edge3    mip  28.0
# 11  data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err2...  edge3    mip  31.0
# 12  data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err2...  edge3    mip  34.0
# 13  data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err2...  edge3    mip  29.0
# 14  data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err2...  edge3    mip  34.0
#                                                n60_k4  edge3    mip  22.2
#
#       bs  gap       time        nodes  opt   lp  glp
# 0   12.0  0.0   1.073002    62.000000    1  0.0  1.0
# 1   14.0  0.0   2.027173   169.000000    1  0.0  1.0
# 2   13.0  0.0   2.022661    76.000000    1  0.0  1.0
# 3   21.0  0.0   5.845131   464.000000    1  0.0  1.0
# 4   16.0  0.0   2.496975   165.000000    1  0.0  1.0
# 5   19.0  0.0   3.404706   212.000000    1  0.0  1.0
# 6   19.0  0.0   3.626842   359.000000    1  0.0  1.0
# 7   20.0  0.0   3.697625   258.000000    1  0.0  1.0
# 8   21.0  0.0   4.339956   333.000000    1  0.0  1.0
# 9   22.0  0.0   5.091888   449.000000    1  0.0  1.0
# 10  28.0  0.0  11.161286  1716.000000    1  0.0  1.0
# 11  31.0  0.0  27.800434  6373.000000    1  0.0  1.0
# 12  34.0  0.0  50.155228  8780.000000    1  0.0  1.0
# 13  29.0  0.0  15.376475  2956.000000    1  0.0  1.0
# 14  34.0  0.0  46.372647  7050.000000    1  0.0  1.0
#     22.2  0.0  12.299469  1961.466667   15  0.0  1.0

# %%
mip3_n60_k4['instance'] = mip3_n60_k4['instance'].str.replace('data/kmbs/RANDOM/random_','')
mip3_n60_k4['instance'] = mip3_n60_k4['instance'].str.replace('_','\_') 
#mip3_n60_k4

print(mip3_n60_k4[['instance','form','bs','gap','time','nodes','opt','lp','glp']].to_latex(index=False,float_format="%.2f"))
# Out:
# \begin{tabular}{llrrrrrrr}
# \toprule
# instance & form & bs & gap & time & nodes & opt & lp & glp \\
# \midrule
# n60\_k4\_pos30\_neg5\_err5\_1.g & edge3 & 12.00 & 0.00 & 1.07 & 62.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err5\_2.g & edge3 & 14.00 & 0.00 & 2.03 & 169.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err5\_3.g & edge3 & 13.00 & 0.00 & 2.02 & 76.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err5\_4.g & edge3 & 21.00 & 0.00 & 5.85 & 464.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err5\_5.g & edge3 & 16.00 & 0.00 & 2.50 & 165.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err10\_1.g & edge3 & 19.00 & 0.00 & 3.40 & 212.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err10\_2.g & edge3 & 19.00 & 0.00 & 3.63 & 359.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err10\_3.g & edge3 & 20.00 & 0.00 & 3.70 & 258.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err10\_4.g & edge3 & 21.00 & 0.00 & 4.34 & 333.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err10\_5.g & edge3 & 22.00 & 0.00 & 5.09 & 449.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err20\_1.g & edge3 & 28.00 & 0.00 & 11.16 & 1716.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err20\_2.g & edge3 & 31.00 & 0.00 & 27.80 & 6373.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err20\_3.g & edge3 & 34.00 & 0.00 & 50.16 & 8780.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err20\_4.g & edge3 & 29.00 & 0.00 & 15.38 & 2956.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err20\_5.g & edge3 & 34.00 & 0.00 & 46.37 & 7050.00 & 1 & 0.00 & 1.00 \\
# n60\_k4 & edge3 & 22.20 & 0.00 & 12.30 & 1961.47 & 15 & 0.00 & 1.00 \\
# \bottomrule
# \end{tabular}

# %%
mip3_n60_k5['lp'] = lp3_n60_k5['bs']
mip3_n60_k5['glp'] = (mip3_n60_k5['bs'] - lp3_n60_k2['bs'])/mip3_n60_k5['bs']

mip3_n60_k5
# Out:
#                                              instance   form method    bb  \
# 0   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge3    mip  18.0
# 1   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge3    mip  13.0
# 2   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge3    mip  14.0
# 3   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge3    mip  16.0
# 4   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge3    mip  10.0
# 5   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge3    mip  22.0
# 6   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge3    mip  18.0
# 7   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge3    mip  22.0
# 8   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge3    mip  18.0
# 9   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge3    mip  17.0
# 10  data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err2...  edge3    mip  25.0
# 11  data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err2...  edge3    mip  23.0
# 12  data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err2...  edge3    mip  23.0
# 13  data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err2...  edge3    mip  27.0
# 14  data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err2...  edge3    mip  26.0
#
#       bs  gap       time  nodes  opt   lp  glp
# 0   18.0  0.0   3.017160    532    1  0.0  1.0
# 1   13.0  0.0   2.311558    367    1  0.0  1.0
# 2   14.0  0.0   2.135700     94    1  0.0  1.0
# 3   16.0  0.0   2.387334    320    1  0.0  1.0
# 4   10.0  0.0   1.084739     78    1  0.0  1.0
# 5   22.0  0.0   6.782330   1669    1  0.0  1.0
# 6   18.0  0.0   3.278335    504    1  0.0  1.0
# 7   22.0  0.0   5.200755   1055    1  0.0  1.0
# 8   18.0  0.0   3.469476    372    1  0.0  1.0
# 9   17.0  0.0   3.723324    351    1  0.0  1.0
# 10  25.0  0.0   7.407416   1902    1  0.0  1.0
# 11  23.0  0.0   7.061247   1397    1  0.0  1.0
# 12  23.0  0.0   5.119867   1087    1  0.0  1.0
# 13  27.0  0.0  21.438919   4602    1  0.0  1.0
# 14  26.0  0.0   9.786657   2035    1  0.0  1.0

# %%
tab = pd.DataFrame({
    'instance':"n60_k5",
    'form':'edge3',
    'method':'mip',
    'bb':mip3_n60_k5['bb'].mean(),
    'bs':mip3_n60_k5['bs'].mean(),
    'gap':mip3_n60_k5['gap'].mean(),
    'time':mip3_n60_k5['time'].mean(),
    'nodes':mip3_n60_k5['nodes'].mean(),
    'opt':mip3_n60_k5['opt'].sum(),
    'lp':mip3_n60_k5['lp'].mean(),
    'glp':mip3_n60_k5['glp'].mean()
    },index=[""]
)

mip3_n60_k5 = pd.concat([mip3_n60_k5,tab])
mip3_n60_k5
# Out:
#                                              instance   form method  \
# 0   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge3    mip
# 1   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge3    mip
# 2   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge3    mip
# 3   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge3    mip
# 4   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge3    mip
# 5   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge3    mip
# 6   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge3    mip
# 7   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge3    mip
# 8   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge3    mip
# 9   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge3    mip
# 10  data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err2...  edge3    mip
# 11  data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err2...  edge3    mip
# 12  data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err2...  edge3    mip
# 13  data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err2...  edge3    mip
# 14  data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err2...  edge3    mip
#                                                n60_k5  edge3    mip
#
#            bb         bs  gap       time   nodes  opt   lp  glp
# 0   18.000000  18.000000  0.0   3.017160   532.0    1  0.0  1.0
# 1   13.000000  13.000000  0.0   2.311558   367.0    1  0.0  1.0
# 2   14.000000  14.000000  0.0   2.135700    94.0    1  0.0  1.0
# 3   16.000000  16.000000  0.0   2.387334   320.0    1  0.0  1.0
# 4   10.000000  10.000000  0.0   1.084739    78.0    1  0.0  1.0
# 5   22.000000  22.000000  0.0   6.782330  1669.0    1  0.0  1.0
# 6   18.000000  18.000000  0.0   3.278335   504.0    1  0.0  1.0
# 7   22.000000  22.000000  0.0   5.200755  1055.0    1  0.0  1.0
# 8   18.000000  18.000000  0.0   3.469476   372.0    1  0.0  1.0
# 9   17.000000  17.000000  0.0   3.723324   351.0    1  0.0  1.0
# 10  25.000000  25.000000  0.0   7.407416  1902.0    1  0.0  1.0
# 11  23.000000  23.000000  0.0   7.061247  1397.0    1  0.0  1.0
# 12  23.000000  23.000000  0.0   5.119867  1087.0    1  0.0  1.0
# 13  27.000000  27.000000  0.0  21.438919  4602.0    1  0.0  1.0
# 14  26.000000  26.000000  0.0   9.786657  2035.0    1  0.0  1.0
#     19.466667  19.466667  0.0   5.613654  1091.0   15  0.0  1.0

# %%
mip3_n60_k5['instance'] = mip3_n60_k5['instance'].str.replace('data/kmbs/RANDOM/random_','')
mip3_n60_k5['instance'] = mip3_n60_k5['instance'].str.replace('_','\_') 
#mip3_n60_k5

print(mip3_n60_k5[['instance','form','bs','gap','time','nodes','opt','lp','glp']].to_latex(index=False,float_format="%.2f"))
# Out:
# \begin{tabular}{llrrrrrrr}
# \toprule
# instance & form & bs & gap & time & nodes & opt & lp & glp \\
# \midrule
# n60\_k5\_pos30\_neg5\_err5\_1.g & edge3 & 18.00 & 0.00 & 3.02 & 532.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err5\_2.g & edge3 & 13.00 & 0.00 & 2.31 & 367.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err5\_3.g & edge3 & 14.00 & 0.00 & 2.14 & 94.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err5\_4.g & edge3 & 16.00 & 0.00 & 2.39 & 320.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err5\_5.g & edge3 & 10.00 & 0.00 & 1.08 & 78.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err10\_1.g & edge3 & 22.00 & 0.00 & 6.78 & 1669.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err10\_2.g & edge3 & 18.00 & 0.00 & 3.28 & 504.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err10\_3.g & edge3 & 22.00 & 0.00 & 5.20 & 1055.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err10\_4.g & edge3 & 18.00 & 0.00 & 3.47 & 372.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err10\_5.g & edge3 & 17.00 & 0.00 & 3.72 & 351.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err20\_1.g & edge3 & 25.00 & 0.00 & 7.41 & 1902.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err20\_2.g & edge3 & 23.00 & 0.00 & 7.06 & 1397.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err20\_3.g & edge3 & 23.00 & 0.00 & 5.12 & 1087.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err20\_4.g & edge3 & 27.00 & 0.00 & 21.44 & 4602.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err20\_5.g & edge3 & 26.00 & 0.00 & 9.79 & 2035.00 & 1 & 0.00 & 1.00 \\
# n60\_k5 & edge3 & 19.47 & 0.00 & 5.61 & 1091.00 & 15 & 0.00 & 1.00 \\
# \bottomrule
# \end{tabular}

# %%
tab_mip_n60_k2 = pd.DataFrame()
tab_mip_n60_k2["instance"] = mip2_n60_k2['instance']
tab_mip_n60_k2["bs1"] = mip1_n60_k2['bs']
tab_mip_n60_k2["bs2"] = mip2_n60_k2['bs']
tab_mip_n60_k2["bs3"] = mip3_n60_k2['bs']
tab_mip_n60_k2["time1"] = mip1_n60_k2['time']
tab_mip_n60_k2["time2"] = mip2_n60_k2['time']
tab_mip_n60_k2["time3"] = mip3_n60_k2['time']
tab_mip_n60_k2["nodes1"] = mip1_n60_k2['nodes']
tab_mip_n60_k2["nodes2"] = mip2_n60_k2['nodes']
tab_mip_n60_k2["nodes3"] = mip3_n60_k2['nodes']

tab_mip_n60_k2
# Out:
#                             instance   bs1   bs2   bs3      time1  \
# 0    n60\_k2\_pos30\_neg5\_err5\_1.g  23.0  23.0  23.0   1.267003
# 1    n60\_k2\_pos30\_neg5\_err5\_2.g  11.0  11.0  11.0   0.275746
# 2    n60\_k2\_pos30\_neg5\_err5\_3.g   9.0   9.0   9.0   0.401247
# 3    n60\_k2\_pos30\_neg5\_err5\_4.g  13.0  13.0  13.0   0.260890
# 4    n60\_k2\_pos30\_neg5\_err5\_5.g  13.0  13.0  13.0   0.224955
# 5   n60\_k2\_pos30\_neg5\_err10\_1.g  38.0  38.0  38.0   3.127075
# 6   n60\_k2\_pos30\_neg5\_err10\_2.g  24.0  24.0  24.0   1.477598
# 7   n60\_k2\_pos30\_neg5\_err10\_3.g  33.0  33.0  33.0   2.232977
# 8   n60\_k2\_pos30\_neg5\_err10\_4.g  35.0  35.0  35.0   2.070462
# 9   n60\_k2\_pos30\_neg5\_err10\_5.g  25.0  25.0  25.0   0.902953
# 10  n60\_k2\_pos30\_neg5\_err20\_1.g  61.0  61.0  61.0  34.543862
# 11  n60\_k2\_pos30\_neg5\_err20\_2.g  50.0  50.0  50.0   7.954383
# 12  n60\_k2\_pos30\_neg5\_err20\_3.g  62.0  62.0  62.0  27.921737
# 13  n60\_k2\_pos30\_neg5\_err20\_4.g  65.0  65.0  65.0  26.724592
# 14  n60\_k2\_pos30\_neg5\_err20\_5.g  54.0  54.0  54.0  16.049069
#                              n60\_k2  34.4  34.4  34.4   8.362303
#
#           time2       time3       nodes1    nodes2        nodes3
# 0      4.572483    3.125646    11.000000    2168.0     47.000000
# 1      0.166248    1.636894     0.000000      38.0     13.000000
# 2      0.171424    1.494714     0.000000      33.0      6.000000
# 3      0.354066    1.523555     0.000000     113.0     10.000000
# 4      0.379188    1.749806     0.000000     260.0     15.000000
# 5     50.686118    8.438817    91.000000    7075.0    403.000000
# 6      1.264719    2.741065     9.000000     917.0     49.000000
# 7     16.050782    4.643853    51.000000    2196.0    108.000000
# 8     14.665711    5.166744    36.000000    1623.0    164.000000
# 9     10.471022    3.571783     9.000000     764.0     43.000000
# 10  1618.881586  196.547501  3414.000000  420316.0  13222.000000
# 11   428.720169   21.516048   312.000000  137576.0    922.000000
# 12  1806.624958   74.140403  1852.000000  527470.0   3808.000000
# 13  3600.003865  177.590134  1708.000000  763563.0   9026.000000
# 14   888.302220  105.707274   741.000000  266161.0   3332.000000
#      562.754304   40.639616   548.933333  142018.2   2077.866667

# %%
#print(tab_mip_n60_k2[['instance','bs1','bs2','bs3','time1','time2','time3','nodes1','nodes2','nodes3']].to_latex(index=False,float_format="%.2f"))
print(tab_mip_n60_k2[['instance','time1','time2','time3','nodes1','nodes2','nodes3']].to_latex(index=False,float_format="%.2f"))
# Out:
# \begin{tabular}{lrrrrrr}
# \toprule
# instance & time1 & time2 & time3 & nodes1 & nodes2 & nodes3 \\
# \midrule
# n60\_k2\_pos30\_neg5\_err5\_1.g & 1.27 & 4.57 & 3.13 & 11.00 & 2168.00 & 47.00 \\
# n60\_k2\_pos30\_neg5\_err5\_2.g & 0.28 & 0.17 & 1.64 & 0.00 & 38.00 & 13.00 \\
# n60\_k2\_pos30\_neg5\_err5\_3.g & 0.40 & 0.17 & 1.49 & 0.00 & 33.00 & 6.00 \\
# n60\_k2\_pos30\_neg5\_err5\_4.g & 0.26 & 0.35 & 1.52 & 0.00 & 113.00 & 10.00 \\
# n60\_k2\_pos30\_neg5\_err5\_5.g & 0.22 & 0.38 & 1.75 & 0.00 & 260.00 & 15.00 \\
# n60\_k2\_pos30\_neg5\_err10\_1.g & 3.13 & 50.69 & 8.44 & 91.00 & 7075.00 & 403.00 \\
# n60\_k2\_pos30\_neg5\_err10\_2.g & 1.48 & 1.26 & 2.74 & 9.00 & 917.00 & 49.00 \\
# n60\_k2\_pos30\_neg5\_err10\_3.g & 2.23 & 16.05 & 4.64 & 51.00 & 2196.00 & 108.00 \\
# n60\_k2\_pos30\_neg5\_err10\_4.g & 2.07 & 14.67 & 5.17 & 36.00 & 1623.00 & 164.00 \\
# n60\_k2\_pos30\_neg5\_err10\_5.g & 0.90 & 10.47 & 3.57 & 9.00 & 764.00 & 43.00 \\
# n60\_k2\_pos30\_neg5\_err20\_1.g & 34.54 & 1618.88 & 196.55 & 3414.00 & 420316.00 & 13222.00 \\
# n60\_k2\_pos30\_neg5\_err20\_2.g & 7.95 & 428.72 & 21.52 & 312.00 & 137576.00 & 922.00 \\
# n60\_k2\_pos30\_neg5\_err20\_3.g & 27.92 & 1806.62 & 74.14 & 1852.00 & 527470.00 & 3808.00 \\
# n60\_k2\_pos30\_neg5\_err20\_4.g & 26.72 & 3600.00 & 177.59 & 1708.00 & 763563.00 & 9026.00 \\
# n60\_k2\_pos30\_neg5\_err20\_5.g & 16.05 & 888.30 & 105.71 & 741.00 & 266161.00 & 3332.00 \\
# n60\_k2 & 8.36 & 562.75 & 40.64 & 548.93 & 142018.20 & 2077.87 \\
# \bottomrule
# \end{tabular}

# %%
tab_mip_n60_k3 = pd.DataFrame()
tab_mip_n60_k3["instance"] = mip2_n60_k3['instance']
tab_mip_n60_k3["bs1"] = mip1_n60_k3['bs']
tab_mip_n60_k3["bs2"] = mip2_n60_k3['bs']
tab_mip_n60_k3["bs3"] = mip3_n60_k3['bs']
tab_mip_n60_k3["time1"] = mip1_n60_k3['time']
tab_mip_n60_k3["time2"] = mip2_n60_k3['time']
tab_mip_n60_k3["time3"] = mip3_n60_k3['time']
tab_mip_n60_k3["nodes1"] = mip1_n60_k3['nodes']
tab_mip_n60_k3["nodes2"] = mip2_n60_k3['nodes']
tab_mip_n60_k3["nodes3"] = mip3_n60_k3['nodes']

tab_mip_n60_k3
# Out:
#                             instance        bs1        bs2        bs3  \
# 0    n60\_k3\_pos30\_neg5\_err5\_1.g  13.000000  13.000000  13.000000
# 1    n60\_k3\_pos30\_neg5\_err5\_2.g   8.000000   8.000000   8.000000
# 2    n60\_k3\_pos30\_neg5\_err5\_3.g  14.000000  14.000000  14.000000
# 3    n60\_k3\_pos30\_neg5\_err5\_4.g  14.000000  14.000000  14.000000
# 4    n60\_k3\_pos30\_neg5\_err5\_5.g   8.000000   8.000000   8.000000
# 5   n60\_k3\_pos30\_neg5\_err10\_1.g  20.000000  20.000000  20.000000
# 6   n60\_k3\_pos30\_neg5\_err10\_2.g  18.000000  18.000000  18.000000
# 7   n60\_k3\_pos30\_neg5\_err10\_3.g  21.000000  21.000000  21.000000
# 8   n60\_k3\_pos30\_neg5\_err10\_4.g  27.000000  27.000000  27.000000
# 9   n60\_k3\_pos30\_neg5\_err10\_5.g  19.000000  19.000000  19.000000
# 10  n60\_k3\_pos30\_neg5\_err20\_1.g  40.000000  40.000000  40.000000
# 11  n60\_k3\_pos30\_neg5\_err20\_2.g  33.000000  33.000000  33.000000
# 12  n60\_k3\_pos30\_neg5\_err20\_3.g  39.000000  39.000000  39.000000
# 13  n60\_k3\_pos30\_neg5\_err20\_4.g  47.000000  47.000000  47.000000
# 14  n60\_k3\_pos30\_neg5\_err20\_5.g  38.000000  38.000000  38.000000
#                              n60\_k3  23.933333  23.933333  23.933333
#
#          time1        time2       time3   nodes1         nodes2   nodes3
# 0     1.007310     0.615653    1.786679      9.0     460.000000     27.0
# 1     0.512733     0.432340    0.992873      0.0     277.000000     10.0
# 2     0.858965     0.654056    2.532493      7.0     572.000000     39.0
# 3     0.924525     1.193325    1.794174     11.0    1089.000000     18.0
# 4     0.094897     0.204746    1.411439      0.0      89.000000      9.0
# 5     1.860288     3.220907    2.709902     29.0    1730.000000     55.0
# 6     1.608990     1.864694    2.642482     24.0    1646.000000     51.0
# 7     1.544780     6.952096    2.837652     28.0    1217.000000    136.0
# 8     2.812268    57.592212    7.357282     80.0   34176.000000    305.0
# 9     1.666477     5.560979    2.568224     15.0    1011.000000     59.0
# 10   11.908260   220.434362   40.603478   1047.0   57053.000000   4097.0
# 11    6.500454    76.829703   14.975926    614.0   17864.000000   1449.0
# 12    9.880773   220.499761   60.373094   1344.0   57642.000000   7820.0
# 13  100.218562  2880.253290  160.469554  13453.0  952526.000000  18889.0
# 14   50.701519  1170.614884   77.157400  10138.0  374951.000000  10434.0
#      12.806720   309.794867   25.347510   1786.6  100153.533333   2893.2

# %%
#print(tab_mip_n60_k3[['instance','bs1','bs2','bs3','time1','time2','time3','nodes1','nodes2','nodes3']].to_latex(index=False,float_format="%.2f"))
print(tab_mip_n60_k3[['instance','time1','time2','time3','nodes1','nodes2','nodes3']].to_latex(index=False,float_format="%.2f"))
# Out:
# \begin{tabular}{lrrrrrr}
# \toprule
# instance & time1 & time2 & time3 & nodes1 & nodes2 & nodes3 \\
# \midrule
# n60\_k3\_pos30\_neg5\_err5\_1.g & 1.01 & 0.62 & 1.79 & 9.00 & 460.00 & 27.00 \\
# n60\_k3\_pos30\_neg5\_err5\_2.g & 0.51 & 0.43 & 0.99 & 0.00 & 277.00 & 10.00 \\
# n60\_k3\_pos30\_neg5\_err5\_3.g & 0.86 & 0.65 & 2.53 & 7.00 & 572.00 & 39.00 \\
# n60\_k3\_pos30\_neg5\_err5\_4.g & 0.92 & 1.19 & 1.79 & 11.00 & 1089.00 & 18.00 \\
# n60\_k3\_pos30\_neg5\_err5\_5.g & 0.09 & 0.20 & 1.41 & 0.00 & 89.00 & 9.00 \\
# n60\_k3\_pos30\_neg5\_err10\_1.g & 1.86 & 3.22 & 2.71 & 29.00 & 1730.00 & 55.00 \\
# n60\_k3\_pos30\_neg5\_err10\_2.g & 1.61 & 1.86 & 2.64 & 24.00 & 1646.00 & 51.00 \\
# n60\_k3\_pos30\_neg5\_err10\_3.g & 1.54 & 6.95 & 2.84 & 28.00 & 1217.00 & 136.00 \\
# n60\_k3\_pos30\_neg5\_err10\_4.g & 2.81 & 57.59 & 7.36 & 80.00 & 34176.00 & 305.00 \\
# n60\_k3\_pos30\_neg5\_err10\_5.g & 1.67 & 5.56 & 2.57 & 15.00 & 1011.00 & 59.00 \\
# n60\_k3\_pos30\_neg5\_err20\_1.g & 11.91 & 220.43 & 40.60 & 1047.00 & 57053.00 & 4097.00 \\
# n60\_k3\_pos30\_neg5\_err20\_2.g & 6.50 & 76.83 & 14.98 & 614.00 & 17864.00 & 1449.00 \\
# n60\_k3\_pos30\_neg5\_err20\_3.g & 9.88 & 220.50 & 60.37 & 1344.00 & 57642.00 & 7820.00 \\
# n60\_k3\_pos30\_neg5\_err20\_4.g & 100.22 & 2880.25 & 160.47 & 13453.00 & 952526.00 & 18889.00 \\
# n60\_k3\_pos30\_neg5\_err20\_5.g & 50.70 & 1170.61 & 77.16 & 10138.00 & 374951.00 & 10434.00 \\
# n60\_k3 & 12.81 & 309.79 & 25.35 & 1786.60 & 100153.53 & 2893.20 \\
# \bottomrule
# \end{tabular}

# %%
tab_mip_n60_k4 = pd.DataFrame()
tab_mip_n60_k4["instance"] = mip2_n60_k4['instance']
tab_mip_n60_k4["bs1"] = mip1_n60_k4['bs']
tab_mip_n60_k4["bs2"] = mip2_n60_k4['bs']
tab_mip_n60_k4["bs3"] = mip3_n60_k4['bs']
tab_mip_n60_k4["time1"] = mip1_n60_k4['time']
tab_mip_n60_k4["time2"] = mip2_n60_k4['time']
tab_mip_n60_k4["time3"] = mip3_n60_k4['time']
tab_mip_n60_k4["nodes1"] = mip1_n60_k4['nodes']
tab_mip_n60_k4["nodes2"] = mip2_n60_k4['nodes']
tab_mip_n60_k4["nodes3"] = mip3_n60_k4['nodes']

tab_mip_n60_k4
# Out:
#                             instance   bs1   bs2   bs3      time1       time2  \
# 0    n60\_k4\_pos30\_neg5\_err5\_1.g  12.0  12.0  12.0   0.703312    0.422697
# 1    n60\_k4\_pos30\_neg5\_err5\_2.g  14.0  14.0  14.0   1.023727    1.245298
# 2    n60\_k4\_pos30\_neg5\_err5\_3.g  13.0  13.0  13.0   0.839539    0.585346
# 3    n60\_k4\_pos30\_neg5\_err5\_4.g  21.0  21.0  21.0   1.919605   17.462224
# 4    n60\_k4\_pos30\_neg5\_err5\_5.g  16.0  16.0  16.0   1.222867    3.435966
# 5   n60\_k4\_pos30\_neg5\_err10\_1.g  19.0  19.0  19.0   1.725496    7.582924
# 6   n60\_k4\_pos30\_neg5\_err10\_2.g  19.0  19.0  19.0   1.136606    6.691188
# 7   n60\_k4\_pos30\_neg5\_err10\_3.g  20.0  20.0  20.0   1.864296    3.024081
# 8   n60\_k4\_pos30\_neg5\_err10\_4.g  21.0  21.0  21.0   2.565522   12.096498
# 9   n60\_k4\_pos30\_neg5\_err10\_5.g  22.0  22.0  22.0   2.671270   19.755078
# 10  n60\_k4\_pos30\_neg5\_err20\_1.g  28.0  28.0  28.0   5.261966  119.777405
# 11  n60\_k4\_pos30\_neg5\_err20\_2.g  31.0  31.0  31.0   9.383905   27.247601
# 12  n60\_k4\_pos30\_neg5\_err20\_3.g  34.0  34.0  34.0  10.276077  303.022499
# 13  n60\_k4\_pos30\_neg5\_err20\_4.g  29.0  29.0  29.0   5.868698   59.820849
# 14  n60\_k4\_pos30\_neg5\_err20\_5.g  34.0  34.0  34.0  26.336490  427.151669
#                              n60\_k4  22.2  22.2  22.2   4.853292   67.288088
#
#         time3  nodes1         nodes2       nodes3
# 0    1.073002    33.0     450.000000    62.000000
# 1    2.027173    38.0    1610.000000   169.000000
# 2    2.022661    12.0     569.000000    76.000000
# 3    5.845131   158.0   11736.000000   464.000000
# 4    2.496975    30.0    1975.000000   165.000000
# 5    3.404706   154.0    1656.000000   212.000000
# 6    3.626842    65.0    1576.000000   359.000000
# 7    3.697625   109.0    3348.000000   258.000000
# 8    4.339956   190.0    2413.000000   333.000000
# 9    5.091888   223.0   12670.000000   449.000000
# 10  11.161286  1083.0   65067.000000  1716.000000
# 11  27.800434  2221.0    9072.000000  6373.000000
# 12  50.155228  2817.0  193481.000000  8780.000000
# 13  15.376475  1197.0   31752.000000  2956.000000
# 14  46.372647  4279.0  232162.000000  7050.000000
#     12.299469   840.6   37969.133333  1961.466667

# %%
#print(tab_mip_n60_k4[['instance','bs1','bs2','bs3','time1','time2','time3','nodes1','nodes2','nodes3']].to_latex(index=False,float_format="%.2f"))
print(tab_mip_n60_k4[['instance','time1','time2','time3','nodes1','nodes2','nodes3']].to_latex(index=False,float_format="%.2f"))
# Out:
# \begin{tabular}{lrrrrrr}
# \toprule
# instance & time1 & time2 & time3 & nodes1 & nodes2 & nodes3 \\
# \midrule
# n60\_k4\_pos30\_neg5\_err5\_1.g & 0.70 & 0.42 & 1.07 & 33.00 & 450.00 & 62.00 \\
# n60\_k4\_pos30\_neg5\_err5\_2.g & 1.02 & 1.25 & 2.03 & 38.00 & 1610.00 & 169.00 \\
# n60\_k4\_pos30\_neg5\_err5\_3.g & 0.84 & 0.59 & 2.02 & 12.00 & 569.00 & 76.00 \\
# n60\_k4\_pos30\_neg5\_err5\_4.g & 1.92 & 17.46 & 5.85 & 158.00 & 11736.00 & 464.00 \\
# n60\_k4\_pos30\_neg5\_err5\_5.g & 1.22 & 3.44 & 2.50 & 30.00 & 1975.00 & 165.00 \\
# n60\_k4\_pos30\_neg5\_err10\_1.g & 1.73 & 7.58 & 3.40 & 154.00 & 1656.00 & 212.00 \\
# n60\_k4\_pos30\_neg5\_err10\_2.g & 1.14 & 6.69 & 3.63 & 65.00 & 1576.00 & 359.00 \\
# n60\_k4\_pos30\_neg5\_err10\_3.g & 1.86 & 3.02 & 3.70 & 109.00 & 3348.00 & 258.00 \\
# n60\_k4\_pos30\_neg5\_err10\_4.g & 2.57 & 12.10 & 4.34 & 190.00 & 2413.00 & 333.00 \\
# n60\_k4\_pos30\_neg5\_err10\_5.g & 2.67 & 19.76 & 5.09 & 223.00 & 12670.00 & 449.00 \\
# n60\_k4\_pos30\_neg5\_err20\_1.g & 5.26 & 119.78 & 11.16 & 1083.00 & 65067.00 & 1716.00 \\
# n60\_k4\_pos30\_neg5\_err20\_2.g & 9.38 & 27.25 & 27.80 & 2221.00 & 9072.00 & 6373.00 \\
# n60\_k4\_pos30\_neg5\_err20\_3.g & 10.28 & 303.02 & 50.16 & 2817.00 & 193481.00 & 8780.00 \\
# n60\_k4\_pos30\_neg5\_err20\_4.g & 5.87 & 59.82 & 15.38 & 1197.00 & 31752.00 & 2956.00 \\
# n60\_k4\_pos30\_neg5\_err20\_5.g & 26.34 & 427.15 & 46.37 & 4279.00 & 232162.00 & 7050.00 \\
# n60\_k4 & 4.85 & 67.29 & 12.30 & 840.60 & 37969.13 & 1961.47 \\
# \bottomrule
# \end{tabular}

# %%
tab_mip_n60_k5 = pd.DataFrame()
tab_mip_n60_k5["instance"] = mip2_n60_k5['instance']
tab_mip_n60_k5["bs1"] = mip1_n60_k5['bs']
tab_mip_n60_k5["bs2"] = mip2_n60_k5['bs']
tab_mip_n60_k5["bs3"] = mip3_n60_k5['bs']
tab_mip_n60_k5["time1"] = mip1_n60_k5['time']
tab_mip_n60_k5["time2"] = mip2_n60_k5['time']
tab_mip_n60_k5["time3"] = mip3_n60_k5['time']
tab_mip_n60_k5["nodes1"] = mip1_n60_k5['nodes']
tab_mip_n60_k5["nodes2"] = mip2_n60_k5['nodes']
tab_mip_n60_k5["nodes3"] = mip3_n60_k5['nodes']

tab_mip_n60_k5
# Out:
#                             instance        bs1        bs2        bs3  \
# 0    n60\_k5\_pos30\_neg5\_err5\_1.g  18.000000  18.000000  18.000000
# 1    n60\_k5\_pos30\_neg5\_err5\_2.g  13.000000  13.000000  13.000000
# 2    n60\_k5\_pos30\_neg5\_err5\_3.g  14.000000  14.000000  14.000000
# 3    n60\_k5\_pos30\_neg5\_err5\_4.g  16.000000  16.000000  16.000000
# 4    n60\_k5\_pos30\_neg5\_err5\_5.g  10.000000  10.000000  10.000000
# 5   n60\_k5\_pos30\_neg5\_err10\_1.g  22.000000  22.000000  22.000000
# 6   n60\_k5\_pos30\_neg5\_err10\_2.g  18.000000  18.000000  18.000000
# 7   n60\_k5\_pos30\_neg5\_err10\_3.g  22.000000  22.000000  22.000000
# 8   n60\_k5\_pos30\_neg5\_err10\_4.g  18.000000  18.000000  18.000000
# 9   n60\_k5\_pos30\_neg5\_err10\_5.g  17.000000  17.000000  17.000000
# 10  n60\_k5\_pos30\_neg5\_err20\_1.g  25.000000  25.000000  25.000000
# 11  n60\_k5\_pos30\_neg5\_err20\_2.g  23.000000  23.000000  23.000000
# 12  n60\_k5\_pos30\_neg5\_err20\_3.g  23.000000  23.000000  23.000000
# 13  n60\_k5\_pos30\_neg5\_err20\_4.g  27.000000  27.000000  27.000000
# 14  n60\_k5\_pos30\_neg5\_err20\_5.g  26.000000  26.000000  26.000000
#                              n60\_k5  19.466667  19.466667  19.466667
#
#         time1      time2      time3  nodes1        nodes2  nodes3
# 0    1.481376  11.647674   3.017160   201.0   6545.000000   532.0
# 1    0.921854   4.899674   2.311558    70.0   3205.000000   367.0
# 2    1.023586   1.062019   2.135700    55.0   1802.000000    94.0
# 3    1.560668   8.365117   2.387334   210.0   5967.000000   320.0
# 4    0.673031   0.590753   1.084739    41.0    667.000000    78.0
# 5    2.781315  17.013782   6.782330   410.0   8339.000000  1669.0
# 6    1.309814   6.059283   3.278335   158.0   2548.000000   504.0
# 7    2.696275  31.535516   5.200755   621.0  10409.000000  1055.0
# 8    1.960290  21.401408   3.469476   242.0  18531.000000   372.0
# 9    1.065829   6.977393   3.723324    91.0   1227.000000   351.0
# 10   3.460459  48.306035   7.407416   670.0  21513.000000  1902.0
# 11   3.050783  35.820541   7.061247   655.0  24616.000000  1397.0
# 12   2.485907  20.685185   5.119867   300.0   7318.000000  1087.0
# 13  13.353358  82.396200  21.438919  3140.0  28837.000000  4602.0
# 14   2.799706  38.732148   9.786657   426.0  27096.000000  2035.0
#      2.708283  22.366182   5.613654   486.0  11241.333333  1091.0

# %%
#print(tab_mip_n60_k5[['instance','bs1','bs2','bs3','time1','time2','time3','nodes1','nodes2','nodes3']].to_latex(index=False,float_format="%.2f"))
print(tab_mip_n60_k5[['instance','time1','time2','time3','nodes1','nodes2','nodes3']].to_latex(index=False,float_format="%.2f"))
# Out:
# \begin{tabular}{lrrrrrr}
# \toprule
# instance & time1 & time2 & time3 & nodes1 & nodes2 & nodes3 \\
# \midrule
# n60\_k5\_pos30\_neg5\_err5\_1.g & 1.48 & 11.65 & 3.02 & 201.00 & 6545.00 & 532.00 \\
# n60\_k5\_pos30\_neg5\_err5\_2.g & 0.92 & 4.90 & 2.31 & 70.00 & 3205.00 & 367.00 \\
# n60\_k5\_pos30\_neg5\_err5\_3.g & 1.02 & 1.06 & 2.14 & 55.00 & 1802.00 & 94.00 \\
# n60\_k5\_pos30\_neg5\_err5\_4.g & 1.56 & 8.37 & 2.39 & 210.00 & 5967.00 & 320.00 \\
# n60\_k5\_pos30\_neg5\_err5\_5.g & 0.67 & 0.59 & 1.08 & 41.00 & 667.00 & 78.00 \\
# n60\_k5\_pos30\_neg5\_err10\_1.g & 2.78 & 17.01 & 6.78 & 410.00 & 8339.00 & 1669.00 \\
# n60\_k5\_pos30\_neg5\_err10\_2.g & 1.31 & 6.06 & 3.28 & 158.00 & 2548.00 & 504.00 \\
# n60\_k5\_pos30\_neg5\_err10\_3.g & 2.70 & 31.54 & 5.20 & 621.00 & 10409.00 & 1055.00 \\
# n60\_k5\_pos30\_neg5\_err10\_4.g & 1.96 & 21.40 & 3.47 & 242.00 & 18531.00 & 372.00 \\
# n60\_k5\_pos30\_neg5\_err10\_5.g & 1.07 & 6.98 & 3.72 & 91.00 & 1227.00 & 351.00 \\
# n60\_k5\_pos30\_neg5\_err20\_1.g & 3.46 & 48.31 & 7.41 & 670.00 & 21513.00 & 1902.00 \\
# n60\_k5\_pos30\_neg5\_err20\_2.g & 3.05 & 35.82 & 7.06 & 655.00 & 24616.00 & 1397.00 \\
# n60\_k5\_pos30\_neg5\_err20\_3.g & 2.49 & 20.69 & 5.12 & 300.00 & 7318.00 & 1087.00 \\
# n60\_k5\_pos30\_neg5\_err20\_4.g & 13.35 & 82.40 & 21.44 & 3140.00 & 28837.00 & 4602.00 \\
# n60\_k5\_pos30\_neg5\_err20\_5.g & 2.80 & 38.73 & 9.79 & 426.00 & 27096.00 & 2035.00 \\
# n60\_k5 & 2.71 & 22.37 & 5.61 & 486.00 & 11241.33 & 1091.00 \\
# \bottomrule
# \end{tabular}
