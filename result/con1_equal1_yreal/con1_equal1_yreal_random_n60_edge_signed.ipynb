# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pdfkit as pdf

# %%
prob_ = "signed_graphs"
n_ = 60

# %%
form_ = "edge1"
method_ = "lp"

k_ = 2

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

lp1_n60_k2 = pd.DataFrame()
lp1_n60_k2 = pd.concat([lp1_n60_k2, df], ignore_index=True)
lp1_n60_k2.columns = ['instance','form','method','bs','time']
#lp1_n60_k2

k_ = 3

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

lp1_n60_k3 = pd.DataFrame()
lp1_n60_k3 = pd.concat([lp1_n60_k3, df], ignore_index=True)
lp1_n60_k3.columns = ['instance','form','method','bs','time']
#lp1_n60_k3

k_ = 4

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

lp1_n60_k4 = pd.DataFrame()
lp1_n60_k4 = pd.concat([lp1_n60_k4, df], ignore_index=True)
lp1_n60_k4.columns = ['instance','form','method','bs','time']
#lp1_n60_k4

k_ = 5

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

lp1_n60_k5 = pd.DataFrame()
lp1_n60_k5 = pd.concat([lp1_n60_k5, df], ignore_index=True)
lp1_n60_k5.columns = ['instance','form','method','bs','time']
#lp1_n60_k5

# %%
form_ = "edge1"
method_ = "mip"

k_ = 2

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

mip1_n60_k2 = pd.DataFrame()
mip1_n60_k2 = pd.concat([mip1_n60_k2, df], ignore_index=True)
mip1_n60_k2.columns = ['instance','form','method','bb','bs','gap','time','nodes','opt']
#mip1_n60_k2

k_ = 3

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

mip1_n60_k3 = pd.DataFrame()
mip1_n60_k3 = pd.concat([mip1_n60_k3, df], ignore_index=True)
mip1_n60_k3.columns = ['instance','form','method','bb','bs','gap','time','nodes','opt']
#mip1_n60_k3


k_ = 4

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

mip1_n60_k4 = pd.DataFrame()
mip1_n60_k4 = pd.concat([mip1_n60_k4, df], ignore_index=True)
mip1_n60_k4.columns = ['instance','form','method','bb','bs','gap','time','nodes','opt']
#mip1_n60_k4

k_ = 5

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

mip1_n60_k5 = pd.DataFrame()
mip1_n60_k5 = pd.concat([mip1_n60_k5, df], ignore_index=True)
mip1_n60_k5.columns = ['instance','form','method','bb','bs','gap','time','nodes','opt']
#mip1_n60_k5

# %%
mip1_n60_k2['lp'] = lp1_n60_k2['bs']
mip1_n60_k2['glp'] = (mip1_n60_k2['bs'] - lp1_n60_k2['bs'])/mip1_n60_k2['bs']
mip1_n60_k2
# Out:
#                                              instance   form method    bb  \
# 0   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge1    mip  23.0
# 1   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge1    mip  11.0
# 2   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge1    mip   9.0
# 3   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge1    mip  13.0
# 4   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge1    mip  13.0
# 5   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge1    mip  38.0
# 6   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge1    mip  24.0
# 7   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge1    mip  33.0
# 8   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge1    mip  35.0
# 9   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge1    mip  25.0
# 10  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge1    mip  61.0
# 11  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge1    mip  50.0
# ...

# %%
tab = pd.DataFrame({
    'instance':"n60_k2",
    'form':'edge1',
    'method':'mip',
    'bb':mip1_n60_k2['bb'].mean(),
    'bs':mip1_n60_k2['bs'].mean(),
    'gap':mip1_n60_k2['gap'].mean(),
    'time':mip1_n60_k2['time'].mean(),
    'nodes':mip1_n60_k2['nodes'].mean(),
    'opt':mip1_n60_k2['opt'].sum(),
    'lp':mip1_n60_k2['lp'].mean(),
    'glp':mip1_n60_k2['glp'].mean()
    },index=[""]
)

mip1_n60_k2 = pd.concat([mip1_n60_k2,tab])
mip1_n60_k2['instance'] = mip1_n60_k2['instance'].str.replace('data/kmbs/RANDOM/random_','')
mip1_n60_k2
# Out:
#                        instance   form method    bb    bs  gap       time  \
# 0    n60_k2_pos30_neg5_err5_1.g  edge1    mip  23.0  23.0  0.0   1.053463
# 1    n60_k2_pos30_neg5_err5_2.g  edge1    mip  11.0  11.0  0.0   0.208470
# 2    n60_k2_pos30_neg5_err5_3.g  edge1    mip   9.0   9.0  0.0   0.136495
# 3    n60_k2_pos30_neg5_err5_4.g  edge1    mip  13.0  13.0  0.0   0.243686
# 4    n60_k2_pos30_neg5_err5_5.g  edge1    mip  13.0  13.0  0.0   0.211492
# 5   n60_k2_pos30_neg5_err10_1.g  edge1    mip  38.0  38.0  0.0   2.883166
# 6   n60_k2_pos30_neg5_err10_2.g  edge1    mip  24.0  24.0  0.0   0.947396
# 7   n60_k2_pos30_neg5_err10_3.g  edge1    mip  33.0  33.0  0.0   2.016801
# 8   n60_k2_pos30_neg5_err10_4.g  edge1    mip  35.0  35.0  0.0   2.196478
# 9   n60_k2_pos30_neg5_err10_5.g  edge1    mip  25.0  25.0  0.0   0.953856
# 10  n60_k2_pos30_neg5_err20_1.g  edge1    mip  61.0  61.0  0.0  22.975967
# 11  n60_k2_pos30_neg5_err20_2.g  edge1    mip  50.0  50.0  0.0   6.780756
# ...

# %%
mip1_n60_k3['lp'] = lp1_n60_k3['bs']
mip1_n60_k3['glp'] = (mip1_n60_k3['bs'] - lp1_n60_k3['bs'])/mip1_n60_k3['bs']
mip1_n60_k3
# Out:
#                                              instance   form method    bb  \
# 0   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge1    mip  13.0
# 1   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge1    mip   8.0
# 2   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge1    mip  14.0
# 3   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge1    mip  14.0
# 4   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge1    mip   8.0
# 5   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge1    mip  20.0
# 6   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge1    mip  18.0
# 7   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge1    mip  21.0
# 8   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge1    mip  27.0
# 9   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge1    mip  19.0
# 10  data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err2...  edge1    mip  40.0
# 11  data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err2...  edge1    mip  33.0
# ...

# %%
tab = pd.DataFrame({
    'instance':"n60_k3",
    'form':'edge1',
    'method':'mip',
    'bb':mip1_n60_k3['bb'].mean(),
    'bs':mip1_n60_k3['bs'].mean(),
    'gap':mip1_n60_k3['gap'].mean(),
    'time':mip1_n60_k3['time'].mean(),
    'nodes':mip1_n60_k3['nodes'].mean(),
    'opt':mip1_n60_k3['opt'].sum(),
    'lp':mip1_n60_k3['lp'].mean(),
    'glp':mip1_n60_k3['glp'].mean()
    },index=[""]
)

mip1_n60_k3 = pd.concat([mip1_n60_k3,tab])
mip1_n60_k3['instance'] = mip1_n60_k3['instance'].str.replace('data/kmbs/RANDOM/random_','')
mip1_n60_k3
# Out:
#                        instance   form method         bb         bs  gap  \
# 0    n60_k3_pos30_neg5_err5_1.g  edge1    mip  13.000000  13.000000  0.0
# 1    n60_k3_pos30_neg5_err5_2.g  edge1    mip   8.000000   8.000000  0.0
# 2    n60_k3_pos30_neg5_err5_3.g  edge1    mip  14.000000  14.000000  0.0
# 3    n60_k3_pos30_neg5_err5_4.g  edge1    mip  14.000000  14.000000  0.0
# 4    n60_k3_pos30_neg5_err5_5.g  edge1    mip   8.000000   8.000000  0.0
# 5   n60_k3_pos30_neg5_err10_1.g  edge1    mip  20.000000  20.000000  0.0
# 6   n60_k3_pos30_neg5_err10_2.g  edge1    mip  18.000000  18.000000  0.0
# 7   n60_k3_pos30_neg5_err10_3.g  edge1    mip  21.000000  21.000000  0.0
# 8   n60_k3_pos30_neg5_err10_4.g  edge1    mip  27.000000  27.000000  0.0
# 9   n60_k3_pos30_neg5_err10_5.g  edge1    mip  19.000000  19.000000  0.0
# 10  n60_k3_pos30_neg5_err20_1.g  edge1    mip  40.000000  40.000000  0.0
# 11  n60_k3_pos30_neg5_err20_2.g  edge1    mip  33.000000  33.000000  0.0
# ...

# %%
mip1_n60_k4['lp'] = lp1_n60_k4['bs']
mip1_n60_k4['glp'] = (mip1_n60_k4['bs'] - lp1_n60_k4['bs'])/mip1_n60_k4['bs']
mip1_n60_k4
# Out:
#                                              instance   form method    bb  \
# 0   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge1    mip  12.0
# 1   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge1    mip  14.0
# 2   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge1    mip  13.0
# 3   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge1    mip  21.0
# 4   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge1    mip  16.0
# 5   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge1    mip  19.0
# 6   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge1    mip  19.0
# 7   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge1    mip  20.0
# 8   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge1    mip  21.0
# 9   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge1    mip  22.0
# 10  data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err2...  edge1    mip  28.0
# 11  data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err2...  edge1    mip  31.0
# ...

# %%
tab = pd.DataFrame({
    'instance':"n60_k4",
    'form':'edge1',
    'method':'mip',
    'bb':mip1_n60_k4['bb'].mean(),
    'bs':mip1_n60_k4['bs'].mean(),
    'gap':mip1_n60_k4['gap'].mean(),
    'time':mip1_n60_k4['time'].mean(),
    'nodes':mip1_n60_k4['nodes'].mean(),
    'opt':mip1_n60_k4['opt'].sum(),
    'lp':mip1_n60_k4['lp'].mean(),
    'glp':mip1_n60_k4['glp'].mean()
    },index=[""]
)

mip1_n60_k4 = pd.concat([mip1_n60_k4,tab])
mip1_n60_k4['instance'] = mip1_n60_k4['instance'].str.replace('data/kmbs/RANDOM/random_','')
mip1_n60_k4
# Out:
#                        instance   form method    bb    bs  gap      time  \
# 0    n60_k4_pos30_neg5_err5_1.g  edge1    mip  12.0  12.0  0.0  0.654223
# 1    n60_k4_pos30_neg5_err5_2.g  edge1    mip  14.0  14.0  0.0  0.815058
# 2    n60_k4_pos30_neg5_err5_3.g  edge1    mip  13.0  13.0  0.0  0.517862
# 3    n60_k4_pos30_neg5_err5_4.g  edge1    mip  21.0  21.0  0.0  2.712034
# 4    n60_k4_pos30_neg5_err5_5.g  edge1    mip  16.0  16.0  0.0  1.002247
# 5   n60_k4_pos30_neg5_err10_1.g  edge1    mip  19.0  19.0  0.0  1.635012
# 6   n60_k4_pos30_neg5_err10_2.g  edge1    mip  19.0  19.0  0.0  1.237598
# 7   n60_k4_pos30_neg5_err10_3.g  edge1    mip  20.0  20.0  0.0  1.865367
# 8   n60_k4_pos30_neg5_err10_4.g  edge1    mip  21.0  21.0  0.0  1.936154
# 9   n60_k4_pos30_neg5_err10_5.g  edge1    mip  22.0  22.0  0.0  1.689434
# 10  n60_k4_pos30_neg5_err20_1.g  edge1    mip  28.0  28.0  0.0  4.301458
# 11  n60_k4_pos30_neg5_err20_2.g  edge1    mip  31.0  31.0  0.0  5.915757
# ...

# %%
mip1_n60_k5['lp'] = lp1_n60_k5['bs']
mip1_n60_k5['glp'] = (mip1_n60_k5['bs'] - lp1_n60_k5['bs'])/mip1_n60_k5['bs']
mip1_n60_k5
# Out:
#                                              instance   form method    bb  \
# 0   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge1    mip  18.0
# 1   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge1    mip  13.0
# 2   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge1    mip  14.0
# 3   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge1    mip  16.0
# 4   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge1    mip  10.0
# 5   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge1    mip  22.0
# 6   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge1    mip  18.0
# 7   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge1    mip  22.0
# 8   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge1    mip  18.0
# 9   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge1    mip  17.0
# 10  data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err2...  edge1    mip  25.0
# 11  data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err2...  edge1    mip  23.0
# ...

# %%
tab = pd.DataFrame({
    'instance':"n60_k5",
    'form':'edge1',
    'method':'mip',
    'bb':mip1_n60_k5['bb'].mean(),
    'bs':mip1_n60_k5['bs'].mean(),
    'gap':mip1_n60_k5['gap'].mean(),
    'time':mip1_n60_k5['time'].mean(),
    'nodes':mip1_n60_k5['nodes'].mean(),
    'opt':mip1_n60_k5['opt'].sum(),
    'lp':mip1_n60_k5['lp'].mean(),
    'glp':mip1_n60_k5['glp'].mean()
    },index=[""]
)

mip1_n60_k5 = pd.concat([mip1_n60_k5,tab])
mip1_n60_k5['instance'] = mip1_n60_k5['instance'].str.replace('data/kmbs/RANDOM/random_','')
mip1_n60_k5
# Out:
#                        instance   form method         bb         bs  gap  \
# 0    n60_k5_pos30_neg5_err5_1.g  edge1    mip  18.000000  18.000000  0.0
# 1    n60_k5_pos30_neg5_err5_2.g  edge1    mip  13.000000  13.000000  0.0
# 2    n60_k5_pos30_neg5_err5_3.g  edge1    mip  14.000000  14.000000  0.0
# 3    n60_k5_pos30_neg5_err5_4.g  edge1    mip  16.000000  16.000000  0.0
# 4    n60_k5_pos30_neg5_err5_5.g  edge1    mip  10.000000  10.000000  0.0
# 5   n60_k5_pos30_neg5_err10_1.g  edge1    mip  22.000000  22.000000  0.0
# 6   n60_k5_pos30_neg5_err10_2.g  edge1    mip  18.000000  18.000000  0.0
# 7   n60_k5_pos30_neg5_err10_3.g  edge1    mip  22.000000  22.000000  0.0
# 8   n60_k5_pos30_neg5_err10_4.g  edge1    mip  18.000000  18.000000  0.0
# 9   n60_k5_pos30_neg5_err10_5.g  edge1    mip  17.000000  17.000000  0.0
# 10  n60_k5_pos30_neg5_err20_1.g  edge1    mip  25.000000  25.000000  0.0
# 11  n60_k5_pos30_neg5_err20_2.g  edge1    mip  23.000000  23.000000  0.0
# ...

# %%
form_="edge2"
method_="lp"

k_ = 2

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

lp2_n60_k2 = pd.DataFrame()
lp2_n60_k2 = pd.concat([lp2_n60_k2, df], ignore_index=True)
lp2_n60_k2.columns = ['instance','form','method','bs','time']
#lp2_n60_k2

k_ = 3

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

lp2_n60_k3 = pd.DataFrame()
lp2_n60_k3 = pd.concat([lp2_n60_k3, df], ignore_index=True)
lp2_n60_k3.columns = ['instance','form','method','bs','time']
#lp2_n60_k3

k_ = 4

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

lp2_n60_k4 = pd.DataFrame()
lp2_n60_k4 = pd.concat([lp2_n60_k4, df], ignore_index=True)
lp2_n60_k4.columns = ['instance','form','method','bs','time']
#lp2_n60_k4

k_ = 5

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

lp2_n60_k5 = pd.DataFrame()
lp2_n60_k5 = pd.concat([lp2_n60_k5, df], ignore_index=True)
lp2_n60_k5.columns = ['instance','form','method','bs','time']
#lp2_n60_k5

# %%
form_="edge2"
method_="mip"

k_ = 2

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

mip2_n60_k2 = pd.DataFrame()
mip2_n60_k2 = pd.concat([mip2_n60_k2, df], ignore_index=True)
mip2_n60_k2.columns = ['instance','form','method','bb','bs','gap','time','nodes','opt']


k_ = 3

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

mip2_n60_k3 = pd.DataFrame()
mip2_n60_k3 = pd.concat([mip2_n60_k3, df], ignore_index=True)
mip2_n60_k3.columns = ['instance','form','method','bb','bs','gap','time','nodes','opt']


k_ = 4

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

mip2_n60_k4 = pd.DataFrame()
mip2_n60_k4 = pd.concat([mip2_n60_k4, df], ignore_index=True)
mip2_n60_k4.columns = ['instance','form','method','bb','bs','gap','time','nodes','opt']


k_ = 4

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

mip2_n60_k4 = pd.DataFrame()
mip2_n60_k4 = pd.concat([mip2_n60_k4, df], ignore_index=True)
mip2_n60_k4.columns = ['instance','form','method','bb','bs','gap','time','nodes','opt']


k_ = 5

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

mip2_n60_k5 = pd.DataFrame()
mip2_n60_k5 = pd.concat([mip2_n60_k5, df], ignore_index=True)
mip2_n60_k5.columns = ['instance','form','method','bb','bs','gap','time','nodes','opt']

# %%
mip2_n60_k2['lp'] = lp2_n60_k2['bs']
mip2_n60_k2['glp'] = (mip2_n60_k2['bs'] - lp2_n60_k2['bs'])/mip2_n60_k2['bs']
mip2_n60_k2
# Out:
#                                              instance   form method    bb  \
# 0   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge2    mip  23.0
# 1   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge2    mip  11.0
# 2   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge2    mip   9.0
# 3   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge2    mip  13.0
# 4   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge2    mip  13.0
# 5   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge2    mip  38.0
# 6   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge2    mip  24.0
# 7   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge2    mip  33.0
# 8   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge2    mip  35.0
# 9   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge2    mip  25.0
# 10  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge2    mip  61.0
# 11  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge2    mip  50.0
# ...

# %%
tab = pd.DataFrame({
    'instance':"n60_k2",
    'form':'edge2',
    'method':'mip',
    'bb':mip2_n60_k2['bb'].mean(),
    'bs':mip2_n60_k2['bs'].mean(),
    'gap':mip2_n60_k2['gap'].mean(),
    'time':mip2_n60_k2['time'].mean(),
    'nodes':mip2_n60_k2['nodes'].mean(),
    'opt':mip2_n60_k2['opt'].sum(),
    'lp':mip2_n60_k2['lp'].mean(),
    'glp':mip2_n60_k2['glp'].mean()
    },index=[""]
)

mip2_n60_k2 = pd.concat([mip2_n60_k2,tab])
mip2_n60_k2['instance'] = mip2_n60_k2['instance'].str.replace('data/kmbs/RANDOM/random_','')
mip2_n60_k2
# Out:
#                        instance   form method    bb    bs  gap         time  \
# 0    n60_k2_pos30_neg5_err5_1.g  edge2    mip  23.0  23.0  0.0     1.090167
# 1    n60_k2_pos30_neg5_err5_2.g  edge2    mip  11.0  11.0  0.0     0.325090
# 2    n60_k2_pos30_neg5_err5_3.g  edge2    mip   9.0   9.0  0.0     0.190903
# 3    n60_k2_pos30_neg5_err5_4.g  edge2    mip  13.0  13.0  0.0     0.415529
# 4    n60_k2_pos30_neg5_err5_5.g  edge2    mip  13.0  13.0  0.0     0.377725
# 5   n60_k2_pos30_neg5_err10_1.g  edge2    mip  38.0  38.0  0.0    60.212962
# 6   n60_k2_pos30_neg5_err10_2.g  edge2    mip  24.0  24.0  0.0     1.676910
# 7   n60_k2_pos30_neg5_err10_3.g  edge2    mip  33.0  33.0  0.0    10.926851
# 8   n60_k2_pos30_neg5_err10_4.g  edge2    mip  35.0  35.0  0.0    22.156795
# 9   n60_k2_pos30_neg5_err10_5.g  edge2    mip  25.0  25.0  0.0     1.523568
# 10  n60_k2_pos30_neg5_err20_1.g  edge2    mip  61.0  61.0  0.0  2816.536866
# ...

# %%
mip2_n60_k3['lp'] = lp2_n60_k3['bs']
mip2_n60_k3['glp'] = (mip2_n60_k3['bs'] - lp2_n60_k3['bs'])/mip2_n60_k3['bs']

mip2_n60_k3
# Out:
#                                              instance   form method    bb  \
# 0   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge2    mip  13.0
# 1   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge2    mip   8.0
# 2   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge2    mip  14.0
# 3   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge2    mip  14.0
# 4   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge2    mip   8.0
# 5   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge2    mip  20.0
# 6   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge2    mip  18.0
# 7   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge2    mip  21.0
# 8   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge2    mip  27.0
# 9   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge2    mip  19.0
# 10  data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err2...  edge2    mip  40.0
# 11  data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err2...  edge2    mip  33.0
# ...

# %%
tab = pd.DataFrame({
    'instance':"n60_k3",
    'form':'edge2',
    'method':'mip',
    'bb':mip2_n60_k3['bb'].mean(),
    'bs':mip2_n60_k3['bs'].mean(),
    'gap':mip2_n60_k3['gap'].mean(),
    'time':mip2_n60_k3['time'].mean(),
    'nodes':mip2_n60_k3['nodes'].mean(),
    'opt':mip2_n60_k3['opt'].sum(),
    'lp':mip2_n60_k3['lp'].mean(),
    'glp':mip2_n60_k3['glp'].mean()
    },index=[""]
)

mip2_n60_k3 = pd.concat([mip2_n60_k3,tab])
mip2_n60_k3['instance'] = mip2_n60_k3['instance'].str.replace('data/kmbs/RANDOM/random_','')
mip2_n60_k3
# Out:
#                        instance   form method         bb         bs  gap  \
# 0    n60_k3_pos30_neg5_err5_1.g  edge2    mip  13.000000  13.000000  0.0
# 1    n60_k3_pos30_neg5_err5_2.g  edge2    mip   8.000000   8.000000  0.0
# 2    n60_k3_pos30_neg5_err5_3.g  edge2    mip  14.000000  14.000000  0.0
# 3    n60_k3_pos30_neg5_err5_4.g  edge2    mip  14.000000  14.000000  0.0
# 4    n60_k3_pos30_neg5_err5_5.g  edge2    mip   8.000000   8.000000  0.0
# 5   n60_k3_pos30_neg5_err10_1.g  edge2    mip  20.000000  20.000000  0.0
# 6   n60_k3_pos30_neg5_err10_2.g  edge2    mip  18.000000  18.000000  0.0
# 7   n60_k3_pos30_neg5_err10_3.g  edge2    mip  21.000000  21.000000  0.0
# 8   n60_k3_pos30_neg5_err10_4.g  edge2    mip  27.000000  27.000000  0.0
# 9   n60_k3_pos30_neg5_err10_5.g  edge2    mip  19.000000  19.000000  0.0
# 10  n60_k3_pos30_neg5_err20_1.g  edge2    mip  40.000000  40.000000  0.0
# 11  n60_k3_pos30_neg5_err20_2.g  edge2    mip  33.000000  33.000000  0.0
# ...

# %%
mip2_n60_k4['lp'] = lp2_n60_k4['bs']
mip2_n60_k4['glp'] = (mip2_n60_k4['bs'] - lp2_n60_k4['bs'])/mip2_n60_k4['bs']

mip2_n60_k4
# Out:
#                                              instance   form method    bb  \
# 0   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge2    mip  12.0
# 1   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge2    mip  14.0
# 2   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge2    mip  13.0
# 3   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge2    mip  21.0
# 4   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge2    mip  16.0
# 5   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge2    mip  19.0
# 6   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge2    mip  19.0
# 7   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge2    mip  20.0
# 8   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge2    mip  21.0
# 9   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge2    mip  22.0
# 10  data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err2...  edge2    mip  28.0
# 11  data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err2...  edge2    mip  31.0
# ...

# %%
tab = pd.DataFrame({
    'instance':"n60_k4",
    'form':'edge2',
    'method':'mip',
    'bb':mip2_n60_k4['bb'].mean(),
    'bs':mip2_n60_k4['bs'].mean(),
    'gap':mip2_n60_k4['gap'].mean(),
    'time':mip2_n60_k4['time'].mean(),
    'nodes':mip2_n60_k4['nodes'].mean(),
    'opt':mip2_n60_k4['opt'].sum(),
    'lp':mip2_n60_k4['lp'].mean(),
    'glp':mip2_n60_k4['glp'].mean()
    },index=[""]
)

mip2_n60_k4 = pd.concat([mip2_n60_k4,tab])
mip2_n60_k4['instance'] = mip2_n60_k4['instance'].str.replace('data/kmbs/RANDOM/random_','')
mip2_n60_k4
# Out:
#                        instance   form method    bb    bs  gap        time  \
# 0    n60_k4_pos30_neg5_err5_1.g  edge2    mip  12.0  12.0  0.0    0.662144
# 1    n60_k4_pos30_neg5_err5_2.g  edge2    mip  14.0  14.0  0.0    1.870286
# 2    n60_k4_pos30_neg5_err5_3.g  edge2    mip  13.0  13.0  0.0    0.770141
# 3    n60_k4_pos30_neg5_err5_4.g  edge2    mip  21.0  21.0  0.0   16.478642
# 4    n60_k4_pos30_neg5_err5_5.g  edge2    mip  16.0  16.0  0.0    1.776805
# 5   n60_k4_pos30_neg5_err10_1.g  edge2    mip  19.0  19.0  0.0    7.156222
# 6   n60_k4_pos30_neg5_err10_2.g  edge2    mip  19.0  19.0  0.0    4.217572
# 7   n60_k4_pos30_neg5_err10_3.g  edge2    mip  20.0  20.0  0.0    9.252443
# 8   n60_k4_pos30_neg5_err10_4.g  edge2    mip  21.0  21.0  0.0    9.382301
# 9   n60_k4_pos30_neg5_err10_5.g  edge2    mip  22.0  22.0  0.0   16.463804
# 10  n60_k4_pos30_neg5_err20_1.g  edge2    mip  28.0  28.0  0.0   54.910181
# ...

# %%
mip2_n60_k5['lp'] = lp2_n60_k5['bs']
mip2_n60_k5['glp'] = (mip2_n60_k5['bs'] - lp2_n60_k2['bs'])/mip2_n60_k5['bs']

mip2_n60_k5
# Out:
#                                              instance   form method    bb  \
# 0   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge2    mip  18.0
# 1   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge2    mip  13.0
# 2   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge2    mip  14.0
# 3   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge2    mip  16.0
# 4   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge2    mip  10.0
# 5   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge2    mip  22.0
# 6   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge2    mip  18.0
# 7   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge2    mip  22.0
# 8   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge2    mip  18.0
# 9   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge2    mip  17.0
# 10  data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err2...  edge2    mip  25.0
# 11  data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err2...  edge2    mip  23.0
# ...

# %%
tab = pd.DataFrame({
    'instance':"n60_k5",
    'form':'edge2',
    'method':'mip',
    'bb':mip2_n60_k5['bb'].mean(),
    'bs':mip2_n60_k5['bs'].mean(),
    'gap':mip2_n60_k5['gap'].mean(),
    'time':mip2_n60_k5['time'].mean(),
    'nodes':mip2_n60_k5['nodes'].mean(),
    'opt':mip2_n60_k5['opt'].sum(),
    'lp':mip2_n60_k5['lp'].mean(),
    'glp':mip2_n60_k5['glp'].mean()
    },index=[""]
)

mip2_n60_k5 = pd.concat([mip2_n60_k5,tab])
mip2_n60_k5['instance'] = mip2_n60_k5['instance'].str.replace('data/kmbs/RANDOM/random_','')
mip2_n60_k5
# Out:
#                        instance   form method         bb         bs  gap  \
# 0    n60_k5_pos30_neg5_err5_1.g  edge2    mip  18.000000  18.000000  0.0
# 1    n60_k5_pos30_neg5_err5_2.g  edge2    mip  13.000000  13.000000  0.0
# 2    n60_k5_pos30_neg5_err5_3.g  edge2    mip  14.000000  14.000000  0.0
# 3    n60_k5_pos30_neg5_err5_4.g  edge2    mip  16.000000  16.000000  0.0
# 4    n60_k5_pos30_neg5_err5_5.g  edge2    mip  10.000000  10.000000  0.0
# 5   n60_k5_pos30_neg5_err10_1.g  edge2    mip  22.000000  22.000000  0.0
# 6   n60_k5_pos30_neg5_err10_2.g  edge2    mip  18.000000  18.000000  0.0
# 7   n60_k5_pos30_neg5_err10_3.g  edge2    mip  22.000000  22.000000  0.0
# 8   n60_k5_pos30_neg5_err10_4.g  edge2    mip  18.000000  18.000000  0.0
# 9   n60_k5_pos30_neg5_err10_5.g  edge2    mip  17.000000  17.000000  0.0
# 10  n60_k5_pos30_neg5_err20_1.g  edge2    mip  25.000000  25.000000  0.0
# 11  n60_k5_pos30_neg5_err20_2.g  edge2    mip  23.000000  23.000000  0.0
# ...

# %%
form_="edge3"
method_="lp"

k_ = 2

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

lp3_n60_k2 = pd.DataFrame()
lp3_n60_k2 = pd.concat([lp3_n60_k2, df], ignore_index=True)
lp3_n60_k2.columns = ['instance','form','method','bs','time']
#lp3_n60_k2

k_ = 3

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

lp3_n60_k3 = pd.DataFrame()
lp3_n60_k3 = pd.concat([lp3_n60_k3, df], ignore_index=True)
lp3_n60_k3.columns = ['instance','form','method','bs','time']
#lp3_n60_k3

k_ = 4

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

lp3_n60_k4 = pd.DataFrame()
lp3_n60_k4 = pd.concat([lp3_n60_k4, df], ignore_index=True)
lp3_n60_k4.columns = ['instance','form','method','bs','time']
#lp3_n60_k4

k_ = 5

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

lp3_n60_k5 = pd.DataFrame()
lp3_n60_k5 = pd.concat([lp3_n60_k5, df], ignore_index=True)
lp3_n60_k5.columns = ['instance','form','method','bs','time']
#lp3_n60_k5

# %%
form_="edge3"
method_="mip"

k_ = 2

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

mip3_n60_k2 = pd.DataFrame()
mip3_n60_k2 = pd.concat([mip3_n60_k2, df], ignore_index=True)
mip3_n60_k2.columns = ['instance','form','method','bb','bs','gap','time','nodes','opt']


k_ = 3

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

mip3_n60_k3 = pd.DataFrame()
mip3_n60_k3 = pd.concat([mip3_n60_k3, df], ignore_index=True)
mip3_n60_k3.columns = ['instance','form','method','bb','bs','gap','time','nodes','opt']


k_ = 4

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

mip3_n60_k4 = pd.DataFrame()
mip3_n60_k4 = pd.concat([mip3_n60_k4, df], ignore_index=True)
mip3_n60_k4.columns = ['instance','form','method','bb','bs','gap','time','nodes','opt']


k_ = 4

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

mip3_n60_k4 = pd.DataFrame()
mip3_n60_k4 = pd.concat([mip3_n60_k4, df], ignore_index=True)
mip3_n60_k4.columns = ['instance','form','method','bb','bs','gap','time','nodes','opt']


k_ = 5

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

mip3_n60_k5 = pd.DataFrame()
mip3_n60_k5 = pd.concat([mip3_n60_k5, df], ignore_index=True)
mip3_n60_k5.columns = ['instance','form','method','bb','bs','gap','time','nodes','opt']

# %%
mip3_n60_k2['lp'] = lp3_n60_k2['bs']
mip3_n60_k2['glp'] = (mip3_n60_k2['bs'] - lp3_n60_k2['bs'])/mip3_n60_k2['bs']

mip3_n60_k2
# Out:
#                                              instance   form method    bb  \
# 0   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge3    mip  23.0
# 1   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge3    mip  11.0
# 2   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge3    mip   9.0
# 3   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge3    mip  13.0
# 4   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge3    mip  13.0
# 5   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge3    mip  38.0
# 6   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge3    mip  24.0
# 7   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge3    mip  33.0
# 8   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge3    mip  35.0
# 9   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge3    mip  25.0
# 10  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge3    mip  61.0
# 11  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge3    mip  50.0
# ...

# %%
tab = pd.DataFrame({
    'instance':"n60_k2",
    'form':'edge3',
    'method':'mip',
    'bb':mip3_n60_k2['bb'].mean(),
    'bs':mip3_n60_k2['bs'].mean(),
    'gap':mip3_n60_k2['gap'].mean(),
    'time':mip3_n60_k2['time'].mean(),
    'nodes':mip3_n60_k2['nodes'].mean(),
    'opt':mip3_n60_k2['opt'].sum(),
    'lp':mip3_n60_k2['lp'].mean(),
    'glp':mip3_n60_k2['glp'].mean()
    },index=[""]
)

mip3_n60_k2 = pd.concat([mip3_n60_k2,tab])
mip3_n60_k2['instance'] = mip3_n60_k2['instance'].str.replace('data/kmbs/RANDOM/random_','')
mip3_n60_k2
# Out:
#                        instance   form method    bb    bs  gap        time  \
# 0    n60_k2_pos30_neg5_err5_1.g  edge3    mip  23.0  23.0  0.0    4.102954
# 1    n60_k2_pos30_neg5_err5_2.g  edge3    mip  11.0  11.0  0.0    1.092203
# 2    n60_k2_pos30_neg5_err5_3.g  edge3    mip   9.0   9.0  0.0    1.483435
# 3    n60_k2_pos30_neg5_err5_4.g  edge3    mip  13.0  13.0  0.0    2.177919
# 4    n60_k2_pos30_neg5_err5_5.g  edge3    mip  13.0  13.0  0.0    1.456862
# 5   n60_k2_pos30_neg5_err10_1.g  edge3    mip  38.0  38.0  0.0   11.478748
# 6   n60_k2_pos30_neg5_err10_2.g  edge3    mip  24.0  24.0  0.0    3.413629
# 7   n60_k2_pos30_neg5_err10_3.g  edge3    mip  33.0  33.0  0.0    3.633337
# 8   n60_k2_pos30_neg5_err10_4.g  edge3    mip  35.0  35.0  0.0    6.133486
# 9   n60_k2_pos30_neg5_err10_5.g  edge3    mip  25.0  25.0  0.0    3.613637
# 10  n60_k2_pos30_neg5_err20_1.g  edge3    mip  61.0  61.0  0.0  139.465575
# ...

# %%
mip3_n60_k3['lp'] = lp3_n60_k3['bs']
mip3_n60_k3['glp'] = (mip3_n60_k3['bs'] - lp3_n60_k3['bs'])/mip3_n60_k3['bs']
mip3_n60_k3
# Out:
#                                              instance   form method    bb  \
# 0   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge3    mip  13.0
# 1   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge3    mip   8.0
# 2   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge3    mip  14.0
# 3   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge3    mip  14.0
# 4   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge3    mip   8.0
# 5   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge3    mip  20.0
# 6   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge3    mip  18.0
# 7   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge3    mip  21.0
# 8   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge3    mip  27.0
# 9   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge3    mip  19.0
# 10  data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err2...  edge3    mip  40.0
# 11  data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err2...  edge3    mip  33.0
# ...

# %%
tab = pd.DataFrame({
    'instance':"n60_k3",
    'form':'edge3',
    'method':'mip',
    'bb':mip3_n60_k3['bb'].mean(),
    'bs':mip3_n60_k3['bs'].mean(),
    'gap':mip3_n60_k3['gap'].mean(),
    'time':mip3_n60_k3['time'].mean(),
    'nodes':mip3_n60_k3['nodes'].mean(),
    'opt':mip3_n60_k3['opt'].sum(),
    'lp':mip3_n60_k3['lp'].mean(),
    'glp':mip3_n60_k3['glp'].mean()
    },index=[""]
)

mip3_n60_k3 = pd.concat([mip3_n60_k3,tab])
mip3_n60_k3['instance'] = mip3_n60_k3['instance'].str.replace('data/kmbs/RANDOM/random_','')
mip3_n60_k3
# Out:
#                        instance   form method         bb         bs  gap  \
# 0    n60_k3_pos30_neg5_err5_1.g  edge3    mip  13.000000  13.000000  0.0
# 1    n60_k3_pos30_neg5_err5_2.g  edge3    mip   8.000000   8.000000  0.0
# 2    n60_k3_pos30_neg5_err5_3.g  edge3    mip  14.000000  14.000000  0.0
# 3    n60_k3_pos30_neg5_err5_4.g  edge3    mip  14.000000  14.000000  0.0
# 4    n60_k3_pos30_neg5_err5_5.g  edge3    mip   8.000000   8.000000  0.0
# 5   n60_k3_pos30_neg5_err10_1.g  edge3    mip  20.000000  20.000000  0.0
# 6   n60_k3_pos30_neg5_err10_2.g  edge3    mip  18.000000  18.000000  0.0
# 7   n60_k3_pos30_neg5_err10_3.g  edge3    mip  21.000000  21.000000  0.0
# 8   n60_k3_pos30_neg5_err10_4.g  edge3    mip  27.000000  27.000000  0.0
# 9   n60_k3_pos30_neg5_err10_5.g  edge3    mip  19.000000  19.000000  0.0
# 10  n60_k3_pos30_neg5_err20_1.g  edge3    mip  40.000000  40.000000  0.0
# 11  n60_k3_pos30_neg5_err20_2.g  edge3    mip  33.000000  33.000000  0.0
# ...

# %%
mip3_n60_k4['lp'] = lp3_n60_k4['bs']
mip3_n60_k4['glp'] = (mip3_n60_k4['bs'] - lp3_n60_k4['bs'])/mip3_n60_k4['bs']
mip3_n60_k4
# Out:
#                                              instance   form method    bb  \
# 0   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge3    mip  12.0
# 1   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge3    mip  14.0
# 2   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge3    mip  13.0
# 3   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge3    mip  21.0
# 4   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge3    mip  16.0
# 5   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge3    mip  19.0
# 6   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge3    mip  19.0
# 7   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge3    mip  20.0
# 8   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge3    mip  21.0
# 9   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge3    mip  22.0
# 10  data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err2...  edge3    mip  28.0
# 11  data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err2...  edge3    mip  31.0
# ...

# %%
tab = pd.DataFrame({
    'instance':"n60_k4",
    'form':'edge3',
    'method':'mip',
    'bb':mip3_n60_k4['bb'].mean(),
    'bs':mip3_n60_k4['bs'].mean(),
    'gap':mip3_n60_k4['gap'].mean(),
    'time':mip3_n60_k4['time'].mean(),
    'nodes':mip3_n60_k4['nodes'].mean(),
    'opt':mip3_n60_k4['opt'].sum(),
    'lp':mip3_n60_k4['lp'].mean(),
    'glp':mip3_n60_k4['glp'].mean()
    },index=[""]
)

mip3_n60_k4 = pd.concat([mip3_n60_k4,tab])
mip3_n60_k4['instance'] = mip3_n60_k4['instance'].str.replace('data/kmbs/RANDOM/random_','')
mip3_n60_k4
# Out:
#                        instance   form method    bb    bs  gap       time  \
# 0    n60_k4_pos30_neg5_err5_1.g  edge3    mip  12.0  12.0  0.0   1.800394
# 1    n60_k4_pos30_neg5_err5_2.g  edge3    mip  14.0  14.0  0.0   1.792483
# 2    n60_k4_pos30_neg5_err5_3.g  edge3    mip  13.0  13.0  0.0   1.688902
# 3    n60_k4_pos30_neg5_err5_4.g  edge3    mip  21.0  21.0  0.0   4.546354
# 4    n60_k4_pos30_neg5_err5_5.g  edge3    mip  16.0  16.0  0.0   2.143296
# 5   n60_k4_pos30_neg5_err10_1.g  edge3    mip  19.0  19.0  0.0   3.244780
# 6   n60_k4_pos30_neg5_err10_2.g  edge3    mip  19.0  19.0  0.0   3.159067
# 7   n60_k4_pos30_neg5_err10_3.g  edge3    mip  20.0  20.0  0.0   3.474291
# 8   n60_k4_pos30_neg5_err10_4.g  edge3    mip  21.0  21.0  0.0   3.739822
# 9   n60_k4_pos30_neg5_err10_5.g  edge3    mip  22.0  22.0  0.0   3.525892
# 10  n60_k4_pos30_neg5_err20_1.g  edge3    mip  28.0  28.0  0.0   7.866065
# 11  n60_k4_pos30_neg5_err20_2.g  edge3    mip  31.0  31.0  0.0  25.770507
# ...

# %%
mip3_n60_k5['lp'] = lp3_n60_k5['bs']
mip3_n60_k5['glp'] = (mip3_n60_k5['bs'] - lp3_n60_k2['bs'])/mip3_n60_k5['bs']
mip3_n60_k5
# Out:
#                                              instance   form method    bb  \
# 0   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge3    mip  18.0
# 1   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge3    mip  13.0
# 2   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge3    mip  14.0
# 3   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge3    mip  16.0
# 4   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge3    mip  10.0
# 5   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge3    mip  22.0
# 6   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge3    mip  18.0
# 7   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge3    mip  22.0
# 8   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge3    mip  18.0
# 9   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge3    mip  17.0
# 10  data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err2...  edge3    mip  25.0
# 11  data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err2...  edge3    mip  23.0
# ...

# %%
tab = pd.DataFrame({
    'instance':"n60_k5",
    'form':'edge3',
    'method':'mip',
    'bb':mip3_n60_k5['bb'].mean(),
    'bs':mip3_n60_k5['bs'].mean(),
    'gap':mip3_n60_k5['gap'].mean(),
    'time':mip3_n60_k5['time'].mean(),
    'nodes':mip3_n60_k5['nodes'].mean(),
    'opt':mip3_n60_k5['opt'].sum(),
    'lp':mip3_n60_k5['lp'].mean(),
    'glp':mip3_n60_k5['glp'].mean()
    },index=[""]
)

mip3_n60_k5 = pd.concat([mip3_n60_k5,tab])
mip3_n60_k5['instance'] = mip3_n60_k5['instance'].str.replace('data/kmbs/RANDOM/random_','')
mip3_n60_k5
# Out:
#                        instance   form method         bb         bs  gap  \
# 0    n60_k5_pos30_neg5_err5_1.g  edge3    mip  18.000000  18.000000  0.0
# 1    n60_k5_pos30_neg5_err5_2.g  edge3    mip  13.000000  13.000000  0.0
# 2    n60_k5_pos30_neg5_err5_3.g  edge3    mip  14.000000  14.000000  0.0
# 3    n60_k5_pos30_neg5_err5_4.g  edge3    mip  16.000000  16.000000  0.0
# 4    n60_k5_pos30_neg5_err5_5.g  edge3    mip  10.000000  10.000000  0.0
# 5   n60_k5_pos30_neg5_err10_1.g  edge3    mip  22.000000  22.000000  0.0
# 6   n60_k5_pos30_neg5_err10_2.g  edge3    mip  18.000000  18.000000  0.0
# 7   n60_k5_pos30_neg5_err10_3.g  edge3    mip  22.000000  22.000000  0.0
# 8   n60_k5_pos30_neg5_err10_4.g  edge3    mip  18.000000  18.000000  0.0
# 9   n60_k5_pos30_neg5_err10_5.g  edge3    mip  17.000000  17.000000  0.0
# 10  n60_k5_pos30_neg5_err20_1.g  edge3    mip  25.000000  25.000000  0.0
# 11  n60_k5_pos30_neg5_err20_2.g  edge3    mip  23.000000  23.000000  0.0
# ...

# %%
tab_mip_n60_k2 = pd.DataFrame()
tab_mip_n60_k2["instance"] = mip2_n60_k2['instance']
tab_mip_n60_k2["bs1"] = mip1_n60_k2['bs']
tab_mip_n60_k2["bs2"] = mip2_n60_k2['bs']
tab_mip_n60_k2["bs3"] = mip3_n60_k2['bs']
tab_mip_n60_k2["time1"] = mip1_n60_k2['time']
tab_mip_n60_k2["time2"] = mip2_n60_k2['time']
tab_mip_n60_k2["time3"] = mip3_n60_k2['time']
tab_mip_n60_k2["nodes1"] = mip1_n60_k2['nodes']
tab_mip_n60_k2["nodes2"] = mip2_n60_k2['nodes']
tab_mip_n60_k2["nodes3"] = mip3_n60_k2['nodes']

tab_mip_n60_k2
# Out:
#                        instance   bs1   bs2   bs3      time1        time2  \
# 0    n60_k2_pos30_neg5_err5_1.g  23.0  23.0  23.0   1.053463     1.090167
# 1    n60_k2_pos30_neg5_err5_2.g  11.0  11.0  11.0   0.208470     0.325090
# 2    n60_k2_pos30_neg5_err5_3.g   9.0   9.0   9.0   0.136495     0.190903
# 3    n60_k2_pos30_neg5_err5_4.g  13.0  13.0  13.0   0.243686     0.415529
# 4    n60_k2_pos30_neg5_err5_5.g  13.0  13.0  13.0   0.211492     0.377725
# 5   n60_k2_pos30_neg5_err10_1.g  38.0  38.0  38.0   2.883166    60.212962
# 6   n60_k2_pos30_neg5_err10_2.g  24.0  24.0  24.0   0.947396     1.676910
# 7   n60_k2_pos30_neg5_err10_3.g  33.0  33.0  33.0   2.016801    10.926851
# 8   n60_k2_pos30_neg5_err10_4.g  35.0  35.0  35.0   2.196478    22.156795
# 9   n60_k2_pos30_neg5_err10_5.g  25.0  25.0  25.0   0.953856     1.523568
# 10  n60_k2_pos30_neg5_err20_1.g  61.0  61.0  61.0  22.975967  2816.536866
# 11  n60_k2_pos30_neg5_err20_2.g  50.0  50.0  50.0   6.780756   190.480004
# ...

# %%
tab_mip_n60_k3 = pd.DataFrame()
tab_mip_n60_k3["instance"] = mip2_n60_k3['instance']
tab_mip_n60_k3["bs1"] = mip1_n60_k3['bs']
tab_mip_n60_k3["bs2"] = mip2_n60_k3['bs']
tab_mip_n60_k3["bs3"] = mip3_n60_k3['bs']
tab_mip_n60_k3["time1"] = mip1_n60_k3['time']
tab_mip_n60_k3["time2"] = mip2_n60_k3['time']
tab_mip_n60_k3["time3"] = mip3_n60_k3['time']
tab_mip_n60_k3["nodes1"] = mip1_n60_k3['nodes']
tab_mip_n60_k3["nodes2"] = mip2_n60_k3['nodes']
tab_mip_n60_k3["nodes3"] = mip3_n60_k3['nodes']

tab_mip_n60_k3
# Out:
#                        instance        bs1        bs2        bs3      time1  \
# 0    n60_k3_pos30_neg5_err5_1.g  13.000000  13.000000  13.000000   0.843392
# 1    n60_k3_pos30_neg5_err5_2.g   8.000000   8.000000   8.000000   0.334350
# 2    n60_k3_pos30_neg5_err5_3.g  14.000000  14.000000  14.000000   0.842058
# 3    n60_k3_pos30_neg5_err5_4.g  14.000000  14.000000  14.000000   0.864538
# 4    n60_k3_pos30_neg5_err5_5.g   8.000000   8.000000   8.000000   0.096334
# 5   n60_k3_pos30_neg5_err10_1.g  20.000000  20.000000  20.000000   1.203071
# 6   n60_k3_pos30_neg5_err10_2.g  18.000000  18.000000  18.000000   1.310839
# 7   n60_k3_pos30_neg5_err10_3.g  21.000000  21.000000  21.000000   1.336672
# 8   n60_k3_pos30_neg5_err10_4.g  27.000000  27.000000  27.000000   2.422936
# 9   n60_k3_pos30_neg5_err10_5.g  19.000000  19.000000  19.000000   1.761886
# 10  n60_k3_pos30_neg5_err20_1.g  40.000000  40.000000  40.000000   8.277011
# ...

# %%
tab_mip_n60_k4 = pd.DataFrame()
tab_mip_n60_k4["instance"] = mip2_n60_k4['instance']
tab_mip_n60_k4["bs1"] = mip1_n60_k4['bs']
tab_mip_n60_k4["bs2"] = mip2_n60_k4['bs']
tab_mip_n60_k4["bs3"] = mip3_n60_k4['bs']
tab_mip_n60_k4["time1"] = mip1_n60_k4['time']
tab_mip_n60_k4["time2"] = mip2_n60_k4['time']
tab_mip_n60_k4["time3"] = mip3_n60_k4['time']
tab_mip_n60_k4["nodes1"] = mip1_n60_k4['nodes']
tab_mip_n60_k4["nodes2"] = mip2_n60_k4['nodes']
tab_mip_n60_k4["nodes3"] = mip3_n60_k4['nodes']

tab_mip_n60_k4
# Out:
#                        instance   bs1   bs2   bs3     time1       time2  \
# 0    n60_k4_pos30_neg5_err5_1.g  12.0  12.0  12.0  0.654223    0.662144
# 1    n60_k4_pos30_neg5_err5_2.g  14.0  14.0  14.0  0.815058    1.870286
# 2    n60_k4_pos30_neg5_err5_3.g  13.0  13.0  13.0  0.517862    0.770141
# 3    n60_k4_pos30_neg5_err5_4.g  21.0  21.0  21.0  2.712034   16.478642
# 4    n60_k4_pos30_neg5_err5_5.g  16.0  16.0  16.0  1.002247    1.776805
# 5   n60_k4_pos30_neg5_err10_1.g  19.0  19.0  19.0  1.635012    7.156222
# 6   n60_k4_pos30_neg5_err10_2.g  19.0  19.0  19.0  1.237598    4.217572
# 7   n60_k4_pos30_neg5_err10_3.g  20.0  20.0  20.0  1.865367    9.252443
# 8   n60_k4_pos30_neg5_err10_4.g  21.0  21.0  21.0  1.936154    9.382301
# 9   n60_k4_pos30_neg5_err10_5.g  22.0  22.0  22.0  1.689434   16.463804
# 10  n60_k4_pos30_neg5_err20_1.g  28.0  28.0  28.0  4.301458   54.910181
# 11  n60_k4_pos30_neg5_err20_2.g  31.0  31.0  31.0  5.915757   53.304259
# ...

# %%
tab_mip_n60_k5 = pd.DataFrame()
tab_mip_n60_k5["instance"] = mip2_n60_k5['instance']
tab_mip_n60_k5["bs1"] = mip1_n60_k5['bs']
tab_mip_n60_k5["bs2"] = mip2_n60_k5['bs']
tab_mip_n60_k5["bs3"] = mip3_n60_k5['bs']
tab_mip_n60_k5["time1"] = mip1_n60_k5['time']
tab_mip_n60_k5["time2"] = mip2_n60_k5['time']
tab_mip_n60_k5["time3"] = mip3_n60_k5['time']
tab_mip_n60_k5["nodes1"] = mip1_n60_k5['nodes']
tab_mip_n60_k5["nodes2"] = mip2_n60_k5['nodes']
tab_mip_n60_k5["nodes3"] = mip3_n60_k5['nodes']

tab_mip_n60_k5
# Out:
#                        instance        bs1        bs2        bs3     time1  \
# 0    n60_k5_pos30_neg5_err5_1.g  18.000000  18.000000  18.000000  1.626230
# 1    n60_k5_pos30_neg5_err5_2.g  13.000000  13.000000  13.000000  0.701172
# 2    n60_k5_pos30_neg5_err5_3.g  14.000000  14.000000  14.000000  0.777528
# 3    n60_k5_pos30_neg5_err5_4.g  16.000000  16.000000  16.000000  1.340440
# 4    n60_k5_pos30_neg5_err5_5.g  10.000000  10.000000  10.000000  0.642152
# 5   n60_k5_pos30_neg5_err10_1.g  22.000000  22.000000  22.000000  2.349576
# 6   n60_k5_pos30_neg5_err10_2.g  18.000000  18.000000  18.000000  1.724390
# 7   n60_k5_pos30_neg5_err10_3.g  22.000000  22.000000  22.000000  2.249855
# 8   n60_k5_pos30_neg5_err10_4.g  18.000000  18.000000  18.000000  1.729536
# 9   n60_k5_pos30_neg5_err10_5.g  17.000000  17.000000  17.000000  1.287910
# 10  n60_k5_pos30_neg5_err20_1.g  25.000000  25.000000  25.000000  2.716056
# ...

# %%
with pd.ExcelWriter('con1_equal1_edge_signed_con1_yreal.xlsx') as writer:  
    mip1_n60_k2.to_excel(writer, sheet_name='edge1_n60_k2', index=False)
    mip1_n60_k3.to_excel(writer, sheet_name='edge1_n60_k3', index=False)
    mip1_n60_k4.to_excel(writer, sheet_name='edge1_n60_k4', index=False)
    mip1_n60_k5.to_excel(writer, sheet_name='edge1_n60_k5', index=False)
    mip2_n60_k2.to_excel(writer, sheet_name='edge2_n60_k2', index=False)
    mip2_n60_k3.to_excel(writer, sheet_name='edge2_n60_k3', index=False)
    mip2_n60_k4.to_excel(writer, sheet_name='edge2_n60_k4', index=False)
    mip2_n60_k5.to_excel(writer, sheet_name='edge2_n60_k5', index=False)
    mip3_n60_k2.to_excel(writer, sheet_name='edge3_n60_k2', index=False)
    mip3_n60_k3.to_excel(writer, sheet_name='edge3_n60_k3', index=False)
    mip3_n60_k4.to_excel(writer, sheet_name='edge3_n60_k4', index=False)
    mip3_n60_k5.to_excel(writer, sheet_name='edge3_n60_k5', index=False)
    tab_mip_n60_k2.to_excel(writer, sheet_name='tab_mip_n60_k2', index=False)
    tab_mip_n60_k3.to_excel(writer, sheet_name='tab_mip_n60_k3', index=False)
    tab_mip_n60_k4.to_excel(writer, sheet_name='tab_mip_n60_k4', index=False)
    tab_mip_n60_k5.to_excel(writer, sheet_name='tab_mip_n60_k5', index=False)

# %%
mip1_n60_k2['instance'] = mip1_n60_k2['instance'].str.replace('_','\_') 
print(mip1_n60_k2[['instance','form','bs','gap','time','nodes','opt','lp','glp']].to_latex(index=False,float_format="%.2f"))
# Out:
# \begin{tabular}{llrrrrrrr}
# \toprule
# instance & form & bs & gap & time & nodes & opt & lp & glp \\
# \midrule
# n60\_k2\_pos30\_neg5\_err5\_1.g & edge1 & 23.00 & 0.00 & 1.05 & 9.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err5\_2.g & edge1 & 11.00 & 0.00 & 0.21 & 0.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err5\_3.g & edge1 & 9.00 & 0.00 & 0.14 & 0.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err5\_4.g & edge1 & 13.00 & 0.00 & 0.24 & 0.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err5\_5.g & edge1 & 13.00 & 0.00 & 0.21 & 3.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err10\_1.g & edge1 & 38.00 & 0.00 & 2.88 & 63.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err10\_2.g & edge1 & 24.00 & 0.00 & 0.95 & 11.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err10\_3.g & edge1 & 33.00 & 0.00 & 2.02 & 27.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err10\_4.g & edge1 & 35.00 & 0.00 & 2.20 & 15.00 & 1 & 0.00 & 1.00 \\
# ...

# %%
mip1_n60_k3['instance'] = mip1_n60_k3['instance'].str.replace('_','\_')
print(mip1_n60_k3[['instance','form','bs','gap','time','nodes','opt','lp','glp']].to_latex(index=False,float_format="%.2f"))
# Out:
# \begin{tabular}{llrrrrrrr}
# \toprule
# instance & form & bs & gap & time & nodes & opt & lp & glp \\
# \midrule
# n60\_k3\_pos30\_neg5\_err5\_1.g & edge1 & 13.00 & 0.00 & 0.84 & 8.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err5\_2.g & edge1 & 8.00 & 0.00 & 0.33 & 0.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err5\_3.g & edge1 & 14.00 & 0.00 & 0.84 & 7.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err5\_4.g & edge1 & 14.00 & 0.00 & 0.86 & 11.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err5\_5.g & edge1 & 8.00 & 0.00 & 0.10 & 0.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err10\_1.g & edge1 & 20.00 & 0.00 & 1.20 & 11.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err10\_2.g & edge1 & 18.00 & 0.00 & 1.31 & 11.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err10\_3.g & edge1 & 21.00 & 0.00 & 1.34 & 31.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err10\_4.g & edge1 & 27.00 & 0.00 & 2.42 & 68.00 & 1 & 0.00 & 1.00 \\
# ...

# %%
mip1_n60_k4['instance'] = mip1_n60_k4['instance'].str.replace('_','\_') 
print(mip1_n60_k4[['instance','form','bs','gap','time','nodes','opt','lp','glp']].to_latex(index=False,float_format="%.2f"))
# Out:
# \begin{tabular}{llrrrrrrr}
# \toprule
# instance & form & bs & gap & time & nodes & opt & lp & glp \\
# \midrule
# n60\_k4\_pos30\_neg5\_err5\_1.g & edge1 & 12.00 & 0.00 & 0.65 & 19.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err5\_2.g & edge1 & 14.00 & 0.00 & 0.82 & 25.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err5\_3.g & edge1 & 13.00 & 0.00 & 0.52 & 11.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err5\_4.g & edge1 & 21.00 & 0.00 & 2.71 & 179.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err5\_5.g & edge1 & 16.00 & 0.00 & 1.00 & 22.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err10\_1.g & edge1 & 19.00 & 0.00 & 1.64 & 72.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err10\_2.g & edge1 & 19.00 & 0.00 & 1.24 & 97.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err10\_3.g & edge1 & 20.00 & 0.00 & 1.87 & 77.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err10\_4.g & edge1 & 21.00 & 0.00 & 1.94 & 67.00 & 1 & 0.00 & 1.00 \\
# ...

# %%
mip1_n60_k5['instance'] = mip1_n60_k5['instance'].str.replace('_','\_') 
print(mip1_n60_k5[['instance','form','bs','gap','time','nodes','opt','lp','glp']].to_latex(index=False,float_format="%.2f"))
# Out:
# \begin{tabular}{llrrrrrrr}
# \toprule
# instance & form & bs & gap & time & nodes & opt & lp & glp \\
# \midrule
# n60\_k5\_pos30\_neg5\_err5\_1.g & edge1 & 18.00 & 0.00 & 1.63 & 201.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err5\_2.g & edge1 & 13.00 & 0.00 & 0.70 & 104.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err5\_3.g & edge1 & 14.00 & 0.00 & 0.78 & 37.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err5\_4.g & edge1 & 16.00 & 0.00 & 1.34 & 164.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err5\_5.g & edge1 & 10.00 & 0.00 & 0.64 & 15.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err10\_1.g & edge1 & 22.00 & 0.00 & 2.35 & 325.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err10\_2.g & edge1 & 18.00 & 0.00 & 1.72 & 134.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err10\_3.g & edge1 & 22.00 & 0.00 & 2.25 & 358.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err10\_4.g & edge1 & 18.00 & 0.00 & 1.73 & 215.00 & 1 & 0.00 & 1.00 \\
# ...

# %%
mip2_n60_k2['instance'] = mip2_n60_k2['instance'].str.replace('_','\_') 
print(mip2_n60_k2[['instance','form','bs','gap','time','nodes','opt','lp','glp']].to_latex(index=False,float_format="%.2f"))
# Out:
# \begin{tabular}{llrrrrrrr}
# \toprule
# instance & form & bs & gap & time & nodes & opt & lp & glp \\
# \midrule
# n60\_k2\_pos30\_neg5\_err5\_1.g & edge2 & 23.00 & 0.00 & 1.09 & 711.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err5\_2.g & edge2 & 11.00 & 0.00 & 0.33 & 79.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err5\_3.g & edge2 & 9.00 & 0.00 & 0.19 & 21.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err5\_4.g & edge2 & 13.00 & 0.00 & 0.42 & 148.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err5\_5.g & edge2 & 13.00 & 0.00 & 0.38 & 159.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err10\_1.g & edge2 & 38.00 & 0.00 & 60.21 & 26639.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err10\_2.g & edge2 & 24.00 & 0.00 & 1.68 & 1036.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err10\_3.g & edge2 & 33.00 & 0.00 & 10.93 & 5242.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err10\_4.g & edge2 & 35.00 & 0.00 & 22.16 & 6752.00 & 1 & 0.00 & 1.00 \\
# ...

# %%
mip2_n60_k3['instance'] = mip2_n60_k3['instance'].str.replace('_','\_') 
print(mip2_n60_k3[['instance','form','bs','gap','time','nodes','opt','lp','glp']].to_latex(index=False,float_format="%.2f"))
# Out:
# \begin{tabular}{llrrrrrrr}
# \toprule
# instance & form & bs & gap & time & nodes & opt & lp & glp \\
# \midrule
# n60\_k3\_pos30\_neg5\_err5\_1.g & edge2 & 13.00 & 0.00 & 0.59 & 379.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err5\_2.g & edge2 & 8.00 & 0.00 & 0.32 & 150.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err5\_3.g & edge2 & 14.00 & 0.00 & 0.61 & 454.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err5\_4.g & edge2 & 14.00 & 0.00 & 1.49 & 1381.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err5\_5.g & edge2 & 8.00 & 0.00 & 0.12 & 37.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err10\_1.g & edge2 & 20.00 & 0.00 & 1.58 & 2126.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err10\_2.g & edge2 & 18.00 & 0.00 & 1.26 & 1782.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err10\_3.g & edge2 & 21.00 & 0.00 & 8.15 & 746.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err10\_4.g & edge2 & 27.00 & 0.00 & 52.17 & 35315.00 & 1 & 0.00 & 1.00 \\
# ...

# %%
mip2_n60_k4['instance'] = mip2_n60_k4['instance'].str.replace('_','\_') 
print(mip2_n60_k4[['instance','form','bs','gap','time','nodes','opt','lp','glp']].to_latex(index=False,float_format="%.2f"))
# Out:
# \begin{tabular}{llrrrrrrr}
# \toprule
# instance & form & bs & gap & time & nodes & opt & lp & glp \\
# \midrule
# n60\_k4\_pos30\_neg5\_err5\_1.g & edge2 & 12.00 & 0.00 & 0.66 & 770.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err5\_2.g & edge2 & 14.00 & 0.00 & 1.87 & 2557.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err5\_3.g & edge2 & 13.00 & 0.00 & 0.77 & 839.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err5\_4.g & edge2 & 21.00 & 0.00 & 16.48 & 10423.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err5\_5.g & edge2 & 16.00 & 0.00 & 1.78 & 3010.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err10\_1.g & edge2 & 19.00 & 0.00 & 7.16 & 7064.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err10\_2.g & edge2 & 19.00 & 0.00 & 4.22 & 2437.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err10\_3.g & edge2 & 20.00 & 0.00 & 9.25 & 8559.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err10\_4.g & edge2 & 21.00 & 0.00 & 9.38 & 2501.00 & 1 & 0.00 & 1.00 \\
# ...

# %%
mip2_n60_k5['instance'] = mip2_n60_k5['instance'].str.replace('_','\_') 
print(mip2_n60_k5[['instance','form','bs','gap','time','nodes','opt','lp','glp']].to_latex(index=False,float_format="%.2f"))
# Out:
# \begin{tabular}{llrrrrrrr}
# \toprule
# instance & form & bs & gap & time & nodes & opt & lp & glp \\
# \midrule
# n60\_k5\_pos30\_neg5\_err5\_1.g & edge2 & 18.00 & 0.00 & 7.06 & 6074.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err5\_2.g & edge2 & 13.00 & 0.00 & 4.53 & 3697.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err5\_3.g & edge2 & 14.00 & 0.00 & 1.16 & 2097.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err5\_4.g & edge2 & 16.00 & 0.00 & 4.06 & 2495.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err5\_5.g & edge2 & 10.00 & 0.00 & 1.04 & 1586.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err10\_1.g & edge2 & 22.00 & 0.00 & 20.71 & 6823.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err10\_2.g & edge2 & 18.00 & 0.00 & 5.92 & 3192.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err10\_3.g & edge2 & 22.00 & 0.00 & 7.68 & 2139.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err10\_4.g & edge2 & 18.00 & 0.00 & 19.89 & 16693.00 & 1 & 0.00 & 1.00 \\
# ...

# %%
mip3_n60_k2['instance'] = mip3_n60_k2['instance'].str.replace('_','\_') 
print(mip3_n60_k2[['instance','form','bs','gap','time','nodes','opt','lp','glp']].to_latex(index=False,float_format="%.2f"))
# Out:
# \begin{tabular}{llrrrrrrr}
# \toprule
# instance & form & bs & gap & time & nodes & opt & lp & glp \\
# \midrule
# n60\_k2\_pos30\_neg5\_err5\_1.g & edge3 & 23.00 & 0.00 & 4.10 & 39.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err5\_2.g & edge3 & 11.00 & 0.00 & 1.09 & 15.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err5\_3.g & edge3 & 9.00 & 0.00 & 1.48 & 7.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err5\_4.g & edge3 & 13.00 & 0.00 & 2.18 & 17.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err5\_5.g & edge3 & 13.00 & 0.00 & 1.46 & 13.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err10\_1.g & edge3 & 38.00 & 0.00 & 11.48 & 309.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err10\_2.g & edge3 & 24.00 & 0.00 & 3.41 & 37.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err10\_3.g & edge3 & 33.00 & 0.00 & 3.63 & 73.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err10\_4.g & edge3 & 35.00 & 0.00 & 6.13 & 131.00 & 1 & 0.00 & 1.00 \\
# ...

# %%
mip3_n60_k3['instance'] = mip3_n60_k3['instance'].str.replace('_','\_') 
print(mip3_n60_k3[['instance','form','bs','gap','time','nodes','opt','lp','glp']].to_latex(index=False,float_format="%.2f"))
# Out:
# \begin{tabular}{llrrrrrrr}
# \toprule
# instance & form & bs & gap & time & nodes & opt & lp & glp \\
# \midrule
# n60\_k3\_pos30\_neg5\_err5\_1.g & edge3 & 13.00 & 0.00 & 1.91 & 27.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err5\_2.g & edge3 & 8.00 & 0.00 & 1.26 & 11.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err5\_3.g & edge3 & 14.00 & 0.00 & 1.67 & 45.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err5\_4.g & edge3 & 14.00 & 0.00 & 2.17 & 17.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err5\_5.g & edge3 & 8.00 & 0.00 & 1.26 & 0.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err10\_1.g & edge3 & 20.00 & 0.00 & 3.82 & 55.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err10\_2.g & edge3 & 18.00 & 0.00 & 2.85 & 31.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err10\_3.g & edge3 & 21.00 & 0.00 & 4.10 & 157.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err10\_4.g & edge3 & 27.00 & 0.00 & 5.07 & 252.00 & 1 & 0.00 & 1.00 \\
# ...

# %%
mip3_n60_k4['instance'] = mip3_n60_k4['instance'].str.replace('_','\_') 
print(mip3_n60_k4[['instance','form','bs','gap','time','nodes','opt','lp','glp']].to_latex(index=False,float_format="%.2f"))
# Out:
# \begin{tabular}{llrrrrrrr}
# \toprule
# instance & form & bs & gap & time & nodes & opt & lp & glp \\
# \midrule
# n60\_k4\_pos30\_neg5\_err5\_1.g & edge3 & 12.00 & 0.00 & 1.80 & 49.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err5\_2.g & edge3 & 14.00 & 0.00 & 1.79 & 170.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err5\_3.g & edge3 & 13.00 & 0.00 & 1.69 & 51.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err5\_4.g & edge3 & 21.00 & 0.00 & 4.55 & 249.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err5\_5.g & edge3 & 16.00 & 0.00 & 2.14 & 144.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err10\_1.g & edge3 & 19.00 & 0.00 & 3.24 & 228.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err10\_2.g & edge3 & 19.00 & 0.00 & 3.16 & 397.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err10\_3.g & edge3 & 20.00 & 0.00 & 3.47 & 225.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err10\_4.g & edge3 & 21.00 & 0.00 & 3.74 & 360.00 & 1 & 0.00 & 1.00 \\
# ...

# %%
mip3_n60_k5['instance'] = mip3_n60_k5['instance'].str.replace('_','\_') 
print(mip3_n60_k5[['instance','form','bs','gap','time','nodes','opt','lp','glp']].to_latex(index=False,float_format="%.2f"))
# Out:
# \begin{tabular}{llrrrrrrr}
# \toprule
# instance & form & bs & gap & time & nodes & opt & lp & glp \\
# \midrule
# n60\_k5\_pos30\_neg5\_err5\_1.g & edge3 & 18.00 & 0.00 & 3.09 & 635.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err5\_2.g & edge3 & 13.00 & 0.00 & 1.81 & 267.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err5\_3.g & edge3 & 14.00 & 0.00 & 2.73 & 239.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err5\_4.g & edge3 & 16.00 & 0.00 & 3.20 & 465.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err5\_5.g & edge3 & 10.00 & 0.00 & 1.16 & 66.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err10\_1.g & edge3 & 22.00 & 0.00 & 6.15 & 1547.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err10\_2.g & edge3 & 18.00 & 0.00 & 2.52 & 423.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err10\_3.g & edge3 & 22.00 & 0.00 & 6.48 & 1450.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err10\_4.g & edge3 & 18.00 & 0.00 & 2.89 & 424.00 & 1 & 0.00 & 1.00 \\
# ...

# %%
#print(tab_mip_n60_k2[['instance','bs1','bs2','bs3','time1','time2','time3','nodes1','nodes2','nodes3']].to_latex(index=False,float_format="%.2f"))
print(tab_mip_n60_k2[['instance','time1','time2','time3','nodes1','nodes2','nodes3']].to_latex(index=False,float_format="%.2f"))
# Out:
# \begin{tabular}{lrrrrrr}
# \toprule
# instance & time1 & time2 & time3 & nodes1 & nodes2 & nodes3 \\
# \midrule
# n60_k2_pos30_neg5_err5_1.g & 1.05 & 1.09 & 4.10 & 9.00 & 711.00 & 39.00 \\
# n60_k2_pos30_neg5_err5_2.g & 0.21 & 0.33 & 1.09 & 0.00 & 79.00 & 15.00 \\
# n60_k2_pos30_neg5_err5_3.g & 0.14 & 0.19 & 1.48 & 0.00 & 21.00 & 7.00 \\
# n60_k2_pos30_neg5_err5_4.g & 0.24 & 0.42 & 2.18 & 0.00 & 148.00 & 17.00 \\
# n60_k2_pos30_neg5_err5_5.g & 0.21 & 0.38 & 1.46 & 3.00 & 159.00 & 13.00 \\
# n60_k2_pos30_neg5_err10_1.g & 2.88 & 60.21 & 11.48 & 63.00 & 26639.00 & 309.00 \\
# n60_k2_pos30_neg5_err10_2.g & 0.95 & 1.68 & 3.41 & 11.00 & 1036.00 & 37.00 \\
# n60_k2_pos30_neg5_err10_3.g & 2.02 & 10.93 & 3.63 & 27.00 & 5242.00 & 73.00 \\
# n60_k2_pos30_neg5_err10_4.g & 2.20 & 22.16 & 6.13 & 15.00 & 6752.00 & 131.00 \\
# n60_k2_pos30_neg5_err10_5.g & 0.95 & 1.52 & 3.61 & 9.00 & 1391.00 & 55.00 \\
# n60_k2_pos30_neg5_err20_1.g & 22.98 & 2816.54 & 139.47 & 2766.00 & 880106.00 & 9752.00 \\
# ...

# %%
#print(tab_mip_n60_k3[['instance','bs1','bs2','bs3','time1','time2','time3','nodes1','nodes2','nodes3']].to_latex(index=False,float_format="%.2f"))
print(tab_mip_n60_k3[['instance','time1','time2','time3','nodes1','nodes2','nodes3']].to_latex(index=False,float_format="%.2f"))
# Out:
# \begin{tabular}{lrrrrrr}
# \toprule
# instance & time1 & time2 & time3 & nodes1 & nodes2 & nodes3 \\
# \midrule
# n60_k3_pos30_neg5_err5_1.g & 0.84 & 0.59 & 1.91 & 8.00 & 379.00 & 27.00 \\
# n60_k3_pos30_neg5_err5_2.g & 0.33 & 0.32 & 1.26 & 0.00 & 150.00 & 11.00 \\
# n60_k3_pos30_neg5_err5_3.g & 0.84 & 0.61 & 1.67 & 7.00 & 454.00 & 45.00 \\
# n60_k3_pos30_neg5_err5_4.g & 0.86 & 1.49 & 2.17 & 11.00 & 1381.00 & 17.00 \\
# n60_k3_pos30_neg5_err5_5.g & 0.10 & 0.12 & 1.26 & 0.00 & 37.00 & 0.00 \\
# n60_k3_pos30_neg5_err10_1.g & 1.20 & 1.58 & 3.82 & 11.00 & 2126.00 & 55.00 \\
# n60_k3_pos30_neg5_err10_2.g & 1.31 & 1.26 & 2.85 & 11.00 & 1782.00 & 31.00 \\
# n60_k3_pos30_neg5_err10_3.g & 1.34 & 8.15 & 4.10 & 31.00 & 746.00 & 157.00 \\
# n60_k3_pos30_neg5_err10_4.g & 2.42 & 52.17 & 5.07 & 68.00 & 35315.00 & 252.00 \\
# n60_k3_pos30_neg5_err10_5.g & 1.76 & 1.32 & 3.74 & 13.00 & 2240.00 & 79.00 \\
# n60_k3_pos30_neg5_err20_1.g & 8.28 & 101.54 & 20.63 & 1190.00 & 29899.00 & 2993.00 \\
# ...

# %%
#print(tab_mip_n60_k4[['instance','bs1','bs2','bs3','time1','time2','time3','nodes1','nodes2','nodes3']].to_latex(index=False,float_format="%.2f"))
print(tab_mip_n60_k4[['instance','time1','time2','time3','nodes1','nodes2','nodes3']].to_latex(index=False,float_format="%.2f"))
# Out:
# \begin{tabular}{lrrrrrr}
# \toprule
# instance & time1 & time2 & time3 & nodes1 & nodes2 & nodes3 \\
# \midrule
# n60_k4_pos30_neg5_err5_1.g & 0.65 & 0.66 & 1.80 & 19.00 & 770.00 & 49.00 \\
# n60_k4_pos30_neg5_err5_2.g & 0.82 & 1.87 & 1.79 & 25.00 & 2557.00 & 170.00 \\
# n60_k4_pos30_neg5_err5_3.g & 0.52 & 0.77 & 1.69 & 11.00 & 839.00 & 51.00 \\
# n60_k4_pos30_neg5_err5_4.g & 2.71 & 16.48 & 4.55 & 179.00 & 10423.00 & 249.00 \\
# n60_k4_pos30_neg5_err5_5.g & 1.00 & 1.78 & 2.14 & 22.00 & 3010.00 & 144.00 \\
# n60_k4_pos30_neg5_err10_1.g & 1.64 & 7.16 & 3.24 & 72.00 & 7064.00 & 228.00 \\
# n60_k4_pos30_neg5_err10_2.g & 1.24 & 4.22 & 3.16 & 97.00 & 2437.00 & 397.00 \\
# n60_k4_pos30_neg5_err10_3.g & 1.87 & 9.25 & 3.47 & 77.00 & 8559.00 & 225.00 \\
# n60_k4_pos30_neg5_err10_4.g & 1.94 & 9.38 & 3.74 & 67.00 & 2501.00 & 360.00 \\
# n60_k4_pos30_neg5_err10_5.g & 1.69 & 16.46 & 3.53 & 97.00 & 11534.00 & 305.00 \\
# ...

# %%
#print(tab_mip_n60_k5[['instance','bs1','bs2','bs3','time1','time2','time3','nodes1','nodes2','nodes3']].to_latex(index=False,float_format="%.2f"))
print(tab_mip_n60_k5[['instance','time1','time2','time3','nodes1','nodes2','nodes3']].to_latex(index=False,float_format="%.2f"))
# Out:
# \begin{tabular}{lrrrrrr}
# \toprule
# instance & time1 & time2 & time3 & nodes1 & nodes2 & nodes3 \\
# \midrule
# n60_k5_pos30_neg5_err5_1.g & 1.63 & 7.06 & 3.09 & 201.00 & 6074.00 & 635.00 \\
# n60_k5_pos30_neg5_err5_2.g & 0.70 & 4.53 & 1.81 & 104.00 & 3697.00 & 267.00 \\
# n60_k5_pos30_neg5_err5_3.g & 0.78 & 1.16 & 2.73 & 37.00 & 2097.00 & 239.00 \\
# n60_k5_pos30_neg5_err5_4.g & 1.34 & 4.06 & 3.20 & 164.00 & 2495.00 & 465.00 \\
# n60_k5_pos30_neg5_err5_5.g & 0.64 & 1.04 & 1.16 & 15.00 & 1586.00 & 66.00 \\
# n60_k5_pos30_neg5_err10_1.g & 2.35 & 20.71 & 6.15 & 325.00 & 6823.00 & 1547.00 \\
# n60_k5_pos30_neg5_err10_2.g & 1.72 & 5.92 & 2.52 & 134.00 & 3192.00 & 423.00 \\
# n60_k5_pos30_neg5_err10_3.g & 2.25 & 7.68 & 6.48 & 358.00 & 2139.00 & 1450.00 \\
# n60_k5_pos30_neg5_err10_4.g & 1.73 & 19.89 & 2.89 & 215.00 & 16693.00 & 424.00 \\
# n60_k5_pos30_neg5_err10_5.g & 1.29 & 3.50 & 1.66 & 51.00 & 2446.00 & 201.00 \\
# ...
