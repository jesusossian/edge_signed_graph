# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pdfkit as pdf

# %%
prob_ = "signed_graphs"
n_ = 60
form_ = "edge1"
method_ = "lp"

# %%
k_ = 2

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

lp_n60_k2 = pd.DataFrame()
lp_n60_k2 = pd.concat([lp_n60_k2, df], ignore_index=True)
lp_n60_k2.columns = ['instance','form','method','bs','time']
lp_n60_k2
# Out:
#                                              instance   form method   bs  \
# 0   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge1     lp  0.0
# 1   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge1     lp  0.0
# 2   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge1     lp  0.0
# 3   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge1     lp  0.0
# 4   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge1     lp  0.0
# 5   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge1     lp  0.0
# 6   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge1     lp  0.0
# 7   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge1     lp  0.0
# 8   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge1     lp  0.0
# 9   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge1     lp  0.0
# 10  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge1     lp  0.0
# 11  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge1     lp  0.0
# ...

# %%
k_ = 3

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

lp_n60_k3 = pd.DataFrame()
lp_n60_k3 = pd.concat([lp_n60_k3, df], ignore_index=True)
lp_n60_k3.columns = ['instance','form','method','bs','time']
lp_n60_k3
# Out:
#                                              instance   form method   bs  \
# 0   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge1     lp  0.0
# 1   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge1     lp  0.0
# 2   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge1     lp  0.0
# 3   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge1     lp  0.0
# 4   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge1     lp  0.0
# 5   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge1     lp  0.0
# 6   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge1     lp  0.0
# 7   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge1     lp  0.0
# 8   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge1     lp  0.0
# 9   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge1     lp  0.0
# 10  data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err2...  edge1     lp  0.0
# 11  data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err2...  edge1     lp  0.0
# ...

# %%
k_ = 4

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

lp_n60_k4 = pd.DataFrame()
lp_n60_k4 = pd.concat([lp_n60_k4, df], ignore_index=True)
lp_n60_k4.columns = ['instance','form','method','bs','time']
lp_n60_k4
# Out:
#                                              instance   form method   bs  \
# 0   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge1     lp  0.0
# 1   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge1     lp  0.0
# 2   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge1     lp  0.0
# 3   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge1     lp  0.0
# 4   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge1     lp  0.0
# 5   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge1     lp  0.0
# 6   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge1     lp  0.0
# 7   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge1     lp  0.0
# 8   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge1     lp  0.0
# 9   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge1     lp  0.0
# 10  data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err2...  edge1     lp  0.0
# 11  data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err2...  edge1     lp  0.0
# ...

# %%
k_ = 5

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

lp_n60_k5 = pd.DataFrame()
lp_n60_k5 = pd.concat([lp_n60_k5, df], ignore_index=True)
lp_n60_k5.columns = ['instance','form','method','bs','time']
lp_n60_k5
# Out:
#                                              instance   form method   bs  \
# 0   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge1     lp  0.0
# 1   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge1     lp  0.0
# 2   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge1     lp  0.0
# 3   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge1     lp  0.0
# 4   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge1     lp  0.0
# 5   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge1     lp  0.0
# 6   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge1     lp  0.0
# 7   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge1     lp  0.0
# 8   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge1     lp  0.0
# 9   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge1     lp  0.0
# 10  data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err2...  edge1     lp  0.0
# 11  data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err2...  edge1     lp  0.0
# ...

# %%
method_ = "mip"
k_ = 2
form_ = "edge1"

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

mip_n60_k2 = pd.DataFrame()
mip_n60_k2 = pd.concat([mip_n60_k2, df], ignore_index=True)
mip_n60_k2.columns = ['instance','form','method','bb','bs','gap','time','nodes','opt']

mip_n60_k2
# Out:
#                                              instance   form method    bb  \
# 0   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge1    mip  23.0
# 1   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge1    mip  11.0
# 2   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge1    mip   9.0
# 3   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge1    mip  13.0
# 4   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge1    mip  13.0
# 5   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge1    mip  38.0
# 6   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge1    mip  24.0
# 7   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge1    mip  33.0
# 8   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge1    mip  35.0
# 9   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge1    mip  25.0
# 10  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge1    mip  61.0
# 11  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge1    mip  50.0
# ...

# %%
mip_n60_k2['lp'] = lp_n60_k2['bs']
mip_n60_k2['glp'] = (mip_n60_k2['bs'] - lp_n60_k2['bs'])/mip_n60_k2['bs']

mip_n60_k2
# Out:
#                                              instance   form method    bb  \
# 0   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge1    mip  23.0
# 1   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge1    mip  11.0
# 2   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge1    mip   9.0
# 3   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge1    mip  13.0
# 4   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge1    mip  13.0
# 5   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge1    mip  38.0
# 6   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge1    mip  24.0
# 7   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge1    mip  33.0
# 8   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge1    mip  35.0
# 9   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge1    mip  25.0
# 10  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge1    mip  61.0
# 11  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge1    mip  50.0
# ...

# %%
method_ = "mip"
k_ = 3
form_ = "edge1"

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

mip_n60_k3 = pd.DataFrame()
mip_n60_k3 = pd.concat([mip_n60_k3, df], ignore_index=True)
mip_n60_k3.columns = ['instance','form','method','bb','bs','gap','time','nodes','opt']

mip_n60_k3
# Out:
#                                              instance   form method    bb  \
# 0   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge1    mip  13.0
# 1   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge1    mip   8.0
# 2   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge1    mip  14.0
# 3   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge1    mip  14.0
# 4   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge1    mip   8.0
# 5   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge1    mip  20.0
# 6   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge1    mip  18.0
# 7   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge1    mip  21.0
# 8   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge1    mip  27.0
# 9   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge1    mip  19.0
# 10  data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err2...  edge1    mip  40.0
# 11  data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err2...  edge1    mip  33.0
# ...

# %%
mip_n60_k3['lp'] = lp_n60_k3['bs']
mip_n60_k3['glp'] = (mip_n60_k3['bs'] - lp_n60_k3['bs'])/mip_n60_k3['bs']

mip_n60_k3
# Out:
#                                              instance   form method    bb  \
# 0   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge1    mip  13.0
# 1   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge1    mip   8.0
# 2   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge1    mip  14.0
# 3   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge1    mip  14.0
# 4   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge1    mip   8.0
# 5   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge1    mip  20.0
# 6   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge1    mip  18.0
# 7   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge1    mip  21.0
# 8   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge1    mip  27.0
# 9   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge1    mip  19.0
# 10  data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err2...  edge1    mip  40.0
# 11  data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err2...  edge1    mip  33.0
# ...

# %%
method_ = "mip"
k_ = 4
form_ = "edge1"

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

mip_n60_k4 = pd.DataFrame()
mip_n60_k4 = pd.concat([mip_n60_k4, df], ignore_index=True)
mip_n60_k4.columns = ['instance','form','method','bb','bs','gap','time','nodes','opt']

mip_n60_k4
# Out:
#                                              instance   form method    bb  \
# 0   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge1    mip  12.0
# 1   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge1    mip  14.0
# 2   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge1    mip  13.0
# 3   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge1    mip  21.0
# 4   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge1    mip  16.0
# 5   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge1    mip  19.0
# 6   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge1    mip  19.0
# 7   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge1    mip  20.0
# 8   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge1    mip  21.0
# 9   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge1    mip  22.0
# 10  data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err2...  edge1    mip  28.0
# 11  data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err2...  edge1    mip  31.0
# ...

# %%
mip_n60_k4['lp'] = lp_n60_k4['bs']
mip_n60_k4['glp'] = (mip_n60_k4['bs'] - lp_n60_k4['bs'])/mip_n60_k4['bs']

mip_n60_k4
# Out:
#                                              instance   form method    bb  \
# 0   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge1    mip  12.0
# 1   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge1    mip  14.0
# 2   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge1    mip  13.0
# 3   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge1    mip  21.0
# 4   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge1    mip  16.0
# 5   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge1    mip  19.0
# 6   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge1    mip  19.0
# 7   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge1    mip  20.0
# 8   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge1    mip  21.0
# 9   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge1    mip  22.0
# 10  data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err2...  edge1    mip  28.0
# 11  data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err2...  edge1    mip  31.0
# ...

# %%
method_ = "mip"
k_ = 5
form_ = "edge1"

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

mip_n60_k5 = pd.DataFrame()
mip_n60_k5 = pd.concat([mip_n60_k5, df], ignore_index=True)
mip_n60_k5.columns = ['instance','form','method','bb','bs','gap','time','nodes','opt']

mip_n60_k5
# Out:
#                                              instance   form method    bb  \
# 0   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge1    mip  18.0
# 1   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge1    mip  13.0
# 2   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge1    mip  14.0
# 3   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge1    mip  16.0
# 4   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge1    mip  10.0
# 5   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge1    mip  22.0
# 6   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge1    mip  18.0
# 7   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge1    mip  22.0
# 8   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge1    mip  18.0
# 9   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge1    mip  17.0
# 10  data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err2...  edge1    mip  25.0
# 11  data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err2...  edge1    mip  23.0
# ...

# %%
mip_n60_k5['lp'] = lp_n60_k5['bs']
mip_n60_k5['glp'] = (mip_n60_k5['bs'] - lp_n60_k5['bs'])/mip_n60_k5['bs']

mip_n60_k5
# Out:
#                                              instance   form method    bb  \
# 0   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge1    mip  18.0
# 1   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge1    mip  13.0
# 2   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge1    mip  14.0
# 3   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge1    mip  16.0
# 4   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge1    mip  10.0
# 5   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge1    mip  22.0
# 6   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge1    mip  18.0
# 7   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge1    mip  22.0
# 8   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge1    mip  18.0
# 9   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge1    mip  17.0
# 10  data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err2...  edge1    mip  25.0
# 11  data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err2...  edge1    mip  23.0
# ...
