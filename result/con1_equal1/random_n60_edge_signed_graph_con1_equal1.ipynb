# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pdfkit as pdf

# %%
prob_ = "signed_graphs"
n_ = 60

# %%
form_ = "edge1"
method_ = "lp"

k_ = 2

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

lp1_n60_k2 = pd.DataFrame()
lp1_n60_k2 = pd.concat([lp1_n60_k2, df], ignore_index=True)
lp1_n60_k2.columns = ['instance','form','method','bs','time']
#lp1_n60_k2

k_ = 3

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

lp1_n60_k3 = pd.DataFrame()
lp1_n60_k3 = pd.concat([lp1_n60_k3, df], ignore_index=True)
lp1_n60_k3.columns = ['instance','form','method','bs','time']
#lp1_n60_k3

k_ = 4

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

lp1_n60_k4 = pd.DataFrame()
lp1_n60_k4 = pd.concat([lp1_n60_k4, df], ignore_index=True)
lp1_n60_k4.columns = ['instance','form','method','bs','time']
#lp1_n60_k4

k_ = 5

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

lp1_n60_k5 = pd.DataFrame()
lp1_n60_k5 = pd.concat([lp1_n60_k5, df], ignore_index=True)
lp1_n60_k5.columns = ['instance','form','method','bs','time']
#lp1_n60_k5

# %%
form_ = "edge1"
method_ = "mip"

k_ = 2

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

mip1_n60_k2 = pd.DataFrame()
mip1_n60_k2 = pd.concat([mip1_n60_k2, df], ignore_index=True)
mip1_n60_k2.columns = ['instance','form','method','bb','bs','gap','time','nodes','opt']
#mip1_n60_k2

k_ = 3

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

mip1_n60_k3 = pd.DataFrame()
mip1_n60_k3 = pd.concat([mip1_n60_k3, df], ignore_index=True)
mip1_n60_k3.columns = ['instance','form','method','bb','bs','gap','time','nodes','opt']
#mip1_n60_k3


k_ = 4

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

mip1_n60_k4 = pd.DataFrame()
mip1_n60_k4 = pd.concat([mip1_n60_k4, df], ignore_index=True)
mip1_n60_k4.columns = ['instance','form','method','bb','bs','gap','time','nodes','opt']
#mip1_n60_k4

k_ = 5

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

mip1_n60_k5 = pd.DataFrame()
mip1_n60_k5 = pd.concat([mip1_n60_k5, df], ignore_index=True)
mip1_n60_k5.columns = ['instance','form','method','bb','bs','gap','time','nodes','opt']
#mip1_n60_k5

# %%
mip1_n60_k2['lp'] = lp1_n60_k2['bs']
mip1_n60_k2['glp'] = (mip1_n60_k2['bs'] - lp1_n60_k2['bs'])/mip1_n60_k2['bs']
mip1_n60_k2
# Out:
#                                              instance   form method    bb  \
# 0   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge1    mip  23.0
# 1   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge1    mip  11.0
# 2   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge1    mip   9.0
# 3   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge1    mip  13.0
# 4   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge1    mip  13.0
# 5   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge1    mip  38.0
# 6   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge1    mip  24.0
# 7   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge1    mip  33.0
# 8   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge1    mip  35.0
# 9   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge1    mip  25.0
# 10  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge1    mip  61.0
# 11  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge1    mip  50.0
# 12  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge1    mip  62.0
# 13  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge1    mip  65.0
# 14  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge1    mip  54.0
#
#       bs  gap       time  nodes  opt   lp  glp
# 0   23.0  0.0   1.121716      9    1  0.0  1.0
# 1   11.0  0.0   0.226189      0    1  0.0  1.0
# 2    9.0  0.0   0.143083      0    1  0.0  1.0
# 3   13.0  0.0   0.278762      0    1  0.0  1.0
# 4   13.0  0.0   0.215705      3    1  0.0  1.0
# 5   38.0  0.0   3.197636     63    1  0.0  1.0
# 6   24.0  0.0   0.946683     11    1  0.0  1.0
# 7   33.0  0.0   1.992214     27    1  0.0  1.0
# 8   35.0  0.0   2.474882     15    1  0.0  1.0
# 9   25.0  0.0   1.001826      9    1  0.0  1.0
# 10  61.0  0.0  24.088452   2766    1  0.0  1.0
# 11  50.0  0.0   7.721081    339    1  0.0  1.0
# 12  62.0  0.0  22.841675   1387    1  0.0  1.0
# 13  65.0  0.0  21.662215   1562    1  0.0  1.0
# 14  54.0  0.0   7.456811    328    1  0.0  1.0

# %%
tab = pd.DataFrame({
    'instance':"n60_k2",
    'form':'edge1',
    'method':'mip',
    'bb':mip1_n60_k2['bb'].mean(),
    'bs':mip1_n60_k2['bs'].mean(),
    'gap':mip1_n60_k2['gap'].mean(),
    'time':mip1_n60_k2['time'].mean(),
    'nodes':mip1_n60_k2['nodes'].mean(),
    'opt':mip1_n60_k2['opt'].sum(),
    'lp':mip1_n60_k2['lp'].mean(),
    'glp':mip1_n60_k2['glp'].mean()
    },index=[""]
)

mip1_n60_k2 = pd.concat([mip1_n60_k2,tab])
mip1_n60_k2
# Out:
#                                              instance   form method    bb  \
# 0   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge1    mip  23.0
# 1   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge1    mip  11.0
# 2   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge1    mip   9.0
# 3   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge1    mip  13.0
# 4   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge1    mip  13.0
# 5   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge1    mip  38.0
# 6   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge1    mip  24.0
# 7   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge1    mip  33.0
# 8   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge1    mip  35.0
# 9   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge1    mip  25.0
# 10  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge1    mip  61.0
# 11  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge1    mip  50.0
# 12  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge1    mip  62.0
# 13  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge1    mip  65.0
# 14  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge1    mip  54.0
#                                                n60_k2  edge1    mip  34.4
#
#       bs  gap       time   nodes  opt   lp  glp
# 0   23.0  0.0   1.121716     9.0    1  0.0  1.0
# 1   11.0  0.0   0.226189     0.0    1  0.0  1.0
# 2    9.0  0.0   0.143083     0.0    1  0.0  1.0
# 3   13.0  0.0   0.278762     0.0    1  0.0  1.0
# 4   13.0  0.0   0.215705     3.0    1  0.0  1.0
# 5   38.0  0.0   3.197636    63.0    1  0.0  1.0
# 6   24.0  0.0   0.946683    11.0    1  0.0  1.0
# 7   33.0  0.0   1.992214    27.0    1  0.0  1.0
# 8   35.0  0.0   2.474882    15.0    1  0.0  1.0
# 9   25.0  0.0   1.001826     9.0    1  0.0  1.0
# 10  61.0  0.0  24.088452  2766.0    1  0.0  1.0
# 11  50.0  0.0   7.721081   339.0    1  0.0  1.0
# 12  62.0  0.0  22.841675  1387.0    1  0.0  1.0
# 13  65.0  0.0  21.662215  1562.0    1  0.0  1.0
# 14  54.0  0.0   7.456811   328.0    1  0.0  1.0
#     34.4  0.0   6.357929   434.6   15  0.0  1.0

# %%
mip1_n60_k2['instance'] = mip1_n60_k2['instance'].str.replace('data/kmbs/RANDOM/random_','')
mip1_n60_k2['instance'] = mip1_n60_k2['instance'].str.replace('_','\_') 
#mip1_n60_k2

print(mip1_n60_k2[['instance','form','bs','gap','time','nodes','opt','lp','glp']].to_latex(index=False,float_format="%.2f"))
# Out:
# \begin{tabular}{llrrrrrrr}
# \toprule
# instance & form & bs & gap & time & nodes & opt & lp & glp \\
# \midrule
# n60\_k2\_pos30\_neg5\_err5\_1.g & edge1 & 23.00 & 0.00 & 1.12 & 9.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err5\_2.g & edge1 & 11.00 & 0.00 & 0.23 & 0.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err5\_3.g & edge1 & 9.00 & 0.00 & 0.14 & 0.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err5\_4.g & edge1 & 13.00 & 0.00 & 0.28 & 0.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err5\_5.g & edge1 & 13.00 & 0.00 & 0.22 & 3.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err10\_1.g & edge1 & 38.00 & 0.00 & 3.20 & 63.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err10\_2.g & edge1 & 24.00 & 0.00 & 0.95 & 11.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err10\_3.g & edge1 & 33.00 & 0.00 & 1.99 & 27.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err10\_4.g & edge1 & 35.00 & 0.00 & 2.47 & 15.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err10\_5.g & edge1 & 25.00 & 0.00 & 1.00 & 9.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err20\_1.g & edge1 & 61.00 & 0.00 & 24.09 & 2766.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err20\_2.g & edge1 & 50.00 & 0.00 & 7.72 & 339.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err20\_3.g & edge1 & 62.00 & 0.00 & 22.84 & 1387.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err20\_4.g & edge1 & 65.00 & 0.00 & 21.66 & 1562.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err20\_5.g & edge1 & 54.00 & 0.00 & 7.46 & 328.00 & 1 & 0.00 & 1.00 \\
# n60\_k2 & edge1 & 34.40 & 0.00 & 6.36 & 434.60 & 15 & 0.00 & 1.00 \\
# \bottomrule
# \end{tabular}

# %%
mip1_n60_k3['lp'] = lp1_n60_k3['bs']
mip1_n60_k3['glp'] = (mip1_n60_k3['bs'] - lp1_n60_k3['bs'])/mip1_n60_k3['bs']
mip1_n60_k3
# Out:
#                                              instance   form method    bb  \
# 0   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge1    mip  13.0
# 1   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge1    mip   8.0
# 2   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge1    mip  14.0
# 3   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge1    mip  14.0
# 4   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge1    mip   8.0
# 5   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge1    mip  20.0
# 6   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge1    mip  18.0
# 7   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge1    mip  21.0
# 8   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge1    mip  27.0
# 9   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge1    mip  19.0
# 10  data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err2...  edge1    mip  40.0
# 11  data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err2...  edge1    mip  33.0
# 12  data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err2...  edge1    mip  39.0
# 13  data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err2...  edge1    mip  47.0
# 14  data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err2...  edge1    mip  38.0
#
#       bs  gap       time  nodes  opt   lp  glp
# 0   13.0  0.0   0.797308      8    1  0.0  1.0
# 1    8.0  0.0   0.342675      0    1  0.0  1.0
# 2   14.0  0.0   0.756208      7    1  0.0  1.0
# 3   14.0  0.0   0.842291     11    1  0.0  1.0
# 4    8.0  0.0   0.090971      0    1  0.0  1.0
# 5   20.0  0.0   1.009782     11    1  0.0  1.0
# 6   18.0  0.0   1.160428     11    1  0.0  1.0
# 7   21.0  0.0   1.366499     31    1  0.0  1.0
# 8   27.0  0.0   2.412780     68    1  0.0  1.0
# 9   19.0  0.0   1.846898     13    1  0.0  1.0
# 10  40.0  0.0   8.499918   1190    1  0.0  1.0
# 11  33.0  0.0   5.767903    515    1  0.0  1.0
# 12  39.0  0.0   6.313169    820    1  0.0  1.0
# 13  47.0  0.0  56.695910   8586    1  0.0  1.0
# 14  38.0  0.0  11.430136   2197    1  0.0  1.0

# %%
tab = pd.DataFrame({
    'instance':"n60_k3",
    'form':'edge1',
    'method':'mip',
    'bb':mip1_n60_k3['bb'].mean(),
    'bs':mip1_n60_k3['bs'].mean(),
    'gap':mip1_n60_k3['gap'].mean(),
    'time':mip1_n60_k3['time'].mean(),
    'nodes':mip1_n60_k3['nodes'].mean(),
    'opt':mip1_n60_k3['opt'].sum(),
    'lp':mip1_n60_k3['lp'].mean(),
    'glp':mip1_n60_k3['glp'].mean()
    },index=[""]
)

mip1_n60_k3 = pd.concat([mip1_n60_k3,tab])
#mip1_n60_k3
mip1_n60_k3['instance'] = mip1_n60_k3['instance'].str.replace('data/kmbs/RANDOM/random_','')
mip1_n60_k3['instance'] = mip1_n60_k3['instance'].str.replace('_','\_') 
mip1_n60_k3
# Out:
#                             instance   form method         bb         bs  gap  \
# 0    n60\_k3\_pos30\_neg5\_err5\_1.g  edge1    mip  13.000000  13.000000  0.0
# 1    n60\_k3\_pos30\_neg5\_err5\_2.g  edge1    mip   8.000000   8.000000  0.0
# 2    n60\_k3\_pos30\_neg5\_err5\_3.g  edge1    mip  14.000000  14.000000  0.0
# 3    n60\_k3\_pos30\_neg5\_err5\_4.g  edge1    mip  14.000000  14.000000  0.0
# 4    n60\_k3\_pos30\_neg5\_err5\_5.g  edge1    mip   8.000000   8.000000  0.0
# 5   n60\_k3\_pos30\_neg5\_err10\_1.g  edge1    mip  20.000000  20.000000  0.0
# 6   n60\_k3\_pos30\_neg5\_err10\_2.g  edge1    mip  18.000000  18.000000  0.0
# 7   n60\_k3\_pos30\_neg5\_err10\_3.g  edge1    mip  21.000000  21.000000  0.0
# 8   n60\_k3\_pos30\_neg5\_err10\_4.g  edge1    mip  27.000000  27.000000  0.0
# 9   n60\_k3\_pos30\_neg5\_err10\_5.g  edge1    mip  19.000000  19.000000  0.0
# 10  n60\_k3\_pos30\_neg5\_err20\_1.g  edge1    mip  40.000000  40.000000  0.0
# 11  n60\_k3\_pos30\_neg5\_err20\_2.g  edge1    mip  33.000000  33.000000  0.0
# 12  n60\_k3\_pos30\_neg5\_err20\_3.g  edge1    mip  39.000000  39.000000  0.0
# 13  n60\_k3\_pos30\_neg5\_err20\_4.g  edge1    mip  47.000000  47.000000  0.0
# 14  n60\_k3\_pos30\_neg5\_err20\_5.g  edge1    mip  38.000000  38.000000  0.0
#                              n60\_k3  edge1    mip  23.933333  23.933333  0.0
#
#          time        nodes  opt   lp  glp
# 0    0.797308     8.000000    1  0.0  1.0
# 1    0.342675     0.000000    1  0.0  1.0
# 2    0.756208     7.000000    1  0.0  1.0
# 3    0.842291    11.000000    1  0.0  1.0
# 4    0.090971     0.000000    1  0.0  1.0
# 5    1.009782    11.000000    1  0.0  1.0
# 6    1.160428    11.000000    1  0.0  1.0
# 7    1.366499    31.000000    1  0.0  1.0
# 8    2.412780    68.000000    1  0.0  1.0
# 9    1.846898    13.000000    1  0.0  1.0
# 10   8.499918  1190.000000    1  0.0  1.0
# 11   5.767903   515.000000    1  0.0  1.0
# 12   6.313169   820.000000    1  0.0  1.0
# 13  56.695910  8586.000000    1  0.0  1.0
# 14  11.430136  2197.000000    1  0.0  1.0
#      6.622192   897.866667   15  0.0  1.0

# %%
print(mip1_n60_k3[['instance','form','bs','gap','time','nodes','opt','lp','glp']].to_latex(index=False,float_format="%.2f"))
# Out:
# \begin{tabular}{llrrrrrrr}
# \toprule
# instance & form & bs & gap & time & nodes & opt & lp & glp \\
# \midrule
# n60\_k3\_pos30\_neg5\_err5\_1.g & edge1 & 13.00 & 0.00 & 0.80 & 8.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err5\_2.g & edge1 & 8.00 & 0.00 & 0.34 & 0.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err5\_3.g & edge1 & 14.00 & 0.00 & 0.76 & 7.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err5\_4.g & edge1 & 14.00 & 0.00 & 0.84 & 11.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err5\_5.g & edge1 & 8.00 & 0.00 & 0.09 & 0.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err10\_1.g & edge1 & 20.00 & 0.00 & 1.01 & 11.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err10\_2.g & edge1 & 18.00 & 0.00 & 1.16 & 11.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err10\_3.g & edge1 & 21.00 & 0.00 & 1.37 & 31.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err10\_4.g & edge1 & 27.00 & 0.00 & 2.41 & 68.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err10\_5.g & edge1 & 19.00 & 0.00 & 1.85 & 13.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err20\_1.g & edge1 & 40.00 & 0.00 & 8.50 & 1190.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err20\_2.g & edge1 & 33.00 & 0.00 & 5.77 & 515.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err20\_3.g & edge1 & 39.00 & 0.00 & 6.31 & 820.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err20\_4.g & edge1 & 47.00 & 0.00 & 56.70 & 8586.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err20\_5.g & edge1 & 38.00 & 0.00 & 11.43 & 2197.00 & 1 & 0.00 & 1.00 \\
# n60\_k3 & edge1 & 23.93 & 0.00 & 6.62 & 897.87 & 15 & 0.00 & 1.00 \\
# \bottomrule
# \end{tabular}

# %%
mip1_n60_k4['lp'] = lp1_n60_k4['bs']
mip1_n60_k4['glp'] = (mip1_n60_k4['bs'] - lp1_n60_k4['bs'])/mip1_n60_k4['bs']
mip1_n60_k4
# Out:
#                                              instance   form method    bb  \
# 0   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge1    mip  12.0
# 1   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge1    mip  14.0
# 2   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge1    mip  13.0
# 3   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge1    mip  21.0
# 4   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge1    mip  16.0
# 5   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge1    mip  19.0
# 6   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge1    mip  19.0
# 7   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge1    mip  20.0
# 8   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge1    mip  21.0
# 9   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge1    mip  22.0
# 10  data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err2...  edge1    mip  28.0
# 11  data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err2...  edge1    mip  31.0
# 12  data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err2...  edge1    mip  34.0
# 13  data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err2...  edge1    mip  29.0
# 14  data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err2...  edge1    mip  34.0
#
#       bs  gap      time  nodes  opt   lp  glp
# 0   12.0  0.0  0.622369     19    1  0.0  1.0
# 1   14.0  0.0  0.769013     25    1  0.0  1.0
# 2   13.0  0.0  0.523701     11    1  0.0  1.0
# 3   21.0  0.0  2.428940    179    1  0.0  1.0
# 4   16.0  0.0  0.956798     22    1  0.0  1.0
# 5   19.0  0.0  1.507842     72    1  0.0  1.0
# 6   19.0  0.0  1.142244     97    1  0.0  1.0
# 7   20.0  0.0  1.841590     77    1  0.0  1.0
# 8   21.0  0.0  1.881426     67    1  0.0  1.0
# 9   22.0  0.0  1.544156     97    1  0.0  1.0
# 10  28.0  0.0  3.935322    663    1  0.0  1.0
# 11  31.0  0.0  5.854201   1269    1  0.0  1.0
# 12  34.0  0.0  6.867686   1396    1  0.0  1.0
# 13  29.0  0.0  4.841896   1070    1  0.0  1.0
# 14  34.0  0.0  7.633432   1732    1  0.0  1.0

# %%
tab = pd.DataFrame({
    'instance':"n60_k4",
    'form':'edge1',
    'method':'mip',
    'bb':mip1_n60_k4['bb'].mean(),
    'bs':mip1_n60_k4['bs'].mean(),
    'gap':mip1_n60_k4['gap'].mean(),
    'time':mip1_n60_k4['time'].mean(),
    'nodes':mip1_n60_k4['nodes'].mean(),
    'opt':mip1_n60_k4['opt'].sum(),
    'lp':mip1_n60_k4['lp'].mean(),
    'glp':mip1_n60_k4['glp'].mean()
    },index=[""]
)

mip1_n60_k4 = pd.concat([mip1_n60_k4,tab])
#mip1_n60_k4
mip1_n60_k4['instance'] = mip1_n60_k4['instance'].str.replace('data/kmbs/RANDOM/random_','')
mip1_n60_k4['instance'] = mip1_n60_k4['instance'].str.replace('_','\_') 
mip1_n60_k4
# Out:
#                             instance   form method    bb    bs  gap      time  \
# 0    n60\_k4\_pos30\_neg5\_err5\_1.g  edge1    mip  12.0  12.0  0.0  0.622369
# 1    n60\_k4\_pos30\_neg5\_err5\_2.g  edge1    mip  14.0  14.0  0.0  0.769013
# 2    n60\_k4\_pos30\_neg5\_err5\_3.g  edge1    mip  13.0  13.0  0.0  0.523701
# 3    n60\_k4\_pos30\_neg5\_err5\_4.g  edge1    mip  21.0  21.0  0.0  2.428940
# 4    n60\_k4\_pos30\_neg5\_err5\_5.g  edge1    mip  16.0  16.0  0.0  0.956798
# 5   n60\_k4\_pos30\_neg5\_err10\_1.g  edge1    mip  19.0  19.0  0.0  1.507842
# 6   n60\_k4\_pos30\_neg5\_err10\_2.g  edge1    mip  19.0  19.0  0.0  1.142244
# 7   n60\_k4\_pos30\_neg5\_err10\_3.g  edge1    mip  20.0  20.0  0.0  1.841590
# 8   n60\_k4\_pos30\_neg5\_err10\_4.g  edge1    mip  21.0  21.0  0.0  1.881426
# 9   n60\_k4\_pos30\_neg5\_err10\_5.g  edge1    mip  22.0  22.0  0.0  1.544156
# 10  n60\_k4\_pos30\_neg5\_err20\_1.g  edge1    mip  28.0  28.0  0.0  3.935322
# 11  n60\_k4\_pos30\_neg5\_err20\_2.g  edge1    mip  31.0  31.0  0.0  5.854201
# 12  n60\_k4\_pos30\_neg5\_err20\_3.g  edge1    mip  34.0  34.0  0.0  6.867686
# 13  n60\_k4\_pos30\_neg5\_err20\_4.g  edge1    mip  29.0  29.0  0.0  4.841896
# 14  n60\_k4\_pos30\_neg5\_err20\_5.g  edge1    mip  34.0  34.0  0.0  7.633432
#                              n60\_k4  edge1    mip  22.2  22.2  0.0  2.823374
#
#           nodes  opt   lp  glp
# 0     19.000000    1  0.0  1.0
# 1     25.000000    1  0.0  1.0
# 2     11.000000    1  0.0  1.0
# 3    179.000000    1  0.0  1.0
# 4     22.000000    1  0.0  1.0
# 5     72.000000    1  0.0  1.0
# 6     97.000000    1  0.0  1.0
# 7     77.000000    1  0.0  1.0
# 8     67.000000    1  0.0  1.0
# 9     97.000000    1  0.0  1.0
# 10   663.000000    1  0.0  1.0
# 11  1269.000000    1  0.0  1.0
# 12  1396.000000    1  0.0  1.0
# 13  1070.000000    1  0.0  1.0
# 14  1732.000000    1  0.0  1.0
#      453.066667   15  0.0  1.0

# %%
print(mip1_n60_k4[['instance','form','bs','gap','time','nodes','opt','lp','glp']].to_latex(index=False,float_format="%.2f"))
# Out:
# \begin{tabular}{llrrrrrrr}
# \toprule
# instance & form & bs & gap & time & nodes & opt & lp & glp \\
# \midrule
# n60\_k4\_pos30\_neg5\_err5\_1.g & edge1 & 12.00 & 0.00 & 0.62 & 19.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err5\_2.g & edge1 & 14.00 & 0.00 & 0.77 & 25.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err5\_3.g & edge1 & 13.00 & 0.00 & 0.52 & 11.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err5\_4.g & edge1 & 21.00 & 0.00 & 2.43 & 179.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err5\_5.g & edge1 & 16.00 & 0.00 & 0.96 & 22.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err10\_1.g & edge1 & 19.00 & 0.00 & 1.51 & 72.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err10\_2.g & edge1 & 19.00 & 0.00 & 1.14 & 97.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err10\_3.g & edge1 & 20.00 & 0.00 & 1.84 & 77.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err10\_4.g & edge1 & 21.00 & 0.00 & 1.88 & 67.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err10\_5.g & edge1 & 22.00 & 0.00 & 1.54 & 97.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err20\_1.g & edge1 & 28.00 & 0.00 & 3.94 & 663.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err20\_2.g & edge1 & 31.00 & 0.00 & 5.85 & 1269.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err20\_3.g & edge1 & 34.00 & 0.00 & 6.87 & 1396.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err20\_4.g & edge1 & 29.00 & 0.00 & 4.84 & 1070.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err20\_5.g & edge1 & 34.00 & 0.00 & 7.63 & 1732.00 & 1 & 0.00 & 1.00 \\
# n60\_k4 & edge1 & 22.20 & 0.00 & 2.82 & 453.07 & 15 & 0.00 & 1.00 \\
# \bottomrule
# \end{tabular}

# %%
mip1_n60_k5['lp'] = lp1_n60_k5['bs']
mip1_n60_k5['glp'] = (mip1_n60_k5['bs'] - lp1_n60_k5['bs'])/mip1_n60_k5['bs']
mip1_n60_k5
# Out:
#                                              instance   form method    bb  \
# 0   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge1    mip  18.0
# 1   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge1    mip  13.0
# 2   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge1    mip  14.0
# 3   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge1    mip  16.0
# 4   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge1    mip  10.0
# 5   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge1    mip  22.0
# 6   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge1    mip  18.0
# 7   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge1    mip  22.0
# 8   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge1    mip  18.0
# 9   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge1    mip  17.0
# 10  data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err2...  edge1    mip  25.0
# 11  data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err2...  edge1    mip  23.0
# 12  data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err2...  edge1    mip  23.0
# 13  data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err2...  edge1    mip  27.0
# 14  data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err2...  edge1    mip  26.0
#
#       bs  gap      time  nodes  opt   lp  glp
# 0   18.0  0.0  1.530999    201    1  0.0  1.0
# 1   13.0  0.0  0.556029    104    1  0.0  1.0
# 2   14.0  0.0  0.787614     37    1  0.0  1.0
# 3   16.0  0.0  1.279030    164    1  0.0  1.0
# 4   10.0  0.0  0.577053     15    1  0.0  1.0
# 5   22.0  0.0  2.544738    325    1  0.0  1.0
# 6   18.0  0.0  1.711206    134    1  0.0  1.0
# 7   22.0  0.0  2.296765    358    1  0.0  1.0
# 8   18.0  0.0  1.748566    215    1  0.0  1.0
# 9   17.0  0.0  1.353910     51    1  0.0  1.0
# 10  25.0  0.0  2.785777    589    1  0.0  1.0
# 11  23.0  0.0  2.753788    416    1  0.0  1.0
# 12  23.0  0.0  1.962922    307    1  0.0  1.0
# 13  27.0  0.0  3.610766    888    1  0.0  1.0
# 14  26.0  0.0  2.235836    267    1  0.0  1.0

# %%
tab = pd.DataFrame({
    'instance':"n60_k5",
    'form':'edge1',
    'method':'mip',
    'bb':mip1_n60_k5['bb'].mean(),
    'bs':mip1_n60_k5['bs'].mean(),
    'gap':mip1_n60_k5['gap'].mean(),
    'time':mip1_n60_k5['time'].mean(),
    'nodes':mip1_n60_k5['nodes'].mean(),
    'opt':mip1_n60_k5['opt'].sum(),
    'lp':mip1_n60_k5['lp'].mean(),
    'glp':mip1_n60_k5['glp'].mean()
    },index=[""]
)

mip1_n60_k5 = pd.concat([mip1_n60_k5,tab])
#mip1_n60_k5

mip1_n60_k5['instance'] = mip1_n60_k5['instance'].str.replace('data/kmbs/RANDOM/random_','')
mip1_n60_k5['instance'] = mip1_n60_k5['instance'].str.replace('_','\_') 
mip1_n60_k5
# Out:
#                             instance   form method         bb         bs  gap  \
# 0    n60\_k5\_pos30\_neg5\_err5\_1.g  edge1    mip  18.000000  18.000000  0.0
# 1    n60\_k5\_pos30\_neg5\_err5\_2.g  edge1    mip  13.000000  13.000000  0.0
# 2    n60\_k5\_pos30\_neg5\_err5\_3.g  edge1    mip  14.000000  14.000000  0.0
# 3    n60\_k5\_pos30\_neg5\_err5\_4.g  edge1    mip  16.000000  16.000000  0.0
# 4    n60\_k5\_pos30\_neg5\_err5\_5.g  edge1    mip  10.000000  10.000000  0.0
# 5   n60\_k5\_pos30\_neg5\_err10\_1.g  edge1    mip  22.000000  22.000000  0.0
# 6   n60\_k5\_pos30\_neg5\_err10\_2.g  edge1    mip  18.000000  18.000000  0.0
# 7   n60\_k5\_pos30\_neg5\_err10\_3.g  edge1    mip  22.000000  22.000000  0.0
# 8   n60\_k5\_pos30\_neg5\_err10\_4.g  edge1    mip  18.000000  18.000000  0.0
# 9   n60\_k5\_pos30\_neg5\_err10\_5.g  edge1    mip  17.000000  17.000000  0.0
# 10  n60\_k5\_pos30\_neg5\_err20\_1.g  edge1    mip  25.000000  25.000000  0.0
# 11  n60\_k5\_pos30\_neg5\_err20\_2.g  edge1    mip  23.000000  23.000000  0.0
# 12  n60\_k5\_pos30\_neg5\_err20\_3.g  edge1    mip  23.000000  23.000000  0.0
# 13  n60\_k5\_pos30\_neg5\_err20\_4.g  edge1    mip  27.000000  27.000000  0.0
# 14  n60\_k5\_pos30\_neg5\_err20\_5.g  edge1    mip  26.000000  26.000000  0.0
#                              n60\_k5  edge1    mip  19.466667  19.466667  0.0
#
#         time  nodes  opt   lp  glp
# 0   1.530999  201.0    1  0.0  1.0
# 1   0.556029  104.0    1  0.0  1.0
# 2   0.787614   37.0    1  0.0  1.0
# 3   1.279030  164.0    1  0.0  1.0
# 4   0.577053   15.0    1  0.0  1.0
# 5   2.544738  325.0    1  0.0  1.0
# 6   1.711206  134.0    1  0.0  1.0
# 7   2.296765  358.0    1  0.0  1.0
# 8   1.748566  215.0    1  0.0  1.0
# 9   1.353910   51.0    1  0.0  1.0
# 10  2.785777  589.0    1  0.0  1.0
# 11  2.753788  416.0    1  0.0  1.0
# 12  1.962922  307.0    1  0.0  1.0
# 13  3.610766  888.0    1  0.0  1.0
# 14  2.235836  267.0    1  0.0  1.0
#     1.849000  271.4   15  0.0  1.0

# %%
print(mip1_n60_k5[['instance','form','bs','gap','time','nodes','opt','lp','glp']].to_latex(index=False,float_format="%.2f"))
# Out:
# \begin{tabular}{llrrrrrrr}
# \toprule
# instance & form & bs & gap & time & nodes & opt & lp & glp \\
# \midrule
# n60\_k5\_pos30\_neg5\_err5\_1.g & edge1 & 18.00 & 0.00 & 1.53 & 201.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err5\_2.g & edge1 & 13.00 & 0.00 & 0.56 & 104.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err5\_3.g & edge1 & 14.00 & 0.00 & 0.79 & 37.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err5\_4.g & edge1 & 16.00 & 0.00 & 1.28 & 164.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err5\_5.g & edge1 & 10.00 & 0.00 & 0.58 & 15.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err10\_1.g & edge1 & 22.00 & 0.00 & 2.54 & 325.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err10\_2.g & edge1 & 18.00 & 0.00 & 1.71 & 134.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err10\_3.g & edge1 & 22.00 & 0.00 & 2.30 & 358.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err10\_4.g & edge1 & 18.00 & 0.00 & 1.75 & 215.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err10\_5.g & edge1 & 17.00 & 0.00 & 1.35 & 51.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err20\_1.g & edge1 & 25.00 & 0.00 & 2.79 & 589.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err20\_2.g & edge1 & 23.00 & 0.00 & 2.75 & 416.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err20\_3.g & edge1 & 23.00 & 0.00 & 1.96 & 307.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err20\_4.g & edge1 & 27.00 & 0.00 & 3.61 & 888.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err20\_5.g & edge1 & 26.00 & 0.00 & 2.24 & 267.00 & 1 & 0.00 & 1.00 \\
# n60\_k5 & edge1 & 19.47 & 0.00 & 1.85 & 271.40 & 15 & 0.00 & 1.00 \\
# \bottomrule
# \end{tabular}

# %%
form_="edge2"
method_="lp"

k_ = 2

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

lp2_n60_k2 = pd.DataFrame()
lp2_n60_k2 = pd.concat([lp2_n60_k2, df], ignore_index=True)
lp2_n60_k2.columns = ['instance','form','method','bs','time']
#lp2_n60_k2

k_ = 3

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

lp2_n60_k3 = pd.DataFrame()
lp2_n60_k3 = pd.concat([lp2_n60_k3, df], ignore_index=True)
lp2_n60_k3.columns = ['instance','form','method','bs','time']
#lp2_n60_k3

k_ = 4

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

lp2_n60_k4 = pd.DataFrame()
lp2_n60_k4 = pd.concat([lp2_n60_k4, df], ignore_index=True)
lp2_n60_k4.columns = ['instance','form','method','bs','time']
#lp2_n60_k4

k_ = 5

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

lp2_n60_k5 = pd.DataFrame()
lp2_n60_k5 = pd.concat([lp2_n60_k5, df], ignore_index=True)
lp2_n60_k5.columns = ['instance','form','method','bs','time']
#lp2_n60_k5

# %%
form_="edge2"
method_="mip"

k_ = 2

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

mip2_n60_k2 = pd.DataFrame()
mip2_n60_k2 = pd.concat([mip2_n60_k2, df], ignore_index=True)
mip2_n60_k2.columns = ['instance','form','method','bb','bs','gap','time','nodes','opt']


k_ = 3

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

mip2_n60_k3 = pd.DataFrame()
mip2_n60_k3 = pd.concat([mip2_n60_k3, df], ignore_index=True)
mip2_n60_k3.columns = ['instance','form','method','bb','bs','gap','time','nodes','opt']


k_ = 4

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

mip2_n60_k4 = pd.DataFrame()
mip2_n60_k4 = pd.concat([mip2_n60_k4, df], ignore_index=True)
mip2_n60_k4.columns = ['instance','form','method','bb','bs','gap','time','nodes','opt']


k_ = 4

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

mip2_n60_k4 = pd.DataFrame()
mip2_n60_k4 = pd.concat([mip2_n60_k4, df], ignore_index=True)
mip2_n60_k4.columns = ['instance','form','method','bb','bs','gap','time','nodes','opt']


k_ = 5

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

mip2_n60_k5 = pd.DataFrame()
mip2_n60_k5 = pd.concat([mip2_n60_k5, df], ignore_index=True)
mip2_n60_k5.columns = ['instance','form','method','bb','bs','gap','time','nodes','opt']

# %%
mip2_n60_k2['lp'] = lp2_n60_k2['bs']
mip2_n60_k2['glp'] = (mip2_n60_k2['bs'] - lp2_n60_k2['bs'])/mip2_n60_k2['bs']
mip2_n60_k2
# Out:
#                                              instance   form method    bb  \
# 0   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge2    mip  23.0
# 1   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge2    mip  11.0
# 2   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge2    mip   9.0
# 3   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge2    mip  13.0
# 4   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge2    mip  13.0
# 5   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge2    mip  38.0
# 6   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge2    mip  24.0
# 7   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge2    mip  33.0
# 8   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge2    mip  35.0
# 9   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge2    mip  25.0
# 10  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge2    mip  61.0
# 11  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge2    mip  50.0
# 12  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge2    mip  62.0
# 13  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge2    mip  65.0
# 14  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge2    mip  54.0
#
#       bs  gap         time   nodes  opt   lp  glp
# 0   23.0  0.0     1.241452     711    1  0.0  1.0
# 1   11.0  0.0     0.338198      79    1  0.0  1.0
# 2    9.0  0.0     0.205148      21    1  0.0  1.0
# 3   13.0  0.0     0.464846     148    1  0.0  1.0
# 4   13.0  0.0     0.405868     159    1  0.0  1.0
# 5   38.0  0.0    59.197714   26639    1  0.0  1.0
# 6   24.0  0.0     1.656975    1036    1  0.0  1.0
# 7   33.0  0.0    10.755289    5242    1  0.0  1.0
# 8   35.0  0.0    21.802125    6752    1  0.0  1.0
# 9   25.0  0.0     1.501103    1391    1  0.0  1.0
# 10  61.0  0.0  2698.829315  880106    1  0.0  1.0
# 11  50.0  0.0   178.716656   95846    1  0.0  1.0
# 12  62.0  0.0  1609.175977  862314    1  0.0  1.0
# 13  65.0  0.0  2301.410802  698231    1  0.0  1.0
# 14  54.0  0.0   604.666833  165361    1  0.0  1.0

# %%
tab = pd.DataFrame({
    'instance':"n60_k2",
    'form':'edge2',
    'method':'mip',
    'bb':mip2_n60_k2['bb'].mean(),
    'bs':mip2_n60_k2['bs'].mean(),
    'gap':mip2_n60_k2['gap'].mean(),
    'time':mip2_n60_k2['time'].mean(),
    'nodes':mip2_n60_k2['nodes'].mean(),
    'opt':mip2_n60_k2['opt'].sum(),
    'lp':mip2_n60_k2['lp'].mean(),
    'glp':mip2_n60_k2['glp'].mean()
    },index=[""]
)

mip2_n60_k2 = pd.concat([mip2_n60_k2,tab])
mip2_n60_k2
# Out:
#                                              instance   form method    bb  \
# 0   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge2    mip  23.0
# 1   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge2    mip  11.0
# 2   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge2    mip   9.0
# 3   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge2    mip  13.0
# 4   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge2    mip  13.0
# 5   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge2    mip  38.0
# 6   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge2    mip  24.0
# 7   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge2    mip  33.0
# 8   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge2    mip  35.0
# 9   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge2    mip  25.0
# 10  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge2    mip  61.0
# 11  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge2    mip  50.0
# 12  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge2    mip  62.0
# 13  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge2    mip  65.0
# 14  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge2    mip  54.0
#                                                n60_k2  edge2    mip  34.4
#
#       bs  gap         time          nodes  opt   lp  glp
# 0   23.0  0.0     1.241452     711.000000    1  0.0  1.0
# 1   11.0  0.0     0.338198      79.000000    1  0.0  1.0
# 2    9.0  0.0     0.205148      21.000000    1  0.0  1.0
# 3   13.0  0.0     0.464846     148.000000    1  0.0  1.0
# 4   13.0  0.0     0.405868     159.000000    1  0.0  1.0
# 5   38.0  0.0    59.197714   26639.000000    1  0.0  1.0
# 6   24.0  0.0     1.656975    1036.000000    1  0.0  1.0
# 7   33.0  0.0    10.755289    5242.000000    1  0.0  1.0
# 8   35.0  0.0    21.802125    6752.000000    1  0.0  1.0
# 9   25.0  0.0     1.501103    1391.000000    1  0.0  1.0
# 10  61.0  0.0  2698.829315  880106.000000    1  0.0  1.0
# 11  50.0  0.0   178.716656   95846.000000    1  0.0  1.0
# 12  62.0  0.0  1609.175977  862314.000000    1  0.0  1.0
# 13  65.0  0.0  2301.410802  698231.000000    1  0.0  1.0
# 14  54.0  0.0   604.666833  165361.000000    1  0.0  1.0
#     34.4  0.0   499.357887  182935.733333   15  0.0  1.0

# %%
mip2_n60_k2['instance'] = mip2_n60_k2['instance'].str.replace('data/kmbs/RANDOM/random_','')
mip2_n60_k2['instance'] = mip2_n60_k2['instance'].str.replace('_','\_') 
#mip2_n60_k2

print(mip2_n60_k2[['instance','form','bs','gap','time','nodes','opt','lp','glp']].to_latex(index=False,float_format="%.2f"))
# Out:
# \begin{tabular}{llrrrrrrr}
# \toprule
# instance & form & bs & gap & time & nodes & opt & lp & glp \\
# \midrule
# n60\_k2\_pos30\_neg5\_err5\_1.g & edge2 & 23.00 & 0.00 & 1.24 & 711.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err5\_2.g & edge2 & 11.00 & 0.00 & 0.34 & 79.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err5\_3.g & edge2 & 9.00 & 0.00 & 0.21 & 21.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err5\_4.g & edge2 & 13.00 & 0.00 & 0.46 & 148.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err5\_5.g & edge2 & 13.00 & 0.00 & 0.41 & 159.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err10\_1.g & edge2 & 38.00 & 0.00 & 59.20 & 26639.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err10\_2.g & edge2 & 24.00 & 0.00 & 1.66 & 1036.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err10\_3.g & edge2 & 33.00 & 0.00 & 10.76 & 5242.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err10\_4.g & edge2 & 35.00 & 0.00 & 21.80 & 6752.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err10\_5.g & edge2 & 25.00 & 0.00 & 1.50 & 1391.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err20\_1.g & edge2 & 61.00 & 0.00 & 2698.83 & 880106.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err20\_2.g & edge2 & 50.00 & 0.00 & 178.72 & 95846.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err20\_3.g & edge2 & 62.00 & 0.00 & 1609.18 & 862314.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err20\_4.g & edge2 & 65.00 & 0.00 & 2301.41 & 698231.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err20\_5.g & edge2 & 54.00 & 0.00 & 604.67 & 165361.00 & 1 & 0.00 & 1.00 \\
# n60\_k2 & edge2 & 34.40 & 0.00 & 499.36 & 182935.73 & 15 & 0.00 & 1.00 \\
# \bottomrule
# \end{tabular}

# %%
mip2_n60_k3['lp'] = lp2_n60_k3['bs']
mip2_n60_k3['glp'] = (mip2_n60_k3['bs'] - lp2_n60_k3['bs'])/mip2_n60_k3['bs']

mip2_n60_k3
# Out:
#                                              instance   form method    bb  \
# 0   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge2    mip  13.0
# 1   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge2    mip   8.0
# 2   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge2    mip  14.0
# 3   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge2    mip  14.0
# 4   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge2    mip   8.0
# 5   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge2    mip  20.0
# 6   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge2    mip  18.0
# 7   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge2    mip  21.0
# 8   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge2    mip  27.0
# 9   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge2    mip  19.0
# 10  data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err2...  edge2    mip  40.0
# 11  data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err2...  edge2    mip  33.0
# 12  data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err2...  edge2    mip  39.0
# 13  data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err2...  edge2    mip  47.0
# 14  data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err2...  edge2    mip  38.0
#
#       bs  gap         time    nodes  opt   lp  glp
# 0   13.0  0.0     0.592326      379    1  0.0  1.0
# 1    8.0  0.0     0.322971      150    1  0.0  1.0
# 2   14.0  0.0     0.612132      454    1  0.0  1.0
# 3   14.0  0.0     1.522780     1381    1  0.0  1.0
# 4    8.0  0.0     0.124313       37    1  0.0  1.0
# 5   20.0  0.0     1.618400     2126    1  0.0  1.0
# 6   18.0  0.0     1.277434     1782    1  0.0  1.0
# 7   21.0  0.0     8.451339      746    1  0.0  1.0
# 8   27.0  0.0    52.613922    35315    1  0.0  1.0
# 9   19.0  0.0     1.310263     2240    1  0.0  1.0
# 10  40.0  0.0   101.596436    29899    1  0.0  1.0
# 11  33.0  0.0    64.007145    16666    1  0.0  1.0
# 12  39.0  0.0   134.044474    33542    1  0.0  1.0
# 13  47.0  0.0  2671.571350  2058303    1  0.0  1.0
# 14  38.0  0.0   167.259387    57377    1  0.0  1.0

# %%
tab = pd.DataFrame({
    'instance':"n60_k3",
    'form':'edge2',
    'method':'mip',
    'bb':mip2_n60_k3['bb'].mean(),
    'bs':mip2_n60_k3['bs'].mean(),
    'gap':mip2_n60_k3['gap'].mean(),
    'time':mip2_n60_k3['time'].mean(),
    'nodes':mip2_n60_k3['nodes'].mean(),
    'opt':mip2_n60_k3['opt'].sum(),
    'lp':mip2_n60_k3['lp'].mean(),
    'glp':mip2_n60_k3['glp'].mean()
    },index=[""]
)

mip2_n60_k3 = pd.concat([mip2_n60_k3,tab])
mip2_n60_k3
# Out:
#                                              instance   form method  \
# 0   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge2    mip
# 1   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge2    mip
# 2   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge2    mip
# 3   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge2    mip
# 4   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge2    mip
# 5   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge2    mip
# 6   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge2    mip
# 7   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge2    mip
# 8   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge2    mip
# 9   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge2    mip
# 10  data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err2...  edge2    mip
# 11  data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err2...  edge2    mip
# 12  data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err2...  edge2    mip
# 13  data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err2...  edge2    mip
# 14  data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err2...  edge2    mip
#                                                n60_k3  edge2    mip
#
#            bb         bs  gap         time      nodes  opt   lp  glp
# 0   13.000000  13.000000  0.0     0.592326      379.0    1  0.0  1.0
# 1    8.000000   8.000000  0.0     0.322971      150.0    1  0.0  1.0
# 2   14.000000  14.000000  0.0     0.612132      454.0    1  0.0  1.0
# 3   14.000000  14.000000  0.0     1.522780     1381.0    1  0.0  1.0
# 4    8.000000   8.000000  0.0     0.124313       37.0    1  0.0  1.0
# 5   20.000000  20.000000  0.0     1.618400     2126.0    1  0.0  1.0
# 6   18.000000  18.000000  0.0     1.277434     1782.0    1  0.0  1.0
# 7   21.000000  21.000000  0.0     8.451339      746.0    1  0.0  1.0
# 8   27.000000  27.000000  0.0    52.613922    35315.0    1  0.0  1.0
# 9   19.000000  19.000000  0.0     1.310263     2240.0    1  0.0  1.0
# 10  40.000000  40.000000  0.0   101.596436    29899.0    1  0.0  1.0
# 11  33.000000  33.000000  0.0    64.007145    16666.0    1  0.0  1.0
# 12  39.000000  39.000000  0.0   134.044474    33542.0    1  0.0  1.0
# 13  47.000000  47.000000  0.0  2671.571350  2058303.0    1  0.0  1.0
# 14  38.000000  38.000000  0.0   167.259387    57377.0    1  0.0  1.0
#     23.933333  23.933333  0.0   213.794978   149359.8   15  0.0  1.0

# %%
mip2_n60_k3['instance'] = mip2_n60_k3['instance'].str.replace('data/kmbs/RANDOM/random_','')
mip2_n60_k3['instance'] = mip2_n60_k3['instance'].str.replace('_','\_') 
#mip2_n60_k3

print(mip2_n60_k3[['instance','form','bs','gap','time','nodes','opt','lp','glp']].to_latex(index=False,float_format="%.2f"))
# Out:
# \begin{tabular}{llrrrrrrr}
# \toprule
# instance & form & bs & gap & time & nodes & opt & lp & glp \\
# \midrule
# n60\_k3\_pos30\_neg5\_err5\_1.g & edge2 & 13.00 & 0.00 & 0.59 & 379.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err5\_2.g & edge2 & 8.00 & 0.00 & 0.32 & 150.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err5\_3.g & edge2 & 14.00 & 0.00 & 0.61 & 454.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err5\_4.g & edge2 & 14.00 & 0.00 & 1.52 & 1381.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err5\_5.g & edge2 & 8.00 & 0.00 & 0.12 & 37.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err10\_1.g & edge2 & 20.00 & 0.00 & 1.62 & 2126.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err10\_2.g & edge2 & 18.00 & 0.00 & 1.28 & 1782.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err10\_3.g & edge2 & 21.00 & 0.00 & 8.45 & 746.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err10\_4.g & edge2 & 27.00 & 0.00 & 52.61 & 35315.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err10\_5.g & edge2 & 19.00 & 0.00 & 1.31 & 2240.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err20\_1.g & edge2 & 40.00 & 0.00 & 101.60 & 29899.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err20\_2.g & edge2 & 33.00 & 0.00 & 64.01 & 16666.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err20\_3.g & edge2 & 39.00 & 0.00 & 134.04 & 33542.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err20\_4.g & edge2 & 47.00 & 0.00 & 2671.57 & 2058303.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err20\_5.g & edge2 & 38.00 & 0.00 & 167.26 & 57377.00 & 1 & 0.00 & 1.00 \\
# n60\_k3 & edge2 & 23.93 & 0.00 & 213.79 & 149359.80 & 15 & 0.00 & 1.00 \\
# \bottomrule
# \end{tabular}

# %%
mip2_n60_k4['lp'] = lp2_n60_k4['bs']
mip2_n60_k4['glp'] = (mip2_n60_k4['bs'] - lp2_n60_k4['bs'])/mip2_n60_k4['bs']

mip2_n60_k4
# Out:
#                                              instance   form method    bb  \
# 0   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge2    mip  12.0
# 1   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge2    mip  14.0
# 2   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge2    mip  13.0
# 3   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge2    mip  21.0
# 4   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge2    mip  16.0
# 5   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge2    mip  19.0
# 6   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge2    mip  19.0
# 7   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge2    mip  20.0
# 8   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge2    mip  21.0
# 9   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge2    mip  22.0
# 10  data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err2...  edge2    mip  28.0
# 11  data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err2...  edge2    mip  31.0
# 12  data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err2...  edge2    mip  34.0
# 13  data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err2...  edge2    mip  29.0
# 14  data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err2...  edge2    mip  34.0
#
#       bs  gap        time  nodes  opt   lp  glp
# 0   12.0  0.0    0.670022    770    1  0.0  1.0
# 1   14.0  0.0    1.818421   2557    1  0.0  1.0
# 2   13.0  0.0    0.768198    839    1  0.0  1.0
# 3   21.0  0.0   17.694059  10423    1  0.0  1.0
# 4   16.0  0.0    1.759425   3010    1  0.0  1.0
# 5   19.0  0.0    7.262779   7064    1  0.0  1.0
# 6   19.0  0.0    4.567353   2437    1  0.0  1.0
# 7   20.0  0.0    9.476639   8559    1  0.0  1.0
# 8   21.0  0.0    9.351215   2501    1  0.0  1.0
# 9   22.0  0.0   16.392109  11534    1  0.0  1.0
# 10  28.0  0.0   55.296921  19497    1  0.0  1.0
# 11  31.0  0.0   53.019697  25012    1  0.0  1.0
# 12  34.0  0.0  172.719193  53966    1  0.0  1.0
# 13  29.0  0.0   56.947131  18352    1  0.0  1.0
# 14  34.0  0.0  130.688444  44585    1  0.0  1.0

# %%
tab = pd.DataFrame({
    'instance':"n60_k4",
    'form':'edge2',
    'method':'mip',
    'bb':mip2_n60_k4['bb'].mean(),
    'bs':mip2_n60_k4['bs'].mean(),
    'gap':mip2_n60_k4['gap'].mean(),
    'time':mip2_n60_k4['time'].mean(),
    'nodes':mip2_n60_k4['nodes'].mean(),
    'opt':mip2_n60_k4['opt'].sum(),
    'lp':mip2_n60_k4['lp'].mean(),
    'glp':mip2_n60_k4['glp'].mean()
    },index=[""]
)

mip2_n60_k4 = pd.concat([mip2_n60_k4,tab])
mip2_n60_k4
# Out:
#                                              instance   form method    bb  \
# 0   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge2    mip  12.0
# 1   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge2    mip  14.0
# 2   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge2    mip  13.0
# 3   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge2    mip  21.0
# 4   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge2    mip  16.0
# 5   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge2    mip  19.0
# 6   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge2    mip  19.0
# 7   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge2    mip  20.0
# 8   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge2    mip  21.0
# 9   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge2    mip  22.0
# 10  data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err2...  edge2    mip  28.0
# 11  data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err2...  edge2    mip  31.0
# 12  data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err2...  edge2    mip  34.0
# 13  data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err2...  edge2    mip  29.0
# 14  data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err2...  edge2    mip  34.0
#                                                n60_k4  edge2    mip  22.2
#
#       bs  gap        time         nodes  opt   lp  glp
# 0   12.0  0.0    0.670022    770.000000    1  0.0  1.0
# 1   14.0  0.0    1.818421   2557.000000    1  0.0  1.0
# 2   13.0  0.0    0.768198    839.000000    1  0.0  1.0
# 3   21.0  0.0   17.694059  10423.000000    1  0.0  1.0
# 4   16.0  0.0    1.759425   3010.000000    1  0.0  1.0
# 5   19.0  0.0    7.262779   7064.000000    1  0.0  1.0
# 6   19.0  0.0    4.567353   2437.000000    1  0.0  1.0
# 7   20.0  0.0    9.476639   8559.000000    1  0.0  1.0
# 8   21.0  0.0    9.351215   2501.000000    1  0.0  1.0
# 9   22.0  0.0   16.392109  11534.000000    1  0.0  1.0
# 10  28.0  0.0   55.296921  19497.000000    1  0.0  1.0
# 11  31.0  0.0   53.019697  25012.000000    1  0.0  1.0
# 12  34.0  0.0  172.719193  53966.000000    1  0.0  1.0
# 13  29.0  0.0   56.947131  18352.000000    1  0.0  1.0
# 14  34.0  0.0  130.688444  44585.000000    1  0.0  1.0
#     22.2  0.0   35.895440  14073.733333   15  0.0  1.0

# %%
mip2_n60_k4['instance'] = mip2_n60_k4['instance'].str.replace('data/kmbs/RANDOM/random_','')
mip2_n60_k4['instance'] = mip2_n60_k4['instance'].str.replace('_','\_') 
#mip2_n60_k4

print(mip2_n60_k4[['instance','form','bs','gap','time','nodes','opt','lp','glp']].to_latex(index=False,float_format="%.2f"))
# Out:
# \begin{tabular}{llrrrrrrr}
# \toprule
# instance & form & bs & gap & time & nodes & opt & lp & glp \\
# \midrule
# n60\_k4\_pos30\_neg5\_err5\_1.g & edge2 & 12.00 & 0.00 & 0.67 & 770.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err5\_2.g & edge2 & 14.00 & 0.00 & 1.82 & 2557.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err5\_3.g & edge2 & 13.00 & 0.00 & 0.77 & 839.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err5\_4.g & edge2 & 21.00 & 0.00 & 17.69 & 10423.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err5\_5.g & edge2 & 16.00 & 0.00 & 1.76 & 3010.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err10\_1.g & edge2 & 19.00 & 0.00 & 7.26 & 7064.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err10\_2.g & edge2 & 19.00 & 0.00 & 4.57 & 2437.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err10\_3.g & edge2 & 20.00 & 0.00 & 9.48 & 8559.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err10\_4.g & edge2 & 21.00 & 0.00 & 9.35 & 2501.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err10\_5.g & edge2 & 22.00 & 0.00 & 16.39 & 11534.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err20\_1.g & edge2 & 28.00 & 0.00 & 55.30 & 19497.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err20\_2.g & edge2 & 31.00 & 0.00 & 53.02 & 25012.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err20\_3.g & edge2 & 34.00 & 0.00 & 172.72 & 53966.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err20\_4.g & edge2 & 29.00 & 0.00 & 56.95 & 18352.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err20\_5.g & edge2 & 34.00 & 0.00 & 130.69 & 44585.00 & 1 & 0.00 & 1.00 \\
# n60\_k4 & edge2 & 22.20 & 0.00 & 35.90 & 14073.73 & 15 & 0.00 & 1.00 \\
# \bottomrule
# \end{tabular}

# %%
mip2_n60_k5['lp'] = lp2_n60_k5['bs']
mip2_n60_k5['glp'] = (mip2_n60_k5['bs'] - lp2_n60_k2['bs'])/mip2_n60_k5['bs']

mip2_n60_k5
# Out:
#                                              instance   form method    bb  \
# 0   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge2    mip  18.0
# 1   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge2    mip  13.0
# 2   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge2    mip  14.0
# 3   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge2    mip  16.0
# 4   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge2    mip  10.0
# 5   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge2    mip  22.0
# 6   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge2    mip  18.0
# 7   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge2    mip  22.0
# 8   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge2    mip  18.0
# 9   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge2    mip  17.0
# 10  data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err2...  edge2    mip  25.0
# 11  data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err2...  edge2    mip  23.0
# 12  data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err2...  edge2    mip  23.0
# 13  data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err2...  edge2    mip  27.0
# 14  data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err2...  edge2    mip  26.0
#
#       bs  gap       time  nodes  opt   lp  glp
# 0   18.0  0.0   7.057456   6074    1  0.0  1.0
# 1   13.0  0.0   4.539970   3697    1  0.0  1.0
# 2   14.0  0.0   1.164195   2097    1  0.0  1.0
# 3   16.0  0.0   4.094858   2495    1  0.0  1.0
# 4   10.0  0.0   1.046793   1586    1  0.0  1.0
# 5   22.0  0.0  20.642300   6823    1  0.0  1.0
# 6   18.0  0.0   5.932356   3192    1  0.0  1.0
# 7   22.0  0.0   7.690631   2139    1  0.0  1.0
# 8   18.0  0.0  19.863235  16693    1  0.0  1.0
# 9   17.0  0.0   3.547748   2446    1  0.0  1.0
# 10  25.0  0.0  55.906832  28758    1  0.0  1.0
# 11  23.0  0.0  22.328037  13178    1  0.0  1.0
# 12  23.0  0.0   9.407271   3294    1  0.0  1.0
# 13  27.0  0.0  30.931963  15440    1  0.0  1.0
# 14  26.0  0.0  56.821747  19811    1  0.0  1.0

# %%
tab = pd.DataFrame({
    'instance':"n60_k5",
    'form':'edge2',
    'method':'mip',
    'bb':mip2_n60_k5['bb'].mean(),
    'bs':mip2_n60_k5['bs'].mean(),
    'gap':mip2_n60_k5['gap'].mean(),
    'time':mip2_n60_k5['time'].mean(),
    'nodes':mip2_n60_k5['nodes'].mean(),
    'opt':mip2_n60_k5['opt'].sum(),
    'lp':mip2_n60_k5['lp'].mean(),
    'glp':mip2_n60_k5['glp'].mean()
    },index=[""]
)

mip2_n60_k5 = pd.concat([mip2_n60_k5,tab])
mip2_n60_k5
# Out:
#                                              instance   form method  \
# 0   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge2    mip
# 1   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge2    mip
# 2   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge2    mip
# 3   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge2    mip
# 4   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge2    mip
# 5   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge2    mip
# 6   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge2    mip
# 7   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge2    mip
# 8   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge2    mip
# 9   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge2    mip
# 10  data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err2...  edge2    mip
# 11  data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err2...  edge2    mip
# 12  data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err2...  edge2    mip
# 13  data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err2...  edge2    mip
# 14  data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err2...  edge2    mip
#                                                n60_k5  edge2    mip
#
#            bb         bs  gap       time         nodes  opt   lp  glp
# 0   18.000000  18.000000  0.0   7.057456   6074.000000    1  0.0  1.0
# 1   13.000000  13.000000  0.0   4.539970   3697.000000    1  0.0  1.0
# 2   14.000000  14.000000  0.0   1.164195   2097.000000    1  0.0  1.0
# 3   16.000000  16.000000  0.0   4.094858   2495.000000    1  0.0  1.0
# 4   10.000000  10.000000  0.0   1.046793   1586.000000    1  0.0  1.0
# 5   22.000000  22.000000  0.0  20.642300   6823.000000    1  0.0  1.0
# 6   18.000000  18.000000  0.0   5.932356   3192.000000    1  0.0  1.0
# 7   22.000000  22.000000  0.0   7.690631   2139.000000    1  0.0  1.0
# 8   18.000000  18.000000  0.0  19.863235  16693.000000    1  0.0  1.0
# 9   17.000000  17.000000  0.0   3.547748   2446.000000    1  0.0  1.0
# 10  25.000000  25.000000  0.0  55.906832  28758.000000    1  0.0  1.0
# 11  23.000000  23.000000  0.0  22.328037  13178.000000    1  0.0  1.0
# 12  23.000000  23.000000  0.0   9.407271   3294.000000    1  0.0  1.0
# 13  27.000000  27.000000  0.0  30.931963  15440.000000    1  0.0  1.0
# 14  26.000000  26.000000  0.0  56.821747  19811.000000    1  0.0  1.0
#     19.466667  19.466667  0.0  16.731693   8514.866667   15  0.0  1.0

# %%
mip2_n60_k5['instance'] = mip2_n60_k5['instance'].str.replace('data/kmbs/RANDOM/random_','')
mip2_n60_k5['instance'] = mip2_n60_k5['instance'].str.replace('_','\_') 
#mip2_n60_k5

print(mip2_n60_k5[['instance','form','bs','gap','time','nodes','opt','lp','glp']].to_latex(index=False,float_format="%.2f"))
# Out:
# \begin{tabular}{llrrrrrrr}
# \toprule
# instance & form & bs & gap & time & nodes & opt & lp & glp \\
# \midrule
# n60\_k5\_pos30\_neg5\_err5\_1.g & edge2 & 18.00 & 0.00 & 7.06 & 6074.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err5\_2.g & edge2 & 13.00 & 0.00 & 4.54 & 3697.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err5\_3.g & edge2 & 14.00 & 0.00 & 1.16 & 2097.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err5\_4.g & edge2 & 16.00 & 0.00 & 4.09 & 2495.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err5\_5.g & edge2 & 10.00 & 0.00 & 1.05 & 1586.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err10\_1.g & edge2 & 22.00 & 0.00 & 20.64 & 6823.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err10\_2.g & edge2 & 18.00 & 0.00 & 5.93 & 3192.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err10\_3.g & edge2 & 22.00 & 0.00 & 7.69 & 2139.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err10\_4.g & edge2 & 18.00 & 0.00 & 19.86 & 16693.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err10\_5.g & edge2 & 17.00 & 0.00 & 3.55 & 2446.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err20\_1.g & edge2 & 25.00 & 0.00 & 55.91 & 28758.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err20\_2.g & edge2 & 23.00 & 0.00 & 22.33 & 13178.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err20\_3.g & edge2 & 23.00 & 0.00 & 9.41 & 3294.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err20\_4.g & edge2 & 27.00 & 0.00 & 30.93 & 15440.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err20\_5.g & edge2 & 26.00 & 0.00 & 56.82 & 19811.00 & 1 & 0.00 & 1.00 \\
# n60\_k5 & edge2 & 19.47 & 0.00 & 16.73 & 8514.87 & 15 & 0.00 & 1.00 \\
# \bottomrule
# \end{tabular}

# %%
form_="edge3"
method_="lp"

k_ = 2

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

lp3_n60_k2 = pd.DataFrame()
lp3_n60_k2 = pd.concat([lp3_n60_k2, df], ignore_index=True)
lp3_n60_k2.columns = ['instance','form','method','bs','time']
#lp3_n60_k2

k_ = 3

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

lp3_n60_k3 = pd.DataFrame()
lp3_n60_k3 = pd.concat([lp3_n60_k3, df], ignore_index=True)
lp3_n60_k3.columns = ['instance','form','method','bs','time']
#lp3_n60_k3

k_ = 4

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

lp3_n60_k4 = pd.DataFrame()
lp3_n60_k4 = pd.concat([lp3_n60_k4, df], ignore_index=True)
lp3_n60_k4.columns = ['instance','form','method','bs','time']
#lp3_n60_k4

k_ = 5

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

lp3_n60_k5 = pd.DataFrame()
lp3_n60_k5 = pd.concat([lp3_n60_k5, df], ignore_index=True)
lp3_n60_k5.columns = ['instance','form','method','bs','time']
#lp3_n60_k5

# %%
form_="edge3"
method_="mip"

k_ = 2

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

mip3_n60_k2 = pd.DataFrame()
mip3_n60_k2 = pd.concat([mip3_n60_k2, df], ignore_index=True)
mip3_n60_k2.columns = ['instance','form','method','bb','bs','gap','time','nodes','opt']


k_ = 3

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

mip3_n60_k3 = pd.DataFrame()
mip3_n60_k3 = pd.concat([mip3_n60_k3, df], ignore_index=True)
mip3_n60_k3.columns = ['instance','form','method','bb','bs','gap','time','nodes','opt']


k_ = 4

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

mip3_n60_k4 = pd.DataFrame()
mip3_n60_k4 = pd.concat([mip3_n60_k4, df], ignore_index=True)
mip3_n60_k4.columns = ['instance','form','method','bb','bs','gap','time','nodes','opt']


k_ = 4

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

mip3_n60_k4 = pd.DataFrame()
mip3_n60_k4 = pd.concat([mip3_n60_k4, df], ignore_index=True)
mip3_n60_k4.columns = ['instance','form','method','bb','bs','gap','time','nodes','opt']


k_ = 5

file=f"{method_}_random_n{n_}_k{k_}_f{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

mip3_n60_k5 = pd.DataFrame()
mip3_n60_k5 = pd.concat([mip3_n60_k5, df], ignore_index=True)
mip3_n60_k5.columns = ['instance','form','method','bb','bs','gap','time','nodes','opt']

# %%
mip3_n60_k2['lp'] = lp3_n60_k2['bs']
mip3_n60_k2['glp'] = (mip3_n60_k2['bs'] - lp3_n60_k2['bs'])/mip3_n60_k2['bs']

mip3_n60_k2
# Out:
#                                              instance   form method    bb  \
# 0   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge3    mip  23.0
# 1   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge3    mip  11.0
# 2   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge3    mip   9.0
# 3   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge3    mip  13.0
# 4   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge3    mip  13.0
# 5   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge3    mip  38.0
# 6   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge3    mip  24.0
# 7   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge3    mip  33.0
# 8   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge3    mip  35.0
# 9   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge3    mip  25.0
# 10  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge3    mip  61.0
# 11  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge3    mip  50.0
# 12  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge3    mip  62.0
# 13  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge3    mip  65.0
# 14  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge3    mip  54.0
#
#       bs  gap        time  nodes  opt   lp  glp
# 0   23.0  0.0    3.439196     39    1  0.0  1.0
# 1   11.0  0.0    1.079528     15    1  0.0  1.0
# 2    9.0  0.0    1.496095      7    1  0.0  1.0
# 3   13.0  0.0    2.125154     17    1  0.0  1.0
# 4   13.0  0.0    1.511922     13    1  0.0  1.0
# 5   38.0  0.0   10.233518    309    1  0.0  1.0
# 6   24.0  0.0    3.340771     37    1  0.0  1.0
# 7   33.0  0.0    4.114115     73    1  0.0  1.0
# 8   35.0  0.0    6.076345    131    1  0.0  1.0
# 9   25.0  0.0    3.499630     55    1  0.0  1.0
# 10  61.0  0.0  142.196924   9752    1  0.0  1.0
# 11  50.0  0.0   19.310089    935    1  0.0  1.0
# 12  62.0  0.0   54.768517   2987    1  0.0  1.0
# 13  65.0  0.0  117.274410   5394    1  0.0  1.0
# 14  54.0  0.0   46.174778   2766    1  0.0  1.0

# %%
tab = pd.DataFrame({
    'instance':"n60_k2",
    'form':'edge3',
    'method':'mip',
    'bb':mip3_n60_k2['bb'].mean(),
    'bs':mip3_n60_k2['bs'].mean(),
    'gap':mip3_n60_k2['gap'].mean(),
    'time':mip3_n60_k2['time'].mean(),
    'nodes':mip3_n60_k2['nodes'].mean(),
    'opt':mip3_n60_k2['opt'].sum(),
    'lp':mip3_n60_k2['lp'].mean(),
    'glp':mip3_n60_k2['glp'].mean()
    },index=[""]
)

mip3_n60_k2 = pd.concat([mip3_n60_k2,tab])
mip3_n60_k2
# Out:
#                                              instance   form method    bb  \
# 0   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge3    mip  23.0
# 1   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge3    mip  11.0
# 2   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge3    mip   9.0
# 3   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge3    mip  13.0
# 4   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err5...  edge3    mip  13.0
# 5   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge3    mip  38.0
# 6   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge3    mip  24.0
# 7   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge3    mip  33.0
# 8   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge3    mip  35.0
# 9   data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err1...  edge3    mip  25.0
# 10  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge3    mip  61.0
# 11  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge3    mip  50.0
# 12  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge3    mip  62.0
# 13  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge3    mip  65.0
# 14  data/kmbs/RANDOM/random_n60_k2_pos30_neg5_err2...  edge3    mip  54.0
#                                                n60_k2  edge3    mip  34.4
#
#       bs  gap        time   nodes  opt   lp  glp
# 0   23.0  0.0    3.439196    39.0    1  0.0  1.0
# 1   11.0  0.0    1.079528    15.0    1  0.0  1.0
# 2    9.0  0.0    1.496095     7.0    1  0.0  1.0
# 3   13.0  0.0    2.125154    17.0    1  0.0  1.0
# 4   13.0  0.0    1.511922    13.0    1  0.0  1.0
# 5   38.0  0.0   10.233518   309.0    1  0.0  1.0
# 6   24.0  0.0    3.340771    37.0    1  0.0  1.0
# 7   33.0  0.0    4.114115    73.0    1  0.0  1.0
# 8   35.0  0.0    6.076345   131.0    1  0.0  1.0
# 9   25.0  0.0    3.499630    55.0    1  0.0  1.0
# 10  61.0  0.0  142.196924  9752.0    1  0.0  1.0
# 11  50.0  0.0   19.310089   935.0    1  0.0  1.0
# 12  62.0  0.0   54.768517  2987.0    1  0.0  1.0
# 13  65.0  0.0  117.274410  5394.0    1  0.0  1.0
# 14  54.0  0.0   46.174778  2766.0    1  0.0  1.0
#     34.4  0.0   27.776066  1502.0   15  0.0  1.0

# %%
mip3_n60_k2['instance'] = mip3_n60_k2['instance'].str.replace('data/kmbs/RANDOM/random_','')
mip3_n60_k2['instance'] = mip3_n60_k2['instance'].str.replace('_','\_') 
#mip3_n60_k2

print(mip3_n60_k2[['instance','form','bs','gap','time','nodes','opt','lp','glp']].to_latex(index=False,float_format="%.2f"))
# Out:
# \begin{tabular}{llrrrrrrr}
# \toprule
# instance & form & bs & gap & time & nodes & opt & lp & glp \\
# \midrule
# n60\_k2\_pos30\_neg5\_err5\_1.g & edge3 & 23.00 & 0.00 & 3.44 & 39.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err5\_2.g & edge3 & 11.00 & 0.00 & 1.08 & 15.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err5\_3.g & edge3 & 9.00 & 0.00 & 1.50 & 7.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err5\_4.g & edge3 & 13.00 & 0.00 & 2.13 & 17.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err5\_5.g & edge3 & 13.00 & 0.00 & 1.51 & 13.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err10\_1.g & edge3 & 38.00 & 0.00 & 10.23 & 309.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err10\_2.g & edge3 & 24.00 & 0.00 & 3.34 & 37.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err10\_3.g & edge3 & 33.00 & 0.00 & 4.11 & 73.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err10\_4.g & edge3 & 35.00 & 0.00 & 6.08 & 131.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err10\_5.g & edge3 & 25.00 & 0.00 & 3.50 & 55.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err20\_1.g & edge3 & 61.00 & 0.00 & 142.20 & 9752.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err20\_2.g & edge3 & 50.00 & 0.00 & 19.31 & 935.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err20\_3.g & edge3 & 62.00 & 0.00 & 54.77 & 2987.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err20\_4.g & edge3 & 65.00 & 0.00 & 117.27 & 5394.00 & 1 & 0.00 & 1.00 \\
# n60\_k2\_pos30\_neg5\_err20\_5.g & edge3 & 54.00 & 0.00 & 46.17 & 2766.00 & 1 & 0.00 & 1.00 \\
# n60\_k2 & edge3 & 34.40 & 0.00 & 27.78 & 1502.00 & 15 & 0.00 & 1.00 \\
# \bottomrule
# \end{tabular}

# %%
mip3_n60_k3['lp'] = lp3_n60_k3['bs']
mip3_n60_k3['glp'] = (mip3_n60_k3['bs'] - lp3_n60_k3['bs'])/mip3_n60_k3['bs']

mip3_n60_k3
# Out:
#                                              instance   form method    bb  \
# 0   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge3    mip  13.0
# 1   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge3    mip   8.0
# 2   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge3    mip  14.0
# 3   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge3    mip  14.0
# 4   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge3    mip   8.0
# 5   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge3    mip  20.0
# 6   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge3    mip  18.0
# 7   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge3    mip  21.0
# 8   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge3    mip  27.0
# 9   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge3    mip  19.0
# 10  data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err2...  edge3    mip  40.0
# 11  data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err2...  edge3    mip  33.0
# 12  data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err2...  edge3    mip  39.0
# 13  data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err2...  edge3    mip  47.0
# 14  data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err2...  edge3    mip  38.0
#
#       bs  gap        time  nodes  opt   lp  glp
# 0   13.0  0.0    2.049429     27    1  0.0  1.0
# 1    8.0  0.0    1.208748     11    1  0.0  1.0
# 2   14.0  0.0    1.610423     45    1  0.0  1.0
# 3   14.0  0.0    2.097015     17    1  0.0  1.0
# 4    8.0  0.0    1.235205      0    1  0.0  1.0
# 5   20.0  0.0    4.000728     55    1  0.0  1.0
# 6   18.0  0.0    3.021103     31    1  0.0  1.0
# 7   21.0  0.0    4.096527    157    1  0.0  1.0
# 8   27.0  0.0    5.556809    252    1  0.0  1.0
# 9   19.0  0.0    3.554172     79    1  0.0  1.0
# 10  40.0  0.0   19.181290   2993    1  0.0  1.0
# 11  33.0  0.0   10.103166   1270    1  0.0  1.0
# 12  39.0  0.0   54.964217   5794    1  0.0  1.0
# 13  47.0  0.0  111.782577  10409    1  0.0  1.0
# 14  38.0  0.0   48.219096   8030    1  0.0  1.0

# %%
tab = pd.DataFrame({
    'instance':"n60_k3",
    'form':'edge3',
    'method':'mip',
    'bb':mip3_n60_k3['bb'].mean(),
    'bs':mip3_n60_k3['bs'].mean(),
    'gap':mip3_n60_k3['gap'].mean(),
    'time':mip3_n60_k3['time'].mean(),
    'nodes':mip3_n60_k3['nodes'].mean(),
    'opt':mip3_n60_k3['opt'].sum(),
    'lp':mip3_n60_k3['lp'].mean(),
    'glp':mip3_n60_k3['glp'].mean()
    },index=[""]
)

mip3_n60_k3 = pd.concat([mip3_n60_k3,tab])
mip3_n60_k3
# Out:
#                                              instance   form method  \
# 0   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge3    mip
# 1   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge3    mip
# 2   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge3    mip
# 3   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge3    mip
# 4   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err5...  edge3    mip
# 5   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge3    mip
# 6   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge3    mip
# 7   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge3    mip
# 8   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge3    mip
# 9   data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err1...  edge3    mip
# 10  data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err2...  edge3    mip
# 11  data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err2...  edge3    mip
# 12  data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err2...  edge3    mip
# 13  data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err2...  edge3    mip
# 14  data/kmbs/RANDOM/random_n60_k3_pos30_neg5_err2...  edge3    mip
#                                                n60_k3  edge3    mip
#
#            bb         bs  gap        time         nodes  opt   lp  glp
# 0   13.000000  13.000000  0.0    2.049429     27.000000    1  0.0  1.0
# 1    8.000000   8.000000  0.0    1.208748     11.000000    1  0.0  1.0
# 2   14.000000  14.000000  0.0    1.610423     45.000000    1  0.0  1.0
# 3   14.000000  14.000000  0.0    2.097015     17.000000    1  0.0  1.0
# 4    8.000000   8.000000  0.0    1.235205      0.000000    1  0.0  1.0
# 5   20.000000  20.000000  0.0    4.000728     55.000000    1  0.0  1.0
# 6   18.000000  18.000000  0.0    3.021103     31.000000    1  0.0  1.0
# 7   21.000000  21.000000  0.0    4.096527    157.000000    1  0.0  1.0
# 8   27.000000  27.000000  0.0    5.556809    252.000000    1  0.0  1.0
# 9   19.000000  19.000000  0.0    3.554172     79.000000    1  0.0  1.0
# 10  40.000000  40.000000  0.0   19.181290   2993.000000    1  0.0  1.0
# 11  33.000000  33.000000  0.0   10.103166   1270.000000    1  0.0  1.0
# 12  39.000000  39.000000  0.0   54.964217   5794.000000    1  0.0  1.0
# 13  47.000000  47.000000  0.0  111.782577  10409.000000    1  0.0  1.0
# 14  38.000000  38.000000  0.0   48.219096   8030.000000    1  0.0  1.0
#     23.933333  23.933333  0.0   18.178700   1944.666667   15  0.0  1.0

# %%
mip3_n60_k3['instance'] = mip3_n60_k3['instance'].str.replace('data/kmbs/RANDOM/random_','')
mip3_n60_k3['instance'] = mip3_n60_k3['instance'].str.replace('_','\_') 
#mip3_n60_k3

print(mip3_n60_k3[['instance','form','bs','gap','time','nodes','opt','lp','glp']].to_latex(index=False,float_format="%.2f"))
# Out:
# \begin{tabular}{llrrrrrrr}
# \toprule
# instance & form & bs & gap & time & nodes & opt & lp & glp \\
# \midrule
# n60\_k3\_pos30\_neg5\_err5\_1.g & edge3 & 13.00 & 0.00 & 2.05 & 27.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err5\_2.g & edge3 & 8.00 & 0.00 & 1.21 & 11.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err5\_3.g & edge3 & 14.00 & 0.00 & 1.61 & 45.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err5\_4.g & edge3 & 14.00 & 0.00 & 2.10 & 17.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err5\_5.g & edge3 & 8.00 & 0.00 & 1.24 & 0.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err10\_1.g & edge3 & 20.00 & 0.00 & 4.00 & 55.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err10\_2.g & edge3 & 18.00 & 0.00 & 3.02 & 31.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err10\_3.g & edge3 & 21.00 & 0.00 & 4.10 & 157.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err10\_4.g & edge3 & 27.00 & 0.00 & 5.56 & 252.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err10\_5.g & edge3 & 19.00 & 0.00 & 3.55 & 79.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err20\_1.g & edge3 & 40.00 & 0.00 & 19.18 & 2993.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err20\_2.g & edge3 & 33.00 & 0.00 & 10.10 & 1270.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err20\_3.g & edge3 & 39.00 & 0.00 & 54.96 & 5794.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err20\_4.g & edge3 & 47.00 & 0.00 & 111.78 & 10409.00 & 1 & 0.00 & 1.00 \\
# n60\_k3\_pos30\_neg5\_err20\_5.g & edge3 & 38.00 & 0.00 & 48.22 & 8030.00 & 1 & 0.00 & 1.00 \\
# n60\_k3 & edge3 & 23.93 & 0.00 & 18.18 & 1944.67 & 15 & 0.00 & 1.00 \\
# \bottomrule
# \end{tabular}

# %%
mip3_n60_k4['lp'] = lp3_n60_k4['bs']
mip3_n60_k4['glp'] = (mip3_n60_k4['bs'] - lp3_n60_k4['bs'])/mip3_n60_k4['bs']

mip3_n60_k4
# Out:
#                                              instance   form method    bb  \
# 0   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge3    mip  12.0
# 1   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge3    mip  14.0
# 2   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge3    mip  13.0
# 3   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge3    mip  21.0
# 4   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge3    mip  16.0
# 5   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge3    mip  19.0
# 6   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge3    mip  19.0
# 7   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge3    mip  20.0
# 8   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge3    mip  21.0
# 9   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge3    mip  22.0
# 10  data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err2...  edge3    mip  28.0
# 11  data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err2...  edge3    mip  31.0
# 12  data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err2...  edge3    mip  34.0
# 13  data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err2...  edge3    mip  29.0
# 14  data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err2...  edge3    mip  34.0
#
#       bs  gap       time  nodes  opt   lp  glp
# 0   12.0  0.0   1.708138     49    1  0.0  1.0
# 1   14.0  0.0   1.698457    170    1  0.0  1.0
# 2   13.0  0.0   1.620808     51    1  0.0  1.0
# 3   21.0  0.0   4.463757    249    1  0.0  1.0
# 4   16.0  0.0   2.109869    144    1  0.0  1.0
# 5   19.0  0.0   3.281901    228    1  0.0  1.0
# 6   19.0  0.0   3.070512    397    1  0.0  1.0
# 7   20.0  0.0   3.390593    225    1  0.0  1.0
# 8   21.0  0.0   3.644062    360    1  0.0  1.0
# 9   22.0  0.0   3.418184    305    1  0.0  1.0
# 10  28.0  0.0   7.694439   1503    1  0.0  1.0
# 11  31.0  0.0  25.158935   3766    1  0.0  1.0
# 12  34.0  0.0  28.105372   4945    1  0.0  1.0
# 13  29.0  0.0  15.408527   3337    1  0.0  1.0
# 14  34.0  0.0  44.431732   8092    1  0.0  1.0

# %%
tab = pd.DataFrame({
    'instance':"n60_k4",
    'form':'edge3',
    'method':'mip',
    'bb':mip3_n60_k4['bb'].mean(),
    'bs':mip3_n60_k4['bs'].mean(),
    'gap':mip3_n60_k4['gap'].mean(),
    'time':mip3_n60_k4['time'].mean(),
    'nodes':mip3_n60_k4['nodes'].mean(),
    'opt':mip3_n60_k4['opt'].sum(),
    'lp':mip3_n60_k4['lp'].mean(),
    'glp':mip3_n60_k4['glp'].mean()
    },index=[""]
)

mip3_n60_k4 = pd.concat([mip3_n60_k4,tab])
mip3_n60_k4
# Out:
#                                              instance   form method    bb  \
# 0   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge3    mip  12.0
# 1   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge3    mip  14.0
# 2   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge3    mip  13.0
# 3   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge3    mip  21.0
# 4   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err5...  edge3    mip  16.0
# 5   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge3    mip  19.0
# 6   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge3    mip  19.0
# 7   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge3    mip  20.0
# 8   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge3    mip  21.0
# 9   data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err1...  edge3    mip  22.0
# 10  data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err2...  edge3    mip  28.0
# 11  data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err2...  edge3    mip  31.0
# 12  data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err2...  edge3    mip  34.0
# 13  data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err2...  edge3    mip  29.0
# 14  data/kmbs/RANDOM/random_n60_k4_pos30_neg5_err2...  edge3    mip  34.0
#                                                n60_k4  edge3    mip  22.2
#
#       bs  gap       time        nodes  opt   lp  glp
# 0   12.0  0.0   1.708138    49.000000    1  0.0  1.0
# 1   14.0  0.0   1.698457   170.000000    1  0.0  1.0
# 2   13.0  0.0   1.620808    51.000000    1  0.0  1.0
# 3   21.0  0.0   4.463757   249.000000    1  0.0  1.0
# 4   16.0  0.0   2.109869   144.000000    1  0.0  1.0
# 5   19.0  0.0   3.281901   228.000000    1  0.0  1.0
# 6   19.0  0.0   3.070512   397.000000    1  0.0  1.0
# 7   20.0  0.0   3.390593   225.000000    1  0.0  1.0
# 8   21.0  0.0   3.644062   360.000000    1  0.0  1.0
# 9   22.0  0.0   3.418184   305.000000    1  0.0  1.0
# 10  28.0  0.0   7.694439  1503.000000    1  0.0  1.0
# 11  31.0  0.0  25.158935  3766.000000    1  0.0  1.0
# 12  34.0  0.0  28.105372  4945.000000    1  0.0  1.0
# 13  29.0  0.0  15.408527  3337.000000    1  0.0  1.0
# 14  34.0  0.0  44.431732  8092.000000    1  0.0  1.0
#     22.2  0.0   9.947019  1588.066667   15  0.0  1.0

# %%
mip3_n60_k4['instance'] = mip3_n60_k4['instance'].str.replace('data/kmbs/RANDOM/random_','')
mip3_n60_k4['instance'] = mip3_n60_k4['instance'].str.replace('_','\_') 
#mip3_n60_k4

print(mip3_n60_k4[['instance','form','bs','gap','time','nodes','opt','lp','glp']].to_latex(index=False,float_format="%.2f"))
# Out:
# \begin{tabular}{llrrrrrrr}
# \toprule
# instance & form & bs & gap & time & nodes & opt & lp & glp \\
# \midrule
# n60\_k4\_pos30\_neg5\_err5\_1.g & edge3 & 12.00 & 0.00 & 1.71 & 49.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err5\_2.g & edge3 & 14.00 & 0.00 & 1.70 & 170.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err5\_3.g & edge3 & 13.00 & 0.00 & 1.62 & 51.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err5\_4.g & edge3 & 21.00 & 0.00 & 4.46 & 249.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err5\_5.g & edge3 & 16.00 & 0.00 & 2.11 & 144.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err10\_1.g & edge3 & 19.00 & 0.00 & 3.28 & 228.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err10\_2.g & edge3 & 19.00 & 0.00 & 3.07 & 397.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err10\_3.g & edge3 & 20.00 & 0.00 & 3.39 & 225.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err10\_4.g & edge3 & 21.00 & 0.00 & 3.64 & 360.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err10\_5.g & edge3 & 22.00 & 0.00 & 3.42 & 305.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err20\_1.g & edge3 & 28.00 & 0.00 & 7.69 & 1503.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err20\_2.g & edge3 & 31.00 & 0.00 & 25.16 & 3766.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err20\_3.g & edge3 & 34.00 & 0.00 & 28.11 & 4945.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err20\_4.g & edge3 & 29.00 & 0.00 & 15.41 & 3337.00 & 1 & 0.00 & 1.00 \\
# n60\_k4\_pos30\_neg5\_err20\_5.g & edge3 & 34.00 & 0.00 & 44.43 & 8092.00 & 1 & 0.00 & 1.00 \\
# n60\_k4 & edge3 & 22.20 & 0.00 & 9.95 & 1588.07 & 15 & 0.00 & 1.00 \\
# \bottomrule
# \end{tabular}

# %%
mip3_n60_k5['lp'] = lp3_n60_k5['bs']
mip3_n60_k5['glp'] = (mip3_n60_k5['bs'] - lp3_n60_k2['bs'])/mip3_n60_k5['bs']

mip3_n60_k5
# Out:
#                                              instance   form method    bb  \
# 0   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge3    mip  18.0
# 1   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge3    mip  13.0
# 2   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge3    mip  14.0
# 3   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge3    mip  16.0
# 4   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge3    mip  10.0
# 5   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge3    mip  22.0
# 6   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge3    mip  18.0
# 7   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge3    mip  22.0
# 8   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge3    mip  18.0
# 9   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge3    mip  17.0
# 10  data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err2...  edge3    mip  25.0
# 11  data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err2...  edge3    mip  23.0
# 12  data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err2...  edge3    mip  23.0
# 13  data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err2...  edge3    mip  27.0
# 14  data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err2...  edge3    mip  26.0
#
#       bs  gap       time  nodes  opt   lp  glp
# 0   18.0  0.0   3.026175    635    1  0.0  1.0
# 1   13.0  0.0   1.788411    267    1  0.0  1.0
# 2   14.0  0.0   2.693398    239    1  0.0  1.0
# 3   16.0  0.0   3.150110    465    1  0.0  1.0
# 4   10.0  0.0   1.127290     66    1  0.0  1.0
# 5   22.0  0.0   6.017452   1547    1  0.0  1.0
# 6   18.0  0.0   2.478276    423    1  0.0  1.0
# 7   22.0  0.0   6.406061   1450    1  0.0  1.0
# 8   18.0  0.0   2.829756    424    1  0.0  1.0
# 9   17.0  0.0   1.621423    201    1  0.0  1.0
# 10  25.0  0.0   6.335167   1689    1  0.0  1.0
# 11  23.0  0.0   6.577866   1509    1  0.0  1.0
# 12  23.0  0.0   3.893074   1233    1  0.0  1.0
# 13  27.0  0.0  16.415525   3819    1  0.0  1.0
# 14  26.0  0.0   7.057079   1183    1  0.0  1.0

# %%
tab = pd.DataFrame({
    'instance':"n60_k5",
    'form':'edge3',
    'method':'mip',
    'bb':mip3_n60_k5['bb'].mean(),
    'bs':mip3_n60_k5['bs'].mean(),
    'gap':mip3_n60_k5['gap'].mean(),
    'time':mip3_n60_k5['time'].mean(),
    'nodes':mip3_n60_k5['nodes'].mean(),
    'opt':mip3_n60_k5['opt'].sum(),
    'lp':mip3_n60_k5['lp'].mean(),
    'glp':mip3_n60_k5['glp'].mean()
    },index=[""]
)

mip3_n60_k5 = pd.concat([mip3_n60_k5,tab])
mip3_n60_k5
# Out:
#                                              instance   form method  \
# 0   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge3    mip
# 1   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge3    mip
# 2   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge3    mip
# 3   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge3    mip
# 4   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err5...  edge3    mip
# 5   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge3    mip
# 6   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge3    mip
# 7   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge3    mip
# 8   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge3    mip
# 9   data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err1...  edge3    mip
# 10  data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err2...  edge3    mip
# 11  data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err2...  edge3    mip
# 12  data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err2...  edge3    mip
# 13  data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err2...  edge3    mip
# 14  data/kmbs/RANDOM/random_n60_k5_pos30_neg5_err2...  edge3    mip
#                                                n60_k5  edge3    mip
#
#            bb         bs  gap       time   nodes  opt   lp  glp
# 0   18.000000  18.000000  0.0   3.026175   635.0    1  0.0  1.0
# 1   13.000000  13.000000  0.0   1.788411   267.0    1  0.0  1.0
# 2   14.000000  14.000000  0.0   2.693398   239.0    1  0.0  1.0
# 3   16.000000  16.000000  0.0   3.150110   465.0    1  0.0  1.0
# 4   10.000000  10.000000  0.0   1.127290    66.0    1  0.0  1.0
# 5   22.000000  22.000000  0.0   6.017452  1547.0    1  0.0  1.0
# 6   18.000000  18.000000  0.0   2.478276   423.0    1  0.0  1.0
# 7   22.000000  22.000000  0.0   6.406061  1450.0    1  0.0  1.0
# 8   18.000000  18.000000  0.0   2.829756   424.0    1  0.0  1.0
# 9   17.000000  17.000000  0.0   1.621423   201.0    1  0.0  1.0
# 10  25.000000  25.000000  0.0   6.335167  1689.0    1  0.0  1.0
# 11  23.000000  23.000000  0.0   6.577866  1509.0    1  0.0  1.0
# 12  23.000000  23.000000  0.0   3.893074  1233.0    1  0.0  1.0
# 13  27.000000  27.000000  0.0  16.415525  3819.0    1  0.0  1.0
# 14  26.000000  26.000000  0.0   7.057079  1183.0    1  0.0  1.0
#     19.466667  19.466667  0.0   4.761138  1010.0   15  0.0  1.0

# %%
mip3_n60_k5['instance'] = mip3_n60_k5['instance'].str.replace('data/kmbs/RANDOM/random_','')
mip3_n60_k5['instance'] = mip3_n60_k5['instance'].str.replace('_','\_') 
#mip3_n60_k5

print(mip3_n60_k5[['instance','form','bs','gap','time','nodes','opt','lp','glp']].to_latex(index=False,float_format="%.2f"))
# Out:
# \begin{tabular}{llrrrrrrr}
# \toprule
# instance & form & bs & gap & time & nodes & opt & lp & glp \\
# \midrule
# n60\_k5\_pos30\_neg5\_err5\_1.g & edge3 & 18.00 & 0.00 & 3.03 & 635.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err5\_2.g & edge3 & 13.00 & 0.00 & 1.79 & 267.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err5\_3.g & edge3 & 14.00 & 0.00 & 2.69 & 239.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err5\_4.g & edge3 & 16.00 & 0.00 & 3.15 & 465.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err5\_5.g & edge3 & 10.00 & 0.00 & 1.13 & 66.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err10\_1.g & edge3 & 22.00 & 0.00 & 6.02 & 1547.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err10\_2.g & edge3 & 18.00 & 0.00 & 2.48 & 423.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err10\_3.g & edge3 & 22.00 & 0.00 & 6.41 & 1450.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err10\_4.g & edge3 & 18.00 & 0.00 & 2.83 & 424.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err10\_5.g & edge3 & 17.00 & 0.00 & 1.62 & 201.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err20\_1.g & edge3 & 25.00 & 0.00 & 6.34 & 1689.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err20\_2.g & edge3 & 23.00 & 0.00 & 6.58 & 1509.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err20\_3.g & edge3 & 23.00 & 0.00 & 3.89 & 1233.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err20\_4.g & edge3 & 27.00 & 0.00 & 16.42 & 3819.00 & 1 & 0.00 & 1.00 \\
# n60\_k5\_pos30\_neg5\_err20\_5.g & edge3 & 26.00 & 0.00 & 7.06 & 1183.00 & 1 & 0.00 & 1.00 \\
# n60\_k5 & edge3 & 19.47 & 0.00 & 4.76 & 1010.00 & 15 & 0.00 & 1.00 \\
# \bottomrule
# \end{tabular}

# %%
tab_mip_n60_k2 = pd.DataFrame()
tab_mip_n60_k2["instance"] = mip2_n60_k2['instance']
tab_mip_n60_k2["bs1"] = mip1_n60_k2['bs']
tab_mip_n60_k2["bs2"] = mip2_n60_k2['bs']
tab_mip_n60_k2["bs3"] = mip3_n60_k2['bs']
tab_mip_n60_k2["time1"] = mip1_n60_k2['time']
tab_mip_n60_k2["time2"] = mip2_n60_k2['time']
tab_mip_n60_k2["time3"] = mip3_n60_k2['time']
tab_mip_n60_k2["nodes1"] = mip1_n60_k2['nodes']
tab_mip_n60_k2["nodes2"] = mip2_n60_k2['nodes']
tab_mip_n60_k2["nodes3"] = mip3_n60_k2['nodes']

tab_mip_n60_k2
# Out:
#                             instance   bs1   bs2   bs3      time1  \
# 0    n60\_k2\_pos30\_neg5\_err5\_1.g  23.0  23.0  23.0   1.121716
# 1    n60\_k2\_pos30\_neg5\_err5\_2.g  11.0  11.0  11.0   0.226189
# 2    n60\_k2\_pos30\_neg5\_err5\_3.g   9.0   9.0   9.0   0.143083
# 3    n60\_k2\_pos30\_neg5\_err5\_4.g  13.0  13.0  13.0   0.278762
# 4    n60\_k2\_pos30\_neg5\_err5\_5.g  13.0  13.0  13.0   0.215705
# 5   n60\_k2\_pos30\_neg5\_err10\_1.g  38.0  38.0  38.0   3.197636
# 6   n60\_k2\_pos30\_neg5\_err10\_2.g  24.0  24.0  24.0   0.946683
# 7   n60\_k2\_pos30\_neg5\_err10\_3.g  33.0  33.0  33.0   1.992214
# 8   n60\_k2\_pos30\_neg5\_err10\_4.g  35.0  35.0  35.0   2.474882
# 9   n60\_k2\_pos30\_neg5\_err10\_5.g  25.0  25.0  25.0   1.001826
# 10  n60\_k2\_pos30\_neg5\_err20\_1.g  61.0  61.0  61.0  24.088452
# 11  n60\_k2\_pos30\_neg5\_err20\_2.g  50.0  50.0  50.0   7.721081
# 12  n60\_k2\_pos30\_neg5\_err20\_3.g  62.0  62.0  62.0  22.841675
# 13  n60\_k2\_pos30\_neg5\_err20\_4.g  65.0  65.0  65.0  21.662215
# 14  n60\_k2\_pos30\_neg5\_err20\_5.g  54.0  54.0  54.0   7.456811
#                              n60\_k2  34.4  34.4  34.4   6.357929
#
#           time2       time3  nodes1         nodes2  nodes3
# 0      1.241452    3.439196     9.0     711.000000    39.0
# 1      0.338198    1.079528     0.0      79.000000    15.0
# 2      0.205148    1.496095     0.0      21.000000     7.0
# 3      0.464846    2.125154     0.0     148.000000    17.0
# 4      0.405868    1.511922     3.0     159.000000    13.0
# 5     59.197714   10.233518    63.0   26639.000000   309.0
# 6      1.656975    3.340771    11.0    1036.000000    37.0
# 7     10.755289    4.114115    27.0    5242.000000    73.0
# 8     21.802125    6.076345    15.0    6752.000000   131.0
# 9      1.501103    3.499630     9.0    1391.000000    55.0
# 10  2698.829315  142.196924  2766.0  880106.000000  9752.0
# 11   178.716656   19.310089   339.0   95846.000000   935.0
# 12  1609.175977   54.768517  1387.0  862314.000000  2987.0
# 13  2301.410802  117.274410  1562.0  698231.000000  5394.0
# 14   604.666833   46.174778   328.0  165361.000000  2766.0
#      499.357887   27.776066   434.6  182935.733333  1502.0

# %%
#print(tab_mip_n60_k2[['instance','bs1','bs2','bs3','time1','time2','time3','nodes1','nodes2','nodes3']].to_latex(index=False,float_format="%.2f"))
print(tab_mip_n60_k2[['instance','time1','time2','time3','nodes1','nodes2','nodes3']].to_latex(index=False,float_format="%.2f"))
# Out:
# \begin{tabular}{lrrrrrr}
# \toprule
# instance & time1 & time2 & time3 & nodes1 & nodes2 & nodes3 \\
# \midrule
# n60\_k2\_pos30\_neg5\_err5\_1.g & 1.12 & 1.24 & 3.44 & 9.00 & 711.00 & 39.00 \\
# n60\_k2\_pos30\_neg5\_err5\_2.g & 0.23 & 0.34 & 1.08 & 0.00 & 79.00 & 15.00 \\
# n60\_k2\_pos30\_neg5\_err5\_3.g & 0.14 & 0.21 & 1.50 & 0.00 & 21.00 & 7.00 \\
# n60\_k2\_pos30\_neg5\_err5\_4.g & 0.28 & 0.46 & 2.13 & 0.00 & 148.00 & 17.00 \\
# n60\_k2\_pos30\_neg5\_err5\_5.g & 0.22 & 0.41 & 1.51 & 3.00 & 159.00 & 13.00 \\
# n60\_k2\_pos30\_neg5\_err10\_1.g & 3.20 & 59.20 & 10.23 & 63.00 & 26639.00 & 309.00 \\
# n60\_k2\_pos30\_neg5\_err10\_2.g & 0.95 & 1.66 & 3.34 & 11.00 & 1036.00 & 37.00 \\
# n60\_k2\_pos30\_neg5\_err10\_3.g & 1.99 & 10.76 & 4.11 & 27.00 & 5242.00 & 73.00 \\
# n60\_k2\_pos30\_neg5\_err10\_4.g & 2.47 & 21.80 & 6.08 & 15.00 & 6752.00 & 131.00 \\
# n60\_k2\_pos30\_neg5\_err10\_5.g & 1.00 & 1.50 & 3.50 & 9.00 & 1391.00 & 55.00 \\
# n60\_k2\_pos30\_neg5\_err20\_1.g & 24.09 & 2698.83 & 142.20 & 2766.00 & 880106.00 & 9752.00 \\
# n60\_k2\_pos30\_neg5\_err20\_2.g & 7.72 & 178.72 & 19.31 & 339.00 & 95846.00 & 935.00 \\
# n60\_k2\_pos30\_neg5\_err20\_3.g & 22.84 & 1609.18 & 54.77 & 1387.00 & 862314.00 & 2987.00 \\
# n60\_k2\_pos30\_neg5\_err20\_4.g & 21.66 & 2301.41 & 117.27 & 1562.00 & 698231.00 & 5394.00 \\
# n60\_k2\_pos30\_neg5\_err20\_5.g & 7.46 & 604.67 & 46.17 & 328.00 & 165361.00 & 2766.00 \\
# n60\_k2 & 6.36 & 499.36 & 27.78 & 434.60 & 182935.73 & 1502.00 \\
# \bottomrule
# \end{tabular}

# %%
tab_mip_n60_k3 = pd.DataFrame()
tab_mip_n60_k3["instance"] = mip2_n60_k3['instance']
tab_mip_n60_k3["bs1"] = mip1_n60_k3['bs']
tab_mip_n60_k3["bs2"] = mip2_n60_k3['bs']
tab_mip_n60_k3["bs3"] = mip3_n60_k3['bs']
tab_mip_n60_k3["time1"] = mip1_n60_k3['time']
tab_mip_n60_k3["time2"] = mip2_n60_k3['time']
tab_mip_n60_k3["time3"] = mip3_n60_k3['time']
tab_mip_n60_k3["nodes1"] = mip1_n60_k3['nodes']
tab_mip_n60_k3["nodes2"] = mip2_n60_k3['nodes']
tab_mip_n60_k3["nodes3"] = mip3_n60_k3['nodes']

tab_mip_n60_k3
# Out:
#                             instance        bs1        bs2        bs3  \
# 0    n60\_k3\_pos30\_neg5\_err5\_1.g  13.000000  13.000000  13.000000
# 1    n60\_k3\_pos30\_neg5\_err5\_2.g   8.000000   8.000000   8.000000
# 2    n60\_k3\_pos30\_neg5\_err5\_3.g  14.000000  14.000000  14.000000
# 3    n60\_k3\_pos30\_neg5\_err5\_4.g  14.000000  14.000000  14.000000
# 4    n60\_k3\_pos30\_neg5\_err5\_5.g   8.000000   8.000000   8.000000
# 5   n60\_k3\_pos30\_neg5\_err10\_1.g  20.000000  20.000000  20.000000
# 6   n60\_k3\_pos30\_neg5\_err10\_2.g  18.000000  18.000000  18.000000
# 7   n60\_k3\_pos30\_neg5\_err10\_3.g  21.000000  21.000000  21.000000
# 8   n60\_k3\_pos30\_neg5\_err10\_4.g  27.000000  27.000000  27.000000
# 9   n60\_k3\_pos30\_neg5\_err10\_5.g  19.000000  19.000000  19.000000
# 10  n60\_k3\_pos30\_neg5\_err20\_1.g  40.000000  40.000000  40.000000
# 11  n60\_k3\_pos30\_neg5\_err20\_2.g  33.000000  33.000000  33.000000
# 12  n60\_k3\_pos30\_neg5\_err20\_3.g  39.000000  39.000000  39.000000
# 13  n60\_k3\_pos30\_neg5\_err20\_4.g  47.000000  47.000000  47.000000
# 14  n60\_k3\_pos30\_neg5\_err20\_5.g  38.000000  38.000000  38.000000
#                              n60\_k3  23.933333  23.933333  23.933333
#
#         time1        time2       time3       nodes1     nodes2        nodes3
# 0    0.797308     0.592326    2.049429     8.000000      379.0     27.000000
# 1    0.342675     0.322971    1.208748     0.000000      150.0     11.000000
# 2    0.756208     0.612132    1.610423     7.000000      454.0     45.000000
# 3    0.842291     1.522780    2.097015    11.000000     1381.0     17.000000
# 4    0.090971     0.124313    1.235205     0.000000       37.0      0.000000
# 5    1.009782     1.618400    4.000728    11.000000     2126.0     55.000000
# 6    1.160428     1.277434    3.021103    11.000000     1782.0     31.000000
# 7    1.366499     8.451339    4.096527    31.000000      746.0    157.000000
# 8    2.412780    52.613922    5.556809    68.000000    35315.0    252.000000
# 9    1.846898     1.310263    3.554172    13.000000     2240.0     79.000000
# 10   8.499918   101.596436   19.181290  1190.000000    29899.0   2993.000000
# 11   5.767903    64.007145   10.103166   515.000000    16666.0   1270.000000
# 12   6.313169   134.044474   54.964217   820.000000    33542.0   5794.000000
# 13  56.695910  2671.571350  111.782577  8586.000000  2058303.0  10409.000000
# 14  11.430136   167.259387   48.219096  2197.000000    57377.0   8030.000000
#      6.622192   213.794978   18.178700   897.866667   149359.8   1944.666667

# %%
#print(tab_mip_n60_k3[['instance','bs1','bs2','bs3','time1','time2','time3','nodes1','nodes2','nodes3']].to_latex(index=False,float_format="%.2f"))
print(tab_mip_n60_k3[['instance','time1','time2','time3','nodes1','nodes2','nodes3']].to_latex(index=False,float_format="%.2f"))
# Out:
# \begin{tabular}{lrrrrrr}
# \toprule
# instance & time1 & time2 & time3 & nodes1 & nodes2 & nodes3 \\
# \midrule
# n60\_k3\_pos30\_neg5\_err5\_1.g & 0.80 & 0.59 & 2.05 & 8.00 & 379.00 & 27.00 \\
# n60\_k3\_pos30\_neg5\_err5\_2.g & 0.34 & 0.32 & 1.21 & 0.00 & 150.00 & 11.00 \\
# n60\_k3\_pos30\_neg5\_err5\_3.g & 0.76 & 0.61 & 1.61 & 7.00 & 454.00 & 45.00 \\
# n60\_k3\_pos30\_neg5\_err5\_4.g & 0.84 & 1.52 & 2.10 & 11.00 & 1381.00 & 17.00 \\
# n60\_k3\_pos30\_neg5\_err5\_5.g & 0.09 & 0.12 & 1.24 & 0.00 & 37.00 & 0.00 \\
# n60\_k3\_pos30\_neg5\_err10\_1.g & 1.01 & 1.62 & 4.00 & 11.00 & 2126.00 & 55.00 \\
# n60\_k3\_pos30\_neg5\_err10\_2.g & 1.16 & 1.28 & 3.02 & 11.00 & 1782.00 & 31.00 \\
# n60\_k3\_pos30\_neg5\_err10\_3.g & 1.37 & 8.45 & 4.10 & 31.00 & 746.00 & 157.00 \\
# n60\_k3\_pos30\_neg5\_err10\_4.g & 2.41 & 52.61 & 5.56 & 68.00 & 35315.00 & 252.00 \\
# n60\_k3\_pos30\_neg5\_err10\_5.g & 1.85 & 1.31 & 3.55 & 13.00 & 2240.00 & 79.00 \\
# n60\_k3\_pos30\_neg5\_err20\_1.g & 8.50 & 101.60 & 19.18 & 1190.00 & 29899.00 & 2993.00 \\
# n60\_k3\_pos30\_neg5\_err20\_2.g & 5.77 & 64.01 & 10.10 & 515.00 & 16666.00 & 1270.00 \\
# n60\_k3\_pos30\_neg5\_err20\_3.g & 6.31 & 134.04 & 54.96 & 820.00 & 33542.00 & 5794.00 \\
# n60\_k3\_pos30\_neg5\_err20\_4.g & 56.70 & 2671.57 & 111.78 & 8586.00 & 2058303.00 & 10409.00 \\
# n60\_k3\_pos30\_neg5\_err20\_5.g & 11.43 & 167.26 & 48.22 & 2197.00 & 57377.00 & 8030.00 \\
# n60\_k3 & 6.62 & 213.79 & 18.18 & 897.87 & 149359.80 & 1944.67 \\
# \bottomrule
# \end{tabular}

# %%
tab_mip_n60_k4 = pd.DataFrame()
tab_mip_n60_k4["instance"] = mip2_n60_k4['instance']
tab_mip_n60_k4["bs1"] = mip1_n60_k4['bs']
tab_mip_n60_k4["bs2"] = mip2_n60_k4['bs']
tab_mip_n60_k4["bs3"] = mip3_n60_k4['bs']
tab_mip_n60_k4["time1"] = mip1_n60_k4['time']
tab_mip_n60_k4["time2"] = mip2_n60_k4['time']
tab_mip_n60_k4["time3"] = mip3_n60_k4['time']
tab_mip_n60_k4["nodes1"] = mip1_n60_k4['nodes']
tab_mip_n60_k4["nodes2"] = mip2_n60_k4['nodes']
tab_mip_n60_k4["nodes3"] = mip3_n60_k4['nodes']

tab_mip_n60_k4
# Out:
#                             instance   bs1   bs2   bs3     time1       time2  \
# 0    n60\_k4\_pos30\_neg5\_err5\_1.g  12.0  12.0  12.0  0.622369    0.670022
# 1    n60\_k4\_pos30\_neg5\_err5\_2.g  14.0  14.0  14.0  0.769013    1.818421
# 2    n60\_k4\_pos30\_neg5\_err5\_3.g  13.0  13.0  13.0  0.523701    0.768198
# 3    n60\_k4\_pos30\_neg5\_err5\_4.g  21.0  21.0  21.0  2.428940   17.694059
# 4    n60\_k4\_pos30\_neg5\_err5\_5.g  16.0  16.0  16.0  0.956798    1.759425
# 5   n60\_k4\_pos30\_neg5\_err10\_1.g  19.0  19.0  19.0  1.507842    7.262779
# 6   n60\_k4\_pos30\_neg5\_err10\_2.g  19.0  19.0  19.0  1.142244    4.567353
# 7   n60\_k4\_pos30\_neg5\_err10\_3.g  20.0  20.0  20.0  1.841590    9.476639
# 8   n60\_k4\_pos30\_neg5\_err10\_4.g  21.0  21.0  21.0  1.881426    9.351215
# 9   n60\_k4\_pos30\_neg5\_err10\_5.g  22.0  22.0  22.0  1.544156   16.392109
# 10  n60\_k4\_pos30\_neg5\_err20\_1.g  28.0  28.0  28.0  3.935322   55.296921
# 11  n60\_k4\_pos30\_neg5\_err20\_2.g  31.0  31.0  31.0  5.854201   53.019697
# 12  n60\_k4\_pos30\_neg5\_err20\_3.g  34.0  34.0  34.0  6.867686  172.719193
# 13  n60\_k4\_pos30\_neg5\_err20\_4.g  29.0  29.0  29.0  4.841896   56.947131
# 14  n60\_k4\_pos30\_neg5\_err20\_5.g  34.0  34.0  34.0  7.633432  130.688444
#                              n60\_k4  22.2  22.2  22.2  2.823374   35.895440
#
#         time3       nodes1        nodes2       nodes3
# 0    1.708138    19.000000    770.000000    49.000000
# 1    1.698457    25.000000   2557.000000   170.000000
# 2    1.620808    11.000000    839.000000    51.000000
# 3    4.463757   179.000000  10423.000000   249.000000
# 4    2.109869    22.000000   3010.000000   144.000000
# 5    3.281901    72.000000   7064.000000   228.000000
# 6    3.070512    97.000000   2437.000000   397.000000
# 7    3.390593    77.000000   8559.000000   225.000000
# 8    3.644062    67.000000   2501.000000   360.000000
# 9    3.418184    97.000000  11534.000000   305.000000
# 10   7.694439   663.000000  19497.000000  1503.000000
# 11  25.158935  1269.000000  25012.000000  3766.000000
# 12  28.105372  1396.000000  53966.000000  4945.000000
# 13  15.408527  1070.000000  18352.000000  3337.000000
# 14  44.431732  1732.000000  44585.000000  8092.000000
#      9.947019   453.066667  14073.733333  1588.066667

# %%
#print(tab_mip_n60_k4[['instance','bs1','bs2','bs3','time1','time2','time3','nodes1','nodes2','nodes3']].to_latex(index=False,float_format="%.2f"))
print(tab_mip_n60_k4[['instance','time1','time2','time3','nodes1','nodes2','nodes3']].to_latex(index=False,float_format="%.2f"))
# Out:
# \begin{tabular}{lrrrrrr}
# \toprule
# instance & time1 & time2 & time3 & nodes1 & nodes2 & nodes3 \\
# \midrule
# n60\_k4\_pos30\_neg5\_err5\_1.g & 0.62 & 0.67 & 1.71 & 19.00 & 770.00 & 49.00 \\
# n60\_k4\_pos30\_neg5\_err5\_2.g & 0.77 & 1.82 & 1.70 & 25.00 & 2557.00 & 170.00 \\
# n60\_k4\_pos30\_neg5\_err5\_3.g & 0.52 & 0.77 & 1.62 & 11.00 & 839.00 & 51.00 \\
# n60\_k4\_pos30\_neg5\_err5\_4.g & 2.43 & 17.69 & 4.46 & 179.00 & 10423.00 & 249.00 \\
# n60\_k4\_pos30\_neg5\_err5\_5.g & 0.96 & 1.76 & 2.11 & 22.00 & 3010.00 & 144.00 \\
# n60\_k4\_pos30\_neg5\_err10\_1.g & 1.51 & 7.26 & 3.28 & 72.00 & 7064.00 & 228.00 \\
# n60\_k4\_pos30\_neg5\_err10\_2.g & 1.14 & 4.57 & 3.07 & 97.00 & 2437.00 & 397.00 \\
# n60\_k4\_pos30\_neg5\_err10\_3.g & 1.84 & 9.48 & 3.39 & 77.00 & 8559.00 & 225.00 \\
# n60\_k4\_pos30\_neg5\_err10\_4.g & 1.88 & 9.35 & 3.64 & 67.00 & 2501.00 & 360.00 \\
# n60\_k4\_pos30\_neg5\_err10\_5.g & 1.54 & 16.39 & 3.42 & 97.00 & 11534.00 & 305.00 \\
# n60\_k4\_pos30\_neg5\_err20\_1.g & 3.94 & 55.30 & 7.69 & 663.00 & 19497.00 & 1503.00 \\
# n60\_k4\_pos30\_neg5\_err20\_2.g & 5.85 & 53.02 & 25.16 & 1269.00 & 25012.00 & 3766.00 \\
# n60\_k4\_pos30\_neg5\_err20\_3.g & 6.87 & 172.72 & 28.11 & 1396.00 & 53966.00 & 4945.00 \\
# n60\_k4\_pos30\_neg5\_err20\_4.g & 4.84 & 56.95 & 15.41 & 1070.00 & 18352.00 & 3337.00 \\
# n60\_k4\_pos30\_neg5\_err20\_5.g & 7.63 & 130.69 & 44.43 & 1732.00 & 44585.00 & 8092.00 \\
# n60\_k4 & 2.82 & 35.90 & 9.95 & 453.07 & 14073.73 & 1588.07 \\
# \bottomrule
# \end{tabular}

# %%
tab_mip_n60_k5 = pd.DataFrame()
tab_mip_n60_k5["instance"] = mip2_n60_k5['instance']
tab_mip_n60_k5["bs1"] = mip1_n60_k5['bs']
tab_mip_n60_k5["bs2"] = mip2_n60_k5['bs']
tab_mip_n60_k5["bs3"] = mip3_n60_k5['bs']
tab_mip_n60_k5["time1"] = mip1_n60_k5['time']
tab_mip_n60_k5["time2"] = mip2_n60_k5['time']
tab_mip_n60_k5["time3"] = mip3_n60_k5['time']
tab_mip_n60_k5["nodes1"] = mip1_n60_k5['nodes']
tab_mip_n60_k5["nodes2"] = mip2_n60_k5['nodes']
tab_mip_n60_k5["nodes3"] = mip3_n60_k5['nodes']

tab_mip_n60_k5
# Out:
#                             instance        bs1        bs2        bs3  \
# 0    n60\_k5\_pos30\_neg5\_err5\_1.g  18.000000  18.000000  18.000000
# 1    n60\_k5\_pos30\_neg5\_err5\_2.g  13.000000  13.000000  13.000000
# 2    n60\_k5\_pos30\_neg5\_err5\_3.g  14.000000  14.000000  14.000000
# 3    n60\_k5\_pos30\_neg5\_err5\_4.g  16.000000  16.000000  16.000000
# 4    n60\_k5\_pos30\_neg5\_err5\_5.g  10.000000  10.000000  10.000000
# 5   n60\_k5\_pos30\_neg5\_err10\_1.g  22.000000  22.000000  22.000000
# 6   n60\_k5\_pos30\_neg5\_err10\_2.g  18.000000  18.000000  18.000000
# 7   n60\_k5\_pos30\_neg5\_err10\_3.g  22.000000  22.000000  22.000000
# 8   n60\_k5\_pos30\_neg5\_err10\_4.g  18.000000  18.000000  18.000000
# 9   n60\_k5\_pos30\_neg5\_err10\_5.g  17.000000  17.000000  17.000000
# 10  n60\_k5\_pos30\_neg5\_err20\_1.g  25.000000  25.000000  25.000000
# 11  n60\_k5\_pos30\_neg5\_err20\_2.g  23.000000  23.000000  23.000000
# 12  n60\_k5\_pos30\_neg5\_err20\_3.g  23.000000  23.000000  23.000000
# 13  n60\_k5\_pos30\_neg5\_err20\_4.g  27.000000  27.000000  27.000000
# 14  n60\_k5\_pos30\_neg5\_err20\_5.g  26.000000  26.000000  26.000000
#                              n60\_k5  19.466667  19.466667  19.466667
#
#        time1      time2      time3  nodes1        nodes2  nodes3
# 0   1.530999   7.057456   3.026175   201.0   6074.000000   635.0
# 1   0.556029   4.539970   1.788411   104.0   3697.000000   267.0
# 2   0.787614   1.164195   2.693398    37.0   2097.000000   239.0
# 3   1.279030   4.094858   3.150110   164.0   2495.000000   465.0
# 4   0.577053   1.046793   1.127290    15.0   1586.000000    66.0
# 5   2.544738  20.642300   6.017452   325.0   6823.000000  1547.0
# 6   1.711206   5.932356   2.478276   134.0   3192.000000   423.0
# 7   2.296765   7.690631   6.406061   358.0   2139.000000  1450.0
# 8   1.748566  19.863235   2.829756   215.0  16693.000000   424.0
# 9   1.353910   3.547748   1.621423    51.0   2446.000000   201.0
# 10  2.785777  55.906832   6.335167   589.0  28758.000000  1689.0
# 11  2.753788  22.328037   6.577866   416.0  13178.000000  1509.0
# 12  1.962922   9.407271   3.893074   307.0   3294.000000  1233.0
# 13  3.610766  30.931963  16.415525   888.0  15440.000000  3819.0
# 14  2.235836  56.821747   7.057079   267.0  19811.000000  1183.0
#     1.849000  16.731693   4.761138   271.4   8514.866667  1010.0

# %%
#print(tab_mip_n60_k5[['instance','bs1','bs2','bs3','time1','time2','time3','nodes1','nodes2','nodes3']].to_latex(index=False,float_format="%.2f"))
print(tab_mip_n60_k5[['instance','time1','time2','time3','nodes1','nodes2','nodes3']].to_latex(index=False,float_format="%.2f"))
# Out:
# \begin{tabular}{lrrrrrr}
# \toprule
# instance & time1 & time2 & time3 & nodes1 & nodes2 & nodes3 \\
# \midrule
# n60\_k5\_pos30\_neg5\_err5\_1.g & 1.53 & 7.06 & 3.03 & 201.00 & 6074.00 & 635.00 \\
# n60\_k5\_pos30\_neg5\_err5\_2.g & 0.56 & 4.54 & 1.79 & 104.00 & 3697.00 & 267.00 \\
# n60\_k5\_pos30\_neg5\_err5\_3.g & 0.79 & 1.16 & 2.69 & 37.00 & 2097.00 & 239.00 \\
# n60\_k5\_pos30\_neg5\_err5\_4.g & 1.28 & 4.09 & 3.15 & 164.00 & 2495.00 & 465.00 \\
# n60\_k5\_pos30\_neg5\_err5\_5.g & 0.58 & 1.05 & 1.13 & 15.00 & 1586.00 & 66.00 \\
# n60\_k5\_pos30\_neg5\_err10\_1.g & 2.54 & 20.64 & 6.02 & 325.00 & 6823.00 & 1547.00 \\
# n60\_k5\_pos30\_neg5\_err10\_2.g & 1.71 & 5.93 & 2.48 & 134.00 & 3192.00 & 423.00 \\
# n60\_k5\_pos30\_neg5\_err10\_3.g & 2.30 & 7.69 & 6.41 & 358.00 & 2139.00 & 1450.00 \\
# n60\_k5\_pos30\_neg5\_err10\_4.g & 1.75 & 19.86 & 2.83 & 215.00 & 16693.00 & 424.00 \\
# n60\_k5\_pos30\_neg5\_err10\_5.g & 1.35 & 3.55 & 1.62 & 51.00 & 2446.00 & 201.00 \\
# n60\_k5\_pos30\_neg5\_err20\_1.g & 2.79 & 55.91 & 6.34 & 589.00 & 28758.00 & 1689.00 \\
# n60\_k5\_pos30\_neg5\_err20\_2.g & 2.75 & 22.33 & 6.58 & 416.00 & 13178.00 & 1509.00 \\
# n60\_k5\_pos30\_neg5\_err20\_3.g & 1.96 & 9.41 & 3.89 & 307.00 & 3294.00 & 1233.00 \\
# n60\_k5\_pos30\_neg5\_err20\_4.g & 3.61 & 30.93 & 16.42 & 888.00 & 15440.00 & 3819.00 \\
# n60\_k5\_pos30\_neg5\_err20\_5.g & 2.24 & 56.82 & 7.06 & 267.00 & 19811.00 & 1183.00 \\
# n60\_k5 & 1.85 & 16.73 & 4.76 & 271.40 & 8514.87 & 1010.00 \\
# \bottomrule
# \end{tabular}
